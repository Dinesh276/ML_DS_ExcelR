# %% [markdown]
#  TWO:
# 1) Extract reviews of any product from ecommerce website like amazon
# 2) Perform emotion mining

# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
import spacy
from nltk.corpus import stopwords
from autoscraper import AutoScraper
import re

# %% [markdown]
# # Imporiting Words List to be used

# %% [markdown]
# ### Positive word List

# %%
pos=pd.read_csv('positive-words.txt',sep='\n',  encoding='cp1252',header=None)
pos.iloc[30:40,:]
# Out:
#                                                     0
# 30  ;       mistakes. They are included as these m...
# 31       ;       frequently in social media content.
# 32                                                  ;
# 33  ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;...
# 34                                                 a+
# 35                                             abound
# 36                                            abounds
# 37                                          abundance
# 38                                           abundant
# 39                                         accessable

# %%
pos[pos[0]=='a+'].index.values
# Out:
# array([34], dtype=int64)

# %%
pos.drop(range(0,35),axis=0,inplace=True)
pos.reset_index(inplace=True)

# %%
pos.drop(labels=['index'],axis=1,inplace=True)
pos.head()
# Out:
#             0
# 0      abound
# 1     abounds
# 2   abundance
# 3    abundant
# 4  accessable

# %%
pos['Value']=np.ones(shape=(pos.shape[0]),dtype=int)

# %%
pos
# Out:
#                0  Value
# 0         abound      1
# 1        abounds      1
# 2      abundance      1
# 3       abundant      1
# 4     accessable      1
# ...          ...    ...
# 2000    youthful      1
# 2001        zeal      1
# 2002      zenith      1
# 2003        zest      1
# 2004       zippy      1
#
# [2005 rows x 2 columns]

# %% [markdown]
# # Negative Words List

# %%
neg=pd.read_csv('negative-words.txt',sep='\n',  encoding='cp1252',header=None , )
neg.head(5)
# Out:
#                                                    0
# 0  ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;...
# 1                                                 ;
# 2                        ; Opinion Lexicon: Negative
# 3                                                  ;
# 4  ; This file contains a list of NEGATIVE opinio...

# %%
neg[neg[0]=='2-faces'].index.values
# Out:
# array([35], dtype=int64)

# %%
neg.drop(range(0,36),axis=0,inplace=True)
neg.reset_index(inplace=True)

# %%
neg.drop(labels=['index'],axis=1,inplace=True)
neg.head()
# Out:
#             0
# 0    abnormal
# 1     abolish
# 2  abominable
# 3  abominably
# 4   abominate

# %%
neg['Value']=[-1 for i in range(0,neg.shape[0])]

# %%
neg
# Out:
#                0  Value
# 0       abnormal     -1
# 1        abolish     -1
# 2     abominable     -1
# 3     abominably     -1
# 4      abominate     -1
# ...          ...    ...
# 4776        zaps     -1
# 4777      zealot     -1
# 4778     zealous     -1
# 4779   zealously     -1
# 4780      zombie     -1
#
# [4781 rows x 2 columns]

# %% [markdown]
# __List Combine__

# %%
all_words = neg.append(pos)
all_words
# Out:
#                0  Value
# 0       abnormal     -1
# 1        abolish     -1
# 2     abominable     -1
# 3     abominably     -1
# 4      abominate     -1
# ...          ...    ...
# 2000    youthful      1
# 2001        zeal      1
# 2002      zenith      1
# 2003        zest      1
# 2004       zippy      1
#
# [6786 rows x 2 columns]

# %% [markdown]
# ### Stop Words

# %%
stop1=stopwords.words('english')
list(stop1)
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
stop2=pd.read_csv('stop.txt',sep='\n',  encoding='cp1252',header=None)
stop2=np.array(stop2).flatten()
stop2=list(stop2)
stop2
# Out:
# ['a',
#  "a's",
#  'able',
#  'about',
#  'above',
#  'according',
#  'accordingly',
#  'across',
#  'actually',
#  'after',
#  'afterwards',
#  'again',
#  'against',
#  "ain't",
#  'all',
#  'allow',
#  'allows',
#  'almost',
#  'alone',
#  'along',
#  'already',
#  'also',
#  'although',
#  'always',
#  'am',
#  'among',
#  'amongst',
#  'an',
#  'and',
#  'another',
#  'any',
#  'anybody',
#  'anyhow',
#  'anyone',
#  'anything',
#  'anyway',
#  'anyways',
#  'anywhere',
#  'apart',
#  'appear',
#  'appreciate',
#  'appropriate',
#  'are',
#  "aren't",
#  'around',
#  'as',
#  'aside',
#  'ask',
#  'asking',
#  'associated',
#  'at',
#  'available',
#  'away',
#  'awfully',
#  'b',
#  'be',
#  'became',
#  'because',
#  'become',
#  'becomes',
#  'becoming',
#  'been',
#  'before',
#  'beforehand',
#  'behind',
#  'being',
#  'believe',
#  'below',
#  'beside',
#  'besides',
#  'best',
#  'better',
#  'between',
#  'beyond',
#  'both',
#  'brief',
#  'but',
#  'by',
#  'c',
#  "c'mon",
#  "c's",
#  'came',
#  'can',
#  "can't",
#  'cannot',
#  'cant',
#  'cause',
#  'causes',
#  'certain',
#  'certainly',
#  'changes',
#  'clearly',
#  'co',
#  'com',
#  'come',
#  'comes',
#  'concerning',
#  'consequently',
#  'consider',
#  'considering',
#  'contain',
#  'containing',
#  'contains',
#  'corresponding',
#  'could',
#  "couldn't",
#  'course',
#  'currently',
#  'd',
#  'definitely',
#  'described',
#  'despite',
#  'did',
#  "didn't",
#  'different',
#  'do',
#  'does',
#  "doesn't",
#  'doing',
#  "don't",
#  'done',
#  'down',
#  'downwards',
#  'during',
#  'e',
#  'each',
#  'edu',
#  'eg',
#  'eight',
#  'either',
#  'else',
#  'elsewhere',
#  'enough',
#  'entirely',
#  'especially',
#  'et',
#  'etc',
#  'even',
#  'ever',
#  'every',
#  'everybody',
#  'everyone',
#  'everything',
#  'everywhere',
#  'ex',
#  'exactly',
#  'example',
#  'except',
#  'f',
#  'far',
#  'few',
#  'fifth',
#  'first',
#  'five',
#  'followed',
#  'following',
#  'follows',
#  'for',
#  'former',
#  'formerly',
#  'forth',
#  'four',
#  'from',
#  'further',
#  'furthermore',
#  'g',
#  'get',
#  'gets',
#  'getting',
#  'given',
#  'gives',
#  'go',
#  'goes',
#  'going',
#  'gone',
#  'got',
#  'gotten',
#  'greetings',
#  'h',
#  'had',
#  "hadn't",
#  'happens',
#  'hardly',
#  'has',
#  "hasn't",
#  'have',
#  "haven't",
#  'having',
#  'he',
#  "he's",
#  'hello',
#  'help',
#  'hence',
#  'her',
#  'here',
#  "here's",
#  'hereafter',
#  'hereby',
#  'herein',
#  'hereupon',
#  'hers',
#  'herself',
#  'hi',
#  'him',
#  'himself',
#  'his',
#  'hither',
#  'hopefully',
#  'how',
#  'howbeit',
#  'however',
#  'i',
#  "i'd",
#  "i'll",
#  "i'm",
#  "i've",
#  'ie',
#  'if',
#  'ignored',
#  'immediate',
#  'in',
#  'inasmuch',
#  'inc',
#  'indeed',
#  'indicate',
#  'indicated',
#  'indicates',
#  'inner',
#  'insofar',
#  'instead',
#  'into',
#  'inward',
#  'is',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  'j',
#  'just',
#  'k',
#  'keep',
#  'keeps',
#  'kept',
#  'know',
#  'knows',
#  'known',
#  'l',
#  'last',
#  'lately',
#  'later',
#  'latter',
#  'latterly',
#  'least',
#  'less',
#  'lest',
#  'let',
#  "let's",
#  'like',
#  'liked',
#  'likely',
#  'little',
#  'look',
#  'looking',
#  'looks',
#  'ltd',
#  'm',
#  'mainly',
#  'many',
#  'may',
#  'maybe',
#  'me',
#  'mean',
#  'meanwhile',
#  'merely',
#  'might',
#  'more',
#  'moreover',
#  'most',
#  'mostly',
#  'much',
#  'must',
#  'my',
#  'myself',
#  'n',
#  'name',
#  'namely',
#  'nd',
#  'near',
#  'nearly',
#  'necessary',
#  'need',
#  'needs',
#  'neither',
#  'never',
#  'nevertheless',
#  'new',
#  'next',
#  'nine',
#  'no',
#  'nobody',
#  'non',
#  'none',
#  'noone',
#  'nor',
#  'normally',
#  'not',
#  'nothing',
#  'novel',
#  'now',
#  'nowhere',
#  'o',
#  'obviously',
#  'of',
#  'off',
#  'often',
#  'oh',
#  'ok',
#  'okay',
#  'old',
#  'on',
#  'once',
#  'one',
#  'ones',
#  'only',
#  'onto',
#  'or',
#  'other',
#  'others',
#  'otherwise',
#  'ought',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'outside',
#  'over',
#  'overall',
#  'own',
#  'p',
#  'particular',
#  'particularly',
#  'per',
#  'perhaps',
#  'placed',
#  'please',
#  'plus',
#  'possible',
#  'presumably',
#  'probably',
#  'provides',
#  'q',
#  'que',
#  'quite',
#  'qv',
#  'r',
#  'rather',
#  'rd',
#  're',
#  'really',
#  'reasonably',
#  'regarding',
#  'regardless',
#  'regards',
#  'relatively',
#  'respectively',
#  'right',
#  's',
#  'said',
#  'same',
#  'saw',
#  'say',
#  'saying',
#  'says',
#  'second',
#  'secondly',
#  'see',
#  'seeing',
#  'seem',
#  'seemed',
#  'seeming',
#  'seems',
#  'seen',
#  'self',
#  'selves',
#  'sensible',
#  'sent',
#  'serious',
#  'seriously',
#  'seven',
#  'several',
#  'shall',
#  'she',
#  'should',
#  "shouldn't",
#  'since',
#  'six',
#  'so',
#  'some',
#  'somebody',
#  'somehow',
#  'someone',
#  'something',
#  'sometime',
#  'sometimes',
#  'somewhat',
#  'somewhere',
#  'soon',
#  'sorry',
#  'specified',
#  'specify',
#  'specifying',
#  'still',
#  'sub',
#  'such',
#  'sup',
#  'sure',
#  't',
#  "t's",
#  'take',
#  'taken',
#  'tell',
#  'tends',
#  'th',
#  'than',
#  'thank',
#  'thanks',
#  'thanx',
#  'that',
#  "that's",
#  'thats',
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'thence',
#  'there',
#  "there's",
#  'thereafter',
#  'thereby',
#  'therefore',
#  'therein',
#  'theres',
#  'thereupon',
#  'these',
#  'they',
#  "they'd",
#  "they'll",
#  "they're",
#  "they've",
#  'think',
#  'third',
#  'this',
#  'thorough',
#  'thoroughly',
#  'those',
#  'though',
#  'three',
#  'through',
#  'throughout',
#  'thru',
#  'thus',
#  'to',
#  'together',
#  'too',
#  'took',
#  'toward',
#  'towards',
#  'tried',
#  'tries',
#  'truly',
#  'try',
#  'trying',
#  'twice',
#  'two',
#  'u',
#  'un',
#  'under',
#  'unfortunately',
#  'unless',
#  'unlikely',
#  'until',
#  'unto',
#  'up',
#  'upon',
#  'us',
#  'use',
#  'used',
#  'useful',
#  'uses',
#  'using',
#  'usually',
#  'uucp',
#  'v',
#  'value',
#  'various',
#  'very',
#  'via',
#  'viz',
#  'vs',
#  'w',
#  'want',
#  'wants',
#  'was',
#  "wasn't",
#  'way',
#  'we',
#  "we'd",
#  "we'll",
#  "we're",
#  "we've",
#  'welcome',
#  'well',
#  'went',
#  'were',
#  "weren't",
#  'what',
#  "what's",
#  'whatever',
#  'when',
#  'whence',
#  'whenever',
#  'where',
#  "where's",
#  'whereafter',
#  'whereas',
#  'whereby',
#  'wherein',
#  'whereupon',
#  'wherever',
#  'whether',
#  'which',
#  'while',
#  'whither',
#  'who',
#  "who's",
#  'whoever',
#  'whole',
#  'whom',
#  'whose',
#  'why',
#  'will',
#  'willing',
#  'wish',
#  'with',
#  'within',
#  'without',
#  "won't",
#  'wonder',
#  'would',
#  'would',
#  "wouldn't",
#  'x',
#  'y',
#  'yes',
#  'yet',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'z',
#  'zero']

# %%
stop=stop1+stop2
print(len(stop))
stop3=set(stop)
print(len(stop3))
# Out:
# 750
# 599

# %% [raw]
# stop=stop.append(stopwords.words('english'))
# print(len(stop))
# stop=np.array(stop).flatten()
# stop

# %% [markdown]
# # ExcelR reviews list

# %%
url='https://www.excelr.com/testimonials'

# %%
wanted_list=['Productive Training with clear explanation could require more reading material. Overall good and useful training.']

# %%
scrap=AutoScraper()

# %%
result=scrap.build(url,wanted_list)

# %%
result
# Out:
# ['Good',
#  'Productive Training with clear explanation could require more reading material. Overall good and useful training.',
#  'Could understand the basics of boom and feel confident for certification and to work on boom fool as well. Thanks.',
#  'Useful training intern of project & Business requirement excellent use case materials & senarios . overall this is good',
#  'The Training provided by krishna sir was excellent.',
#  'The 4 days training course was very effective. the trainer played a key role in explained each concept in dept.',
#  'Great',
#  'Teaching method and examples were good. Pace was bit fast & Training material is missing content intro page but overall it was a great experience.',
#  'Trainer is very professional and effective speaker. we will able to group data as much as possible interactive session made it a success.',
#  'Excellent',
#  'Well planed course and Could relate with real time examples at work.',
#  'Well explained course with real time examples. which helped me to relate with.',
#  'Well organized , easy to understand.',
#  'The Course was very effective & useful instructor gave real time examples & We could connect the concepts well.',
#  'The PMP training was very engaging and the concepts were very clearly explained with examples by Krishna.',
#  'Well Structured Training, easy to understand & Good online Support.',
#  'Very valuable training. Krishna sir provided very good examples which could be easily relates to the topics.',
#  'Course has been structured from pm book is easy to understand.',
#  'Training Provided was excellent, all key areas were covered with clear explanation & Relevant Examples.',
#  'Training & Course was really good . overall good training.',
#  'It was an excellent experience. cleared lot of my doubts.very useful training for the people who will appear in pmp exam. Methodology used in the Training was clear and interactive.',
#  'Excellent Training by Mr. Krishna , Provided good examples. And went in depth of each knowledge area and process.',
#  'Covered most of the topics.',
#  'Subject pm book is very good but krishna sir did the job well.',
#  "Training on PMP was good . Clear examples was given against each KA's & PG's.",
#  'It is a well organised and well structured course. The teaching method of krishna sir is very interactive.',
#  'The Training was quite help full. Really appreciate Krishna sir efforts towards individual student.',
#  'Training was good &well organized.',
#  'It is a very good and useful course. Through which one can develop their skill set and career growth.',
#  'Very structured program and the process very effective.',
#  'The trainer is interactive and knowledgeable on the area of pmp.',
#  'Training was through and concise.',
#  'Effective, Interactive, Planed coaching approach.',
#  'Very well organized and effective.',
#  'Very Well Structured/ With good real time examples.',
#  'Training was good informative.',
#  'Course is very good.',
#  'Training was good. Duration can be extended & add more hands on exercises.',
#  'kiran Knows the topic very will and he explained the fundamentals and advanced methods , What Why and Where use it. Overall it was very good',
#  'It is good. the trainer was food presentation skills.',
#  'this training on advanced python helped me to concert my on the usage of python . Also helps to understand the various aspects of machine learning.',
#  'Good Understanding on the data science & machine Learning concepts.',
#  'Good Training Science I was not having any background of AI. Concepts are very well arranged and presented. Kiran is a good faculty.',
#  'The course content was very good. Given summary of how to start project on data scioner and machine learning.',
#  'Coursed covered basics of python for half of the day.And will go to the subject . It is Good.',
#  'Training was very informative and well presented.',
#  'Training was good.',
#  'The Course is Excellent point to start journey to Data science.',
#  'Excellent Training',
#  'He has good Knowledge on',
#  'Very Good',
#  'Great explanation and With easy example to understand the topic and make a happy nature to make the session interested',
#  'It Was very nice faulty has explained us to teach and topic very well and with all the practical in day to day life . Finally the entire session was really good',
#  'The Training is Very helpful Because it guides and teach you the value of business.',
#  'The course is designed in very organize structure and it contain many learning elements. Also we learned many points in detailed manner . thanks',
#  'Overall course content and training was excellent good teaching techniques',
#  'Training was good , But not very advanced as expected.The topic was elaborated for the beginners to intermediate but some more advanced topics lick service meshes deep dive into monitoring ect.',
#  'Course is good for the developing with a basic understanding of Kubernetes .',
#  'Training was good',
#  'Training was good ,get the good hands an kubernetes concepts. and more interactive.',
#  'Course was great, one suggestion is to share the presentation deck for each day at the end of training day.',
#  'the training was good. we learn multiple techniques and it is useful to our development',
#  'Overall the training was good. Less time to allocated. Project Management tool become only those are working on the tool.',
#  'Overall the training was good the course give a good overview of project management. I have learnt lot of new information . Trainer did an excellent gob.',
#  'IT Good & detailed out.',
#  'It was excellent . Paced it well and explained with suitable examples. Great session with would help me to get certified on PMP.',
#  'Training was really good and helpful . Krishna helped us to solve so many doubts .Training has been provided on tilling the application also which is relay applicable.',
#  '4 days PMP training was valuable & each topic has been explained neither examples. Which helps to understand the concept',
#  'The Training is good. covered all aspects in depth.',
#  'Valuable & effective , good insight of the tools & techniques',
#  'Really liked the interactive training given by Mr . Krishna , It helped in understanding the concept and easy to remember.',
#  'Overall good',
#  'Ram was best on his capability & skill got good no of stacking point also to have more trainer like him',
#  'IT was training with words learn with fun excellent examples given.',
#  'Course content is good the faculty who came here was god &delivered the thing in a practical manner.',
#  'Training course was good and the topic were explained clearly.',
#  'Very good training . Excellent in communication and in engaging the audiance',
#  'Training was very useful & delivered good understanding about the subject.',
#  'Training session was good and very informative. It will help me enhancing my skill and knowledge in my professional career.',
#  '"It was good and informative\ncontains good examples to explain concepts"',
#  '"The training is must value add and well explained to enhance the device skills\nIt will motivate to perform best practices in organization in day to day basis of service delivery."',
#  'Training content was very subjective and easy to understand. I learn more new things which i never haired in the industry. It was fantastic way sir delivered every point of course.',
#  'Much needed training provided by Mr.Ram Tavva. I appreciate the efforts he put to teach us. Wish him best and best time ahead in future with training.',
#  'Received good knowledge about handling and improving our work and how to implement new things. in terms of IT concerns.',
#  'Training course was made simple and very easy to understand ,It was made more practical approach and faculty made us more engaging with some beautiful examples.',
#  'The training was clear, concise with good amount of depth in terms of topics coverage. I find it very useful and it will help me in doing my job effectively. I find Ram really friendly and knowledgeable.',
#  'Practical fun with learning more examples will make it excellent course.',
#  'It was well organised & content was relevant to my current project.',
#  'Good Session . Very informative & effective.',
#  'Excellent workshop . Very relevant . Super feedback mechanism with view recording',
#  'training is very interactive, Live examples made the process understand clearly. material was very good',
#  'Completed pmp training ,Great session , Good experience',
#  '"The training was good"',
#  'excellent one,Good Delivered',
#  'Good Training experience',
#  'Excellent , Training was a good',
#  'Excellent Training session & Special thanks to krishna.',
#  'Very interactive & engaging training',
#  'Training was very helpful in understanding the concept of PMP class room training by Krishna gave insight to the concept & also how to prepare for exam.',
#  'The training provided was very helpful , effective and reliable . Interactive session',
#  'Valuable & Effective , Good insight of the tools & techniques',
#  'Course material was very apt to prepare for pmp certification and also from an overall knowledge perspective. Trainer was very patient,highly knowledgeable & kept the course to be interactive & interested.',
#  'Excellent & easy to understand, Mr. Krishna us understand each module with simple & precise examples for our better understanding . Thanking you sir.',
#  'PMP Training by Krishna was well served & Really gaining. The concepts delivered were clear and resources used matched excellence. Very informative.',
#  'PMP training was really good by Krishna sir.',
#  'Good knowledge sharing and to course on pmp content.',
#  'The Training was 4 days and it was really nice training with the peoples . Krishna has a really great trainer. I enjoyed the session and learning.',
#  'Good training covering all aspects of project management.',
#  'It was nice learning many things The training was good.',
#  'Training was structured & Krishna sir was explained everything well with good examples.',
#  'The training course is well structured.',
#  'The class room Training was conducted thoroughly professionally . I was enjoyable . It provided insight into the concepts & also to approach the exam preparation.',
#  'PMP class room training very impressed by the level dedication by the faculty Krishna sir and his excellent method of explaining concepts very interactive and effective',
#  'Overall experience was good, Trainer should provide lot more examples which help a lot to understand.',
#  'Very good knowledge and interactive session.',
#  'good training The examples provided during the session helped a lot',
#  '"Course was very good , Preparation guide and preparation tips are good.\nhe explain practical examples to make it even more effective."',
#  'The work shop was informative Real time knowledge examples help full in computer courses.',
#  'Got covered all process with valid examples and i am very much satisfied.',
#  'Nicely conducted course',
#  'Excellent course by excellent instructor . E- learning support is a great thing',
#  'Krishna explained each & every topic with more clarity & live examples . He is very helpful in teaching every small doubts involved & also in the application Process.',
#  'Enough content available.',
#  'PMP training was very satisfactory . The knowledge shared was an good examples and very easy to understand . overall the training was good.',
#  'Very interactive & good training',
#  'Good , Intensive training by Mr Krishna , Supporting staff.',
#  'Training is Good',
#  'The PMP Training was good with relevant examples',
#  'Very good, Highly interactive session, easy to understood and explained with relevant examples , Trainer is highly knowledgeable and having good exposure.',
#  'The course was very organized and learn more on PMP',
#  'It is well managed ,Helpful Training session where most of the doubts are clarified Get a better idea about PMP',
#  'Excellent training by Krishna.',
#  'I attended the 4 days PMP training conducted by Krishna . It was a great.',
#  'The training was excellent with good supporting staff Great teaching',
#  'The 4 days training program was good. Covered all the processes . Also learned the way forward to study fir certification',
#  'Good training . Request to have more scenarios on EVM and contract type in procurement management.',
#  'It was really good, real time examples are easy to relate things to concept',
#  'It was a very good training. Trainer krishna was interesting And helpful throughout',
#  'It was very good',
#  'The training have been very effective as it would be directly motivating in developing good service skill and helping me in improving my way that can be externally used to meet business requirements.',
#  'The training is good and excellent. We learned much things and process about it and its values for organization & business.',
#  'The training was great.',
#  'Excellent faculty, The way to train was ultimate. The presentation and the training course is very good and appropriate.',
#  'Training course has been very much informative and interactively.',
#  'Excellent training on ITIL with good examples',
#  'It was great, very helpfull',
#  'Course was very good, knowledgable',
#  'It was very good provided by Ram Tavva',
#  'Overall it was good knowledgeable course. Learnt new things.',
#  'Learnt many things whish will be useful for future. Trainer is excelent interesting training. Thank you',
#  'Great nice trainer',
#  'Training was very intractive able to make things easy to understand. Able to give examples related to current life.Over all the training is best.',
#  'the training have been very effective as it would be directly motivating in developing good service skill and helping me in improving my way that can be externally used to meet business requirements.',
#  'It was good training.',
#  'MS Training by Excelr was in depth to the subject and the trainer had complete knowledge and Profesinal Experience',
#  'Its very useful to relevant job',
#  'Training is fine.Content and duration could have been made extended more instead of two days.Hard copy study material other than there is also regular.',
#  'Came as novice user in MS.P, Now I can confidently say I know the basics and with real time practice. .I Can be more confident in the tool. Training was well structured and the faculty is highly experienced with the real time industrial knowledge.Which helps in depth understanding.',
#  'Great trainer, explained each and every doubt and always ready for open discussions',
#  'Excellent coverage of topics with some good examples',
#  'Good and effective',
#  'Great material, concepts explained very well. Very helpful',
#  'Good Training session',
#  'Worth spending,Boosts confidence,concepts with day to day examples',
#  'Excellent training.Krishna has made it more interesting and simple with practical examples.',
#  'Course was very good.Though the content being dry,Krishna made it very interactive session and I could gain the required Knowledge.',
#  'It was very interactive specially the faculty Mr. Krishna who is very experienced and make subject very easy by giving real life examples.',
#  'Excellent Trainer,Helped upto understandthings in a simply way',
#  'Simply I would say "EXCELLENT"',
#  'Excellent Training.Thanks to the institute & faculty(Krishna sir) for such a wonderful training.Thanks to Lekshmi for coordinating the training.',
#  'Good Paced training.Covers the required content.',
#  'It was very interactive session and got all doubts and queries cleared by the trainer',
#  'It eases the PMP preparation from daily busy schedule.Given right direction to achieve the goal.Trainer guidance is really valuable.',
#  'Training conducted on PMP was easy to understand and approach was excellent.',
#  'The training is helpful and in detail.',
#  'Well planned,Well paced and good training.',
#  'Krishna was too good in explaining the complete PMP content.Course content was also excellent. He carries good understanding and relate to the real time scenario.',
#  'Perfect.Exceeded my expectations.',
#  'Good understanding of the course was provided that will help clear the concepts.',
#  'Very Good.Helped in proper arrangement of 12 years experience in a sequencial manner.',
#  'Well structured ,organized and delivered. We were able to understand the key concepts well. Good examples helped to connect topics to real life.',
#  'The course was excellent and effective',
#  'Good environment for these who are taking to cruck the PMP examination first attempt.Krishna sir will do the course review in a well manner and knowledgeble',
#  'Course content were explained well, considering the overall requirement to be a PMP professional methods and techniques were well explained.',
#  'Overall experience was really good.',
#  'ExcelR has a standard approach training.The students ExcelR supports and helps till the crack the exam.Training is excellent ,standardised ,straight apporach.',
#  'It was good insight to project management,Good Directions.',
#  'It was good training of 4 days(2 weekends).Topics covered with logical order.Facility provided was good.',
#  'It was very useful and resourceful sevion indeed.',
#  'Very happy with direct classes.But online videos pauses needs to be cut shortened.',
#  'Training was very good with good examples',
#  'Training was awesome.Really appreciate Mr.Krishna',
#  'Very good knowledge transfes on each process',
#  'Training was excellent. Training gave attention to detail in all the knowledge areas.',
#  'Training is given Excellent way and well connecting with real time examples.',
#  'Training Program is satisfactory. Instructor covered the session within a time frame and with good examples.',
#  'Excellent delivery techniques by the trainer. All clarifications were immediate with real time examples.',
#  'It is very useful and able to understand the project management concepts.I have clearly met my expectations by attending the training.',
#  'Amazing Presentation skills. But the pace of the course should be lowered.',
#  'Awesome',
#  'Course Content is very well organized.Trainer is very experienced and we can feel the experience in his content delivering. Very professional faculty and support staffs.I will take this as good starting point for my PMP Journey.',
#  'Good Knowledge & points wise explanation was very clear.Clearly helps us to start the preparation. Very effective approach in delivering',
#  'Overall training was really good.Faculty is good, but facility is ok.If after every session an online short exam be kept, that would be really great.',
#  'Very good and informative',
#  'Very Good ,Informative',
#  'Training program was very good.Got detail insight of the subject.Thank You',
#  'Trainer Mr.Krishna is very well versed of PMP concepts. During the sessions, he cited day to day life examples which made the session very interesting and learning a cakewalk.Overall great learning experience.',
#  'Overall training is very good and useful.I got what I expected.',
#  'Very useful to enhance the project management knowledge and to become PMP course materials are very simple and easy to understand.',
#  'Overall it was a nice experience.Very informative training.',
#  'Excellent Course Content.Covers basics of statistical terms and data analysis.Got a newer perspective to analyse data in our formation and to enhance the product development efficiencies.',
#  'Training was found to be verygood and may help us in analyzing our data in a good way.',
#  'Topics covered are very interesting.But can be made tailored according to the customer data.',
#  'Content was involved from fundamentals to little advancement in the data analysis.It was worth to attend the course.',
#  'Training was very good.It covered most of the relevant topics.',
#  'I have attended 2 days PMI - ACP training session at ExcelR. Trainer Ram Tavva well trained us. He has excellent knowledge of the subject.',
#  'Good,Can be shortened by half a day',
#  'Training course is very well organized with clear output of the agenda',
#  'Training was very good.Clarifications are done better. Nice Presentation.',
#  'Trainer Ram Tavva was the excellent knowledge on the subject and teaches with good examples to understand.',
#  'Faculty Ram Tavva shared knowledge is very good and polite.Clarified the doubts .Excellent training presenting skills was very good.Finally this is very good and helped to us.',
#  'Need to be explained by using IT related scenarios instead of manufacturing & construcions.Otherwise overall very good and understandable.',
#  'Training was very interesting & informative.',
#  'Training was good, Explained with examples very interesting.Not get bored.Good Session.',
#  'The faculty was well aware of the concepts and was patient enough to listen to queries and answer them.',
#  'Before training course I dont know agile methodology. After completing then I know good about the agile methodology.',
#  'Course content was very good.The faculty is pretty aware about the concept the concept and patient enough to listen and answer the queries.The course was good enough to implement at work.',
#  'Training was very satisfied and was more interactive where every person can understands the concept well.Also the trainer has gave some excitement so that we learn and understand more.',
#  'Training provided by the faculty was very good. Gave a thorough knowledge on agile from base, as a fresher also it was really helpful and understandable training.',
#  'It is very useful to us what has use to the planning the project as some advantage',
#  'He teached very nice way and took live examples.',
#  'Training was good and its superb good Explanations.',
#  'As a fresher I got good knowledge about agile.',
#  'Good Coverage of the Examination syllabus.',
#  'Good interactive training session. organized and planned teaching. Very much effective. Overall very good techniques to teach these theoretical courses',
#  'Very good course content.Structured, very accommodating. Krishna sir has a very good teaching technique.',
#  "The course was very well structured/organized. Trainer understood the student's requirement and clearly explained the concepts.I could easily grasp the concepts.",
#  'Training content and delivery was very good.Krishna explained the processes with good examples which helps to grasp the concept.',
#  'Training provided by krishna was excellent',
#  'Training was effective,preuse and valuable to the core .happy with the trainer and his method of training.',
#  'It is really a wonderful training.Trainer gave each and every process thoroughly with examples.Every parts of exam he explain in detail.Krishna sir is extrordinary in PMP Training',
#  'The training was very good, especially the trainer Mr.Krishna course topics were well covered and now I have confidence that I will clear the certification.',
#  'Training was very much informative with live examples on each concepts.',
#  'Training Provided was upto the mark.',
#  'Training was very informative and helpful. Well organised and structured.',
#  'Training was interactive and well structured. Explained all the aspect in detail.',
#  'The training was really informative and linked with many real examples.',
#  'Training was satisfactory.',
#  'It was a great experience with ExcelR.I appreciate the trainer Mr,Krishna for his explanation, examples and doubt clearance.',
#  'Excellent training Delivery.Very Professional delivery course material and the contents chosen as part of explanation was apt.',
#  'It was very good. Good introduction and complete guide to get the PMP.',
#  "It's a Good Learning Experience.",
#  'Exellent training provided by Krishna and ExcelR Team.',
#  'The training met my objectives.The instructor communicated clearly and used relevant examples.',
#  'Very Structured training, Krishna is very knowledgeable and the class is lively.',
#  'The Course was really good which has given me a breakthrough on the subject matter and Krishna sir has very patiently given clarity on the subject matter which has motivated me to do the certification',
#  'It was nice training ever attended. It explores the different knowledge area of project management.',
#  'Good Training conducted and advised for exam preparations.',
#  'All Sessions were really good with interactions and examples.material provided is also good for covering the required details and information.',
#  'Awesome,No Comment on excellence.',
#  'The training was very effective. Even though the subject is very deep and full of theories, the trainer is able to keep the session in such a way that I was able to be attentive throughout. The breaks are very thoughtfully done.',
#  'Excellent coaching, the examples used were helpful to understand. Heartfelt Thanks to Mr.Krishna & the ExcelR team.',
#  'Well paced, Structured training. Covered all the areas quite well. Trainer Krishnam Raj sir has very good command over the topics.',
#  'Excellent Training, Student friendly Trainer',
#  'Training was good, Well paced and helpful.',
#  'Training made me realize the easiest way of preparing the methods,examples,clarity provided to us was very useful.Simple language was a highlight.Trainer was giving very simple examples which made easy.',
#  'Interesting and really motivating. As the trainer convince, he is available to help us.',
#  'It was good& detailed training followed by practical examples. Liked the way each chapter was co-related with another & properly explained with logic.',
#  'Training was delivered with good examples.Easier to connect to the subject.',
#  'Very good interactive sessions.',
#  'Course was not interactive but the content was very good.It would have been better to let the instructor explain instead of continuous videos . Trainer was excellent though.',
#  'Excellent training with real world scenario empowered with recommended tools,skills. Interactive and time management was excellent.Enjoyed!!!',
#  'The training was very interactive and intense. I have gained lot of knowledge on Agile and its principles.Hoping to attend PMP training as well in the near future.',
#  'Trainer is very knowledge and peomising.Good Communication skills.In depth knowledge on concept .Useful course materials.',
#  'Very good and learnt a lot from Ram.It was very helpful to understand training completely.',
#  'Course was well conducted.Concept were made clear. But at the end felt the topics were slightly rushed.',
#  'Training was excellent.Got confidence on passing the exam.',
#  'The training definitely serves the complete expectations.The trainer is very well experienced and helps understand all the concepts with ease.Would be more good if the duration was distributed to 3-4 days followed by assessment.',
#  'It was overall good training session emphasizing on the basic guidewire concepts and workflow.',
#  'The material covered almost all the important concepts of guidewire and the trainer has explained thoroughly as expected within the stipulated time. The trainer cleared the basic concepts too and I had a great learning time.',
#  'The training was useful in setting up the foundation for Guidewire.',
#  'It was really very good, informative with clarity.',
#  'It was good.',
#  'It is good',
#  'Very helpful & could gain knowledge. Very subjective for day to day work.',
#  'Very well articulated and explained.',
#  'Everything was good, covered all the topics. Could teach more about R programming concepts were explained very clearly.',
#  'Course has been satisfactory.The entire range of topics were discussed.Faculty was good at handling doubts. However the course can be improved by making weekly assgnment compulsory.',
#  'Overall course is good,but the place is very high.If the pace can slowered a bit then it will be very good. Knowledge of faculty is very good.',
#  "This course nowadays it's trending course,lectures are good,good teaching. It is so useful to us.",
#  'The training was very good.But if more classroom training. So it helps very much to us.Rest of things are very good about faculty and institute.',
#  'Very good training provided by the trainer.Made us learn complex techniques with ease and made the concepts clear.',
#  'Course has been good,training provided was apt and well explained by Mr.Dinesh.',
#  'Very Good,explanation with examples.Informative,Get to know new terminology.',
#  'Excellent and very useful.Gained knowledge about ITIL in two days.The way trainer explained in excellent and very easy to understand.',
#  'This course would really help any kind of Business to be managed in a better structure.',
#  'It was understandable session with live references and incidents.Which helped in understanding. Also appreciate the additional info on ITIL Foundation.',
#  'Very Much informative',
#  'Tranier giving with best examples and understand the process of concepts.',
#  'Explained with simple and easy examples.',
#  'Understd the process of service in systematic manner',
#  'It was very good, very interactive and will be useful in our day to day activities.',
#  'Session wasgood & interesting. As a young support engineer it given more knowledge on how to manage the things.',
#  'Very Well Conducted course with practical and relevant examples & discussions.Keep it up.',
#  '"Trainer is a very professional and exlained in a very good way.Course contents were very helpful in our daily activities.\n"',
#  'It was very much relevant for IT people.It was very useful.',
#  'Informative and Useful',
#  'The course training given with live examples made me easy to understand-Thanks.',
#  'Good and Interactive, trainer provided the the knowledge required.',
#  'Training was good, Trainer gave live examples to make us understand the concepts worth attending it.',
#  'Good With real wotld examples, the session was intensity and informative.',
#  'Training was good, but more and more practical session should be done to get the grip on the subject.',
#  'Sir, tremending set of courses influnce to basic level with high altitude. So we can understand fairly, clearly concept wise. LMS content and online webinars helps',
#  'Best and quality training course.Best place to learn data science.Course material and course contents are very nice and relevant.Trainer have good knowledge.',
#  "It's good, as the content is huge, need the additional classes or you should provide one week of gap,so that working people will concentrate and ask the questions as well. Need more assistance as the subject is huge.",
#  'Overall course content and support is good.But we spent more on theory rather application of the theory, which is more important for Data Science. Need more Scenarios or classroom examples and length of the classroom is more.Anything horizontal with less rows would be better.',
#  'Teaching was excellent.Course was well structural. Mostly was focus on theory, it would have been more better with practical classes. Great support with materials too. Overall 4/5.',
#  "Course was well designed & the concepts given by faculty is excellent,but the coding part explanation would have been nice, although time frame won't permit. I recommend my friends very likely.",
#  "Mentor is good in delivering the subject in understandable way. Only difficulties faced ,more concepts covered in same day,couldn't able to get when to apply which concepts.If 3 or 4 data sets would solved in five by mentor using different techniques is used for same data sets.",
#  'It was very good and interactive session, It helped to relate the real time things in the office environment.',
#  'Excellent tutor,having in depth knowledge of the subjectand very engaging during the training.',
#  'Excellent Training. Gave very good insight on how to implement CSI & how an organization can benefit from its implementation. Trainer was highly experienced.',
#  'The training provided me an understanding of one can cut across the IT life cycles and bring in an improvement for the organization',
#  'Very interactive',
#  'Overall satisfied with training and the discipline',
#  'Interactive,Knowledgeable faculty',
#  'PMP training was simple ,effective and Interactive',
#  'Training was effective to prepare for final exam-PMP',
#  'Concepts were really well explained, trainer was excellent & co-operative. Overall had a great experience.',
#  'Krishnam Raj Sir has very good knowledge on PMP Course.I love the way he teaches the course partical.',
#  'Matured approach by Trainer.Students friendly methodologies handled during training.',
#  'Classes were really informative and interactive',
#  'Good,Covered the required topics in good planned Manner.',
#  'Course is excellent.Mr.Krishnam raj explained all the area with simple and good example.Which help me to understood the concept easily.',
#  'Overall training is god and gave us good knowledge of Project Management best practices.',
#  'Training was very good.',
#  'It was good and explained properly.',
#  'PMP training is very useful and explained with real time scenario.',
#  'Excellent Training (Appreciates if more Q and A session could be arranged)',
#  'Excellent training.Trainer Krishna could relate us to real world examples and take us through all knowledge areas at a comfortable and understanding face.Rita Mulcay material was promised as part of the course.But the quality of the material is not good.',
#  'Overall good,Feel like more time will be good.',
#  'Training on PMP all the processes and groups with knowledge areas is very layman understandable.Krishnam Raj is very Knowledgable person and he explained in realistic examples.',
#  'Good Training and was very helpful.',
#  'Training was very informative and very clearly thought in the short available time.Now the confidence and clarity to face exam is high.',
#  "Trainer was wonderful.Provided examples withlayman team& covered all the KA's effectively.",
#  'Good Instructor with required input.',
#  'The training was done very well with examples and explained very well.Thank you very much',
#  'Very Good for initial start,I strongly recommend this classroom training session',
#  'Training was good and helped us understand all KA',
#  'Interactive Training session,efficiently conducted.',
#  'I have been searching for good institutes from last 2-3 months.After completing the PMP course in Excelr,felt the search was worth it.Krishna has indepth knowledge on all topics of PMP.He has covered all process thouroughly and helped to understand clearly',
#  'Best Experience in learning',
#  'Training delivered exceeds expectation',
#  'Mr.Krishna is much experience trainer and provided good training for PMP.',
#  'Very professional approach.Well conducted classroom sessions.',
#  'Good,with clarity and examples.Krishnam Raj is a SME on PMP and has given us clear picture of the subject',
#  'Training was very good with lots of real time examples and working on problems as given in exam,which increases on confidence to face the exam.',
#  'Content is fruitful and the way explaining the concepts also good.',
#  'Got clarified weak points and confusion on process/knowledge areas.',
#  'Excellent Training course.Trainer has explained everything with examples.',
#  'The facilitator was very knowledgeable and warm person and could be reachable for any help and has good hold on the subject.',
#  'The information provided and explained by trainer was excellent. Which is easy to remember and attempt the PMP certification',
#  'Training with Krishna gave a great insight on the subject. Very interactive.',
#  'The flow of course and method of engaging in learning is excellent.',
#  'Training being conducted in a very well structured manner by the PMP Guru - Krishnam Raj',
#  'Training was good, detailed, helped me understand about pmp,and also will help in my daily job activities.Great Work.!!!',
#  'It was a good Experience.It was awesome training.',
#  'I thoroughly enjoyedthe course, Great insights through practical examples.',
#  'Good content coverage, good insights into PMP process coupled with subject knowledge of the trainer, Mr.Krishnam Raj.',
#  'Very well structured& shared what is needed to clear the certification',
#  'Excellent with good case studies.',
#  "Very good interactive sessions. Touched upon industry examples for KA's",
#  'It was good.Suggestions: Please add few more numerical and practice question during sessions?',
#  'Training was very helpful',
#  'A little slow pace,can be followed, but again time has to be managed too.',
#  "Good training with material & trainer behaviour. Training room's Infra could have been better for long sitting.",
#  'Very good session and very profession instructor Mr.Krishnam Raj. it was a tremendous experience overall.',
#  'Training course is good.It helps me to understand the subject.Overall It is a great session',
#  'Total processes can be linked with one generalised project.',
#  'Good-PMP training Course',
#  'Excellent training session.Krishna made it as interactive as possible.I would definitely recommend the institute to anyone who needs to get certified.',
#  'Training was very motivating.Trainer has the good experience and thorough on the subject',
#  'Good Paced training.Covers the required content well.',
#  'All are planned well,Each knowledge areas define in very good manner',
#  'Its really good training.Explained all the relevant topics thoroughly',
#  'It was a good training.Krishna Sir delivers the content very nice & in a way we can understand .It was a very Interactive session',
#  'Satisfactory',
#  'Very informative and interesting',
#  'Got the very good understanding of the PMP in detail.',
#  '"It was helpful,Hopefully will be able to clear my certification on April 28th\n"',
#  'Excellent training happy with the learning krishna is an exceptional trainer with great delivery skills',
#  'Training on PMP .Got good understanding which help understand concepts.Krishna explained the way further helps to explore more,highly recommended to go for it',
#  'The training was very helpful to understand the PMP concepts.Trainer Mr Krishna was very good in making the concepts clear.He also advised on many other things eg :How to clear the exam(road map)',
#  'The pmp training helped me in understanding concepts.Looking forward to your support in exam preparation',
#  'Extremely effective course.Easy understanding with day to day examples.Course duration can be increased to 5 days in order for the information to get assimilated',
#  'BEEN AN AWESOME EXPERIENCE AND THE ENTIRE COURSE WAS DELIVERED IN A FASHION THAT ENTIRE CONCEPT WAS MOLESTED CLEARLY AND EFFECTIVELY',
#  'IN DETAILS STUDY. INTERACTIVE',
#  '"EXCELLENT TRAINING BY TRAINER KRISHNAMRAJ\nAMBIANCE IS GOOD."',
#  'TRAINING QUALITY, AND TOPICS COVERAGE WAS REALLY GOOD. THE TRAINER IS KNOWLEDGEABLE AND MAKES LEARNING EASIER. OVERALL IT WAS WELL PLANED MANAGED AND DELIVERED.',
#  '"FACILITY AND FACULTY BOTH ARE AD-EQUATION\nCLASS ROOM TRAINING ALWAYS HAS A GOOD EFFECT ON LEARNING\nKRISHNA HAS FULFILLED THE NEED AND COMMITMENT "',
#  'VERY USEFUL TRAINING, TRAINER BROKE DOWN SOME OFF THE TOUGHS CONCEPTS , IT SIMPLE ENGLISH MR. KRISHNA GIVE LOT OF SAMPLES AND ENSURED THAT AL OF US UNDERSTAND THIS SUBJECT. VERY INTERACTIVE CLEAR TRAINING IMPARTED.',
#  'Good training ,Facility is not so great',
#  'Training was OK. Concepts needed more in depth clarification and study and demostration through examples during discussions',
#  'The trainers had a vast knowledge of the domain however the agenda and structure of the training could be improved: I think we insisted a bit too much on the very basics (swagger generation, endpoint testing, unit testing) and too little on the actual microservice. Also for future trainings I would recommend having all resources in a Git repository and each day on a branch, so we starting on branch day1, and we try to code this branch to get even with branch day2. I would have liked to insist more on microservice design patterns, architecture and maybe even break down a monolith app into microservices.',
#  'This course helps me to understand better the basics of all the infra services and what the services offer; helps me to understand better the microservices architecture, how the services can communicate one to each other. I understood what is Swagger, what means a Swagger specification file, how can be generated and how it helps. I learnt many new things/technologies like Eureka, Zuul, Kibana, how they can do, what are their roles and how work together.',
#  'It was very good experience but LMS details shared but late otherwise over all is good.',
#  'The course was provided in professional way by quoting the real world examples. Also the trainer "Ram" was kind and patience enough to handle all the queries.',
#  'Very Interactive,hearing skills ,thanks to anoopp',
#  'Very Interesting',
#  'Excellent training.The Explanation of each topic is very nice.',
#  'The training was great.Very informative and interactive.',
#  'Very good,interesting and easy to follow',
#  'Content is relevant and useful.The way of presenting is good.Time is not sufficient to cover all the areas',
#  'It was a very good training.Thank you for your wonderful training on ITIL',
#  'Overall course went well.One small suggestion is to link the examples with IT as well.Also discussing mock test before exam will increase candidate confidence.',
#  'Training is Good. Faculty is explaining the concepts in a very good way',
#  'The trainer was good.',
#  'VERY GOOD -GAINED KNOWLEDGE ABOUT AGILE CONCEPTS',
#  'Require more practice sessions in class room training',
#  'Overall Good. By the end of the course kindly provide the whole lot of material together, instead of posting regularly in drive.',
#  'Overall training can be rated as average. Scenario based examples can help to improve. Further, time to be spent on different topics can be better planned. More focus on unique functionalities of Tabluea can be helpful.',
#  'The way it was designed for the course it was not covered.By designed course my expectation was different.Basically my expectation was how Tableau is different than excel and other software.',
#  "Thankyou very much ExcelR for providing such an interactive sessions .I sincerely appreciate Krishna Sir's dedication to his students .He was very patient throughout the training",
#  'Faculty was good,Teaching was nice',
#  'It was useful & industry related .Made easy to understand',
#  'Impressive training,Good to have here',
#  'The course was a real refresher for the pmp exam preparation',
#  '"Very good overview\nMore examples would have helped\nSession with short tests & quiz will help "',
#  'Excellent training.I would recommend people for this .Only suggestion i have is "Have more examples & provide more shortcuts or technique to remember the some critical concepts',
#  'Mr Yogesh was very good teacher ,Attention to detail as well as attention to students which is pluspoint in him & very good examples for every topic is provided ,Good Recap; Overall very good only one suggestions :For peoples with different background & qualification cooling seems to be difficult & hard to understand so please make it in simple way of teaching if possible',
#  'The arrangements were good and course material is ok.',
#  'Excellent.',
#  'Training was Excellent.',
#  'Training was well phased across 4 days.',
#  'It was quite helpful in understanding the way PMP should be looked at and gave us the direction not only towards the certification but also the very concept of Project Management.',
#  '"A good training covering the basics of PMP course. The Trainers are very cooperative and good in their knowledge and skills.\n"',
#  'Brilliant Training and Coordination Quality training and excellent customer service.',
#  '"It was extremely helpful to understand the Project Management.\nQuality of the content was excellent.\nNice balance of theory and practice."',
#  '"It is overall good. Trainers and training material is good enough to understand.\nTrainers has good knowledge of the subject."',
#  'Very great experience to be in this Training . The faculty has touch based the complex topics with simple day to day example to make it PMP look simple and easy to digest . I highly recommend them and strongly stand with their contributions',
#  '"Training was good, Trainer was very good and clear in concept.\nwhole ExcelR team is very helpful.\nApart from videos if they can provide some reading material , multiple type questions for preparation."',
#  'One of the best educational training institute with good trainers. I highly recommend this training institute.',
#  'GOOD',
#  'Training was quite instructive and helpful to understand the concepts of RMP. Trainer explained well with providing good examples to understand.',
#  'Training was good, but if you could provide the material (Not excelr material) that would be great. Each and every chapter there should have been some exercises to practice.',
#  '"Overall ExcelR Solution is very good option to choose and seek assistance on certification. My online PMP training is really great and covered all topics and real life examples of project management.\nOnline training video and simulation questions are very helpful and i reviewed them couple of times conveniently 24X7. Thanks for ExcelR team to proving such a dynamic environment to get my PMP credential. "',
#  'Very good training. Trainer provided very good n relevant examples to understand the concept. made the class very interesting n interactive.',
#  'Good, Recommended before writing the PMP exam.',
#  'Overall training was good.',
#  '"Training is very methodical. concept explanation is very clear and examples help in easy understanding."',
#  'The training was really good, the concepts are thoroughly explained with examples to understand . The trainers are very help-full .',
#  'The course is good. A perfect kickstart for a novice',
#  'its good and the training ways are good, way of making the concept clear with appropriate examples are outstanding.',
#  'Excellent, i like the examples provided, made me understand tough concepts with easy examples',
#  'Concise, could be more elaborate. LMS is good .',
#  'It was good !!',
#  'Excellent training..keep up the good work!!!',
#  'Training was good and informative. Good examples provided during the training to help relate to ITIL scenarios.',
#  'The training and the material are good. The facilities at the training institute are good. The trainer is very punctual and the sessions are interactive with better examples.',
#  'Excellent in-detailed explanation of Project Management concepts by the trainer. Interactive sessions. Good training material provided by ExcelR. Would recommend ExcelR for PMP training.',
#  'Fruitful... Krishna was able to provide us real time examples which helped us in understanding the concepts easily',
#  'Training was really good. Examples quoted were easy to understand and pace of training was very much comfortable.',
#  'Overall training has been good and would also recommend to have questionnaire session to be conducted at the end of each knowledge area which can be effective.',
#  'Excellent, got clarity and knowledge regarding ITIL concepts.',
#  'Bharani has been an excellent trainer. The kind of serious institute has towards their students and they getting placed, has never seen this before with any of the training institutes. Thank You so much EXCELR',
#  'All the sessions in R and Tableau were very well explained.Also , I was able to contact both Bharani & Srinivas Sir whenever I had doubts.',
#  'Excellent training with lots of hands on excercise. Some good live project exposure too.',
#  'Overall training was very effective. It was worth spending a money. Covered maximum topics and concepts were explained beautifully by trainer.',
#  "The overall training was extremely good. No doubt it is definitely great value for money!! Bharani's knowledge levels on Data Science are really top-notch!! The advantage with ExceR is their trainers are people who have really worked in BA Industry or even currently managing consulting projects to world-class customers on Business Analytics. It greatly helps students to get a industry perspective of Data science domain and the practical issues those come across by excel-r, which may be given to students as case-studies. Overall truly happy and its a wonderful experience, which i surely recommend.. Thanks, Dr. Shajahan, PhD.",
# ...
#  'The training was good and informative.',
#  '"1.Good Training\n2.Satisfied with the training"',
#  'Very Good Training Plan and Trainer was very clear in putting concepts in a crisp way',
#  'Training is very useful and we have learnt about the easy methodologies for applying the process in our routine business works.',
#  'Very Good. Trainer was able to handle the crowd very professionaly and was easily approachable to clarify doubts. He quoted the live examples (online) which helped us to understand the concept easily.',
#  'Good interactive session. Overall it was good and useful',
#  '"The trainer is very knowledgeable and have a very good experience.\nHe evolved his own methods to train the tough parts.\nEven if I\'m new to the subject, I completed the training without having doubts."',
#  "It's good",
#  'good informative, even more interactive',
#  'Very useful training session',
#  '"Agile training is very use full to me, i came to know the clear methodology as a team how we have to take the work how to plan and how to implement the things and complete it in a given timelines.\nThis type of training\'s will help us to improve ourselves."',
#  'Training was very helpful in understanding the concepts.',
#  'Training was informative. Would have been more helpful if the examples were more related to the retail, IT, HR scenarios which would have helped associates in each field to better relate to their work field. Overall training can be rated good!',
#  'The overall training was good.',
#  'Overall PMP framework well articulated by Ram. Was able to connect to the concepts, processes, tools and techniques explained to my job area. Good practical examples were used with a fairly systematic approach on covering the topics',
#  'Interactive,knowledgeable and directive',
#  'Training was intensive and helpful to understand all the 10 Knowledge areas & 47 Processes',
#  'The training was very good .',
#  'Very engaging. Trainer kept everybody attentive !!',
#  'The trainer is very good . He explained with good examples and made easy to understand, All the inputs provided are good.',
#  'The training was very helpful for the daily business and I have learnt more than I expected in terms of IT processes, the trainer was excellent and kept the group active, thanks.',
#  'Great Experience. Very good trainer.',
#  'Training wa good could gain good understanding of the subject',
#  'Should be more practical and need be addressed matured example',
#  'Good place to learn. And more information about outside market',
#  'Excelr is the best place to have excellent quality training',
#  'Analytics Training was very much Interactive and nicely explained',
#  'Super training. Excellent work. I will recommend ExcelR',
#  'Excellent training. Experienced faculty and curriculum is also good',
#  'Excellent institute, trainers and traning process are really excellent. Thanks all the trainer..',
#  'Trainers are very skilled Experts in terms of training and practical experience they provide is awesome.They are really good advisers.They helped me in terms of professional career. I personally recommend people to join EXCELR Solutions for Data Sciences programme.',
#  'Great learning experience and very helpful after the course completion',
#  'Training was good and also staff is very knowledgeable',
#  'They have good coaching manual and videos for self learning apart from their in house training, which is good. Overall it was a good coaching for PMI ACP. Trainers are well trained on concepts and it interactions with the trainers was helpful.',
#  'Excelr Solutions is a nice place if you want to build data science as career option.',
#  'Currently associated with Excelr for data analytics course.. Excellent teaching...with free add-on sessions...gives you confidence to go ahead in the chosen field!!!',
#  'ExcelR provides the best training on data science at a reasonable price and with timing suitable for working professional.Their hands on approach and assignment give lot of confidence.',
#  'I had a very good learning experience with Excel R.. I liked their way of teaching and the course content was very good with relevant practical examples and real time business scenarios.I have taken Data Science course and it was very informative and very well presented by Sharat. I would like to thank Sharat for this wonderful session.',
#  'Very good trAINI9NG AND PERSONAL ATTENTION',
#  'Excellent training ,happy with the learning .Krishna is an exceptional trainer with grat delivery skills',
#  'Very efficient training.Good faculty,good faculty ,Very knowledgeable would be great if the training time was more then 4 days',
#  'THE TRAINING PROGRAM IS PACED PROPERLY AND QUITE HELPFUL IN UNDERSTANDING THE PMP CONCEPTS. THE FACULTY HAS BEEN VERY EFFICIENT IN DELIVERING THE COURSE.',
#  'The training was excellent. The trainer had a good knowledge over the subject and cited relevant examples.\nOverall this was a good training program.',
#  'The trainer was excellent . The overall training was a fun and learning experience.',
#  'The training was structured well,which explains all concepts very holistically followed by the quizzes,that helped me to internalize the knowledge very well',
#  'well structured training,ample knowledge transfer.',
#  'Fantastic way of explaining the concepts with real time scenorious',
#  'Very Well',
#  'Expert Explanation',
#  'Training was excellent. But a bit more indepth would be better',
#  'Very Interactive',
#  'Very good course. Indepth coverage of all topics',
#  'Excellent training sessions',
#  'Very nice sessions to attend. I am very happy in completing this course',
#  'Training was good. LMS was very helpful.The sessions were very elaborative',
#  'Trainer was excellent,explained the concepts very vell',
#  'Good learning. But was a bit fast',
#  'Training was very good and interactive. Very happy with the course',
#  'Very effective and interactive sessions',
#  'Training and the trainer were both good. But time was short',
#  'Was very effective,interactive and explanatory',
#  'Course is very good. Value for monry',
#  'Time was a bit less',
#  'Program was good but would be better with more practicals. Pace could be slow',
#  'Training covers a large amount of topics. But time is a bit less',
#  'Good. But it would be better with more real life examples',
#  'Faculty has great knowledge about the subject. He provided great real life examples',
#  'Course was very good and interactive. Trainer was very supportive and was able to give practical anecdotes',
#  'Very good,detailed,real life examples were provided',
#  'Good material,awesome knowledge,delivery was very good',
#  'Ram gave real life examples which helped relate to ITIL concepts',
#  'Very interactive session,gave lots of realtime IT related examples which helped me. Gained good knowledge on ST concepts',
#  'Very useful and very interactive classes',
#  'Sharat cored about making the course interesting and comprehensive to everyone. great attitude about teaching',
#  'As a working professionals, want to have same kind of material, that cores the main topic along with the memorized things and simple definitions. This is just advise overall training is satisfied',
#  'it is one of the best training institute in Hyderabad with professional facility',
#  'overall training is good, base studies to explain concepts are very well handed. I suggest to have this course for weeks instead of 5',
#  'Overall training is good. Recommended to explore each topic with examples',
#  'Course is structured in very sequencing manner and understanding is very good. Faculty is very good in delivering the content with relevant examples. personally i learnt lot and am confidence now in DS to implement',
#  'In-depth Knowledge of the subject with relevant Examples',
#  'Well planned and clear communication. very good',
#  'Training is very good and faculty has very good Parental skills. I have learnt many things, it is very helpful to me to qualify PMP exam',
#  'Extensive course material and good training sessions',
#  'very helpful and interactive topics were covered cocepts with relevant examples',
#  'ram is a very good coach and is clear on topics which helped to understanding principle and basics of acp i recomend ExcelR for such courses',
#  'Good program',
#  'Informative and concepts were thought.Videos were displayed which made understand better',
#  'Training is very informative with right kind of training materials and knowledgeable trainer',
#  'Good content,knowledgeable instruction,friendly and approachable staff. Overall good place',
#  'Training is very good and the course covers all important topics. It is very useful for project management',
#  'Very useful training to gain knowledge',
#  'The course was designed in a very good way.The trainer explained each cocept with good amount of examples to understand',
#  'Training was clear. Learning was easy and fun',
#  'This training was of great value.Thank you',
#  'Clear and descriptive training on each subject',
#  'Excellent training but needs more time',
#  'Content was very good and helpful.Trainer was very and understandable',
#  'Training was good but duration was short',
#  'Training and content was good.',
#  'Training is conducted in a very good manner so that all understand',
#  'Good and well organized',
#  'One extra day would be better',
#  'Pace is a bit fast',
#  'Course should be for 3 days',
#  'Training was very good.Duration was not enough.',
#  'Our trainer made it very interesting ang gave many creative examples.',
#  'Ram was very nice and interactive,provided good examples',
#  'Content covered was very good.Sessions were very interactive',
#  'Course content was explained very clearly and precisely.It was very effective',
#  'It was a fantastic training session.Ram was a very knowledgable trainer.All the best to Ram and EXCELR',
#  'Trainer Ram was excellent and very interactive',
#  'Ram was an amazing trainer.He kept things very interesting and intriguing,used real life examples to understand better',
#  'Excellent interactive sessions conducted in a very enjoyable manner.It was a productive learning experience.',
#  'Excellent training.Examples were very helpful to understand the concept.',
#  'Trainers are well prepared and have indepth knowledge in the subject.',
#  'Very well structured and interactive.Good knowledge on the subject',
#  'The content and structure is very much useful for my career. The trainer was excellent',
#  'Fully descriptive and thorough training',
#  'Excellent program',
#  'Exellent',
#  'Excellent lecture',
#  'Great interactive training with real life examples for effective understanding.',
#  'The session was very interesting and interactive',
#  'The overall programme was excellent.I have gained more knowledge on ITIL.It will help me in my day to day activities.',
#  'Very informative.Aligned to practical work exposure.Real life examples made understanding easy',
#  'The content of the course and the structure is very useful. It helps me give better service to my client',
#  'Very much relevant for day to day work',
#  'Course contents and the way it was explained was well organized.',
#  'All modules of the course were covered fully.We got a superb trainer.Explanations and examples were very clear',
#  'Good but would be better with more time',
#  'Its good.It would be better if the duration is longer',
#  'Very well explained',
#  'Very useful and attractive',
#  'The course was very engaging and interesting',
#  'Gained knowledge on the subject',
#  'Excellent course',
#  'One of the best sessions i have ever participated in.All chapters related to ITIL were covered in a very short time in a very vibrant way',
#  'Great training',
#  'It was good learning,very understandable',
#  'It would have been better if we had some more time',
#  'Excellent training.Faculty has immense knowledge on subject.He manages it well',
#  'Excellent delivery of material with exercise and useful tips',
#  'Training is very exhaustive,detail and informative.All concepts were explained very well with examples.',
#  'Training is good. Knowledge of trainer is good',
#  'The best coach i ever had',
#  'Krishna comes with rich experience and made the learning sessions very interactive and interesting. He is a very good mentor.',
#  'Classroom sessions are engaging and interesting.All the KA were covered adequately.A good learning experience',
#  'Mentor was knowledgable and clarified our doubts efficiently. Training course was distributed well across 4 days and adequate time was spent on important areas which improved overall understanding.',
#  'PMP training is very good and interactive.Faculty thought us with good examples',
#  'Course was good with LMS access and mock tests.But there are times were it is dull and less interesting.',
#  'Training was good and precise. Our trainer was like an experienced professional.The facilities at the training centre were good too.Overall a good learning atmosphere.',
#  'The objective and delivery of the course is very clear and helps one to easily understand the project management.Also the examples were very helpful. i felt it was an effective and efficient session.',
#  'Course is well prepared and documented.More examples would be better',
#  'Training was good.Facilitator was clear on content and explained with common examples which made it easier.',
#  'I think it was all-in-all a good experience learning from ExcelR',
#  'Kiran demonstrated all the traits.required for the session excellently.',
#  'Training was very interactive , various field people , having no of examples.well explained training.',
#  'This is excellent and very informative and trainer is very interactive and crowd pulling. I enjoyed. I got my encouragement boosted for attending exam and seems easy to crack based on training & inputs',
#  'communication was very clear ,but completing the course in 4 days is good to have on saturdays .or even for better managing .only on the 1st half of saturdays& sundays would be fine.Infrastructure resources can be aligned better.',
#  'It is good presentation and the course content covered is understandable and it is easy to understand the PMP program',
#  'I had a great experience in learning PMP with trainer Krishna. With real time scenarios.',
#  'Good Trainer ,Clear understanding',
#  'Good Experience',
#  'Training given was good and set the understanding on the basics of ITIL',
#  'Excellent training provided by the experts on board with Excelr .Overall wonderful experience with this institute for my ITIL Foundation .Real time scenarios would further help us in understanding ITIL',
#  'Helpful & Adds a value add to our day to day work environment according to our role',
#  'It was good,We got lots of knowledge & understanding over the subject',
#  'Very good trainer ,Dinesh helped 7us to understand course with good & practical examples quality of training material solves the purpose .Have learnt a lot in my training with new knowlege to implement in daily worth',
#  'All the information regarding the training course was properly provided',
#  'The course was very helpful .The content was excellent',
#  'Nice Explanation ,Clearing the doubts, Giving real time examples to make concepts more visible',
#  'Helpful & interesting throughout the course',
#  'The course was very helpful also materials are very good ,Trainers are very Friendly',
#  'The training material and the classroom training is excellent .The trainer has efficiently explained the topics',
#  'Overall its an enriching learning experience .Very much satisfied with the course content and coaching style and depth of hold on the topic',
#  'I appreciate clartity and quality of the course content delivered by trainer "Yogesh".Iam happy to say that time & money inverted is worth to take your career to next level .I would suggest to allocate more time for practical lab senior',
#  'The course is quite exhaustive & attention to details is paramount',
#  'Very good & reached expectations.Gained confidence as i have gap in my career.Maintaining whatsapp group is good & also LMS videos are clear',
#  'The course quite exhaustive & attention to details is paramount',
#  ...]

# %%
len(result)
# Out:
# 1381

# %% [markdown]
# # Text Preprocessing

# %%
from nltk.stem import WordNetLemmatizer
wnl=WordNetLemmatizer()

# %%
X=[]
for i in range(len(result)):
    sent=result[i].strip()
    sent=re.sub(r'[^a-zA-z]',' ',result[i])
    sent=re.sub('_',' ',sent)
    sent=sent.lower()
    words=nltk.word_tokenize(sent)
    sent=[wnl.lemmatize(word) for word in words if not word in stop3]
    sent=' '.join(sent)
    X.append(sent)

# %%
X
# Out:
# ['good',
#  'productive training clear explanation require reading material good training',
#  'understand basic boom feel confident certification work boom fool',
#  'training intern project business requirement excellent case material senarios good',
#  'training provided krishna sir excellent',
#  'day training effective trainer played key role explained concept dept',
#  'great',
#  'teaching method example good pace bit fast training material missing content intro page great experience',
#  'trainer professional effective speaker group data interactive session made success',
#  'excellent',
#  'planed relate real time example work',
#  'explained real time example helped relate',
#  'organized easy understand',
#  'effective instructor gave real time example connect concept',
#  'pmp training engaging concept explained example krishna',
#  'structured training easy understand good online support',
#  'valuable training krishna sir provided good example easily relates topic',
#  'structured pm book easy understand',
#  'training provided excellent key area covered clear explanation relevant example',
#  'training good good training',
#  'excellent experience cleared lot doubt training people pmp exam methodology training clear interactive',
#  'excellent training mr krishna provided good example depth knowledge area process',
#  'covered topic',
#  'subject pm book good krishna sir job',
#  'training pmp good clear example ka pg',
#  'organised structured teaching method krishna sir interactive',
#  'training full krishna sir effort individual student',
#  'training good organized',
#  'good develop skill set career growth',
#  'structured program process effective',
#  'trainer interactive knowledgeable area pmp',
#  'training concise',
#  'effective interactive planed coaching approach',
#  'organized effective',
#  'structured good real time example',
#  'training good informative',
#  'good',
#  'training good duration extended add hand exercise',
#  'kiran topic explained fundamental advanced method good',
#  'good trainer food presentation skill',
#  'training advanced python helped concert usage python help understand aspect machine learning',
#  'good understanding data science machine learning concept',
#  'good training science background ai concept arranged presented kiran good faculty',
#  'content good summary start project data scioner machine learning',
#  'coursed covered basic python half day subject good',
#  'training informative presented',
#  'training good',
#  'excellent point start journey data science',
#  'excellent training',
#  'good knowledge',
#  'good',
#  'great explanation easy understand topic make happy nature make session interested',
#  'nice faulty explained teach topic practical day day life finally entire session good',
#  'training helpful guide teach business',
#  'designed organize structure learning element learned point detailed manner',
#  'content training excellent good teaching technique',
#  'training good advanced expected topic elaborated beginner intermediate advanced topic lick service mesh deep dive monitoring ect',
#  'good developing basic understanding kubernetes',
#  'training good',
#  'training good good hand kubernetes concept interactive',
#  'great suggestion share presentation deck day end training day',
#  'training good learn multiple technique development',
#  'training good time allocated project management tool working tool',
#  'training good give good overview project management learnt lot information trainer excellent gob',
#  'good detailed',
#  'excellent paced explained suitable example great session certified pmp',
#  'training good helpful krishna helped solve doubt training provided tilling application relay applicable',
#  'day pmp training valuable topic explained example help understand concept',
#  'training good covered aspect depth',
#  'valuable effective good insight tool technique',
#  'interactive training mr krishna helped understanding concept easy remember',
#  'good',
#  'ram capability skill good stacking point trainer',
#  'training word learn fun excellent example',
#  'content good faculty god delivered thing practical manner',
#  'training good topic explained',
#  'good training excellent communication engaging audiance',
#  'training delivered good understanding subject',
#  'training session good informative enhancing skill knowledge professional career',
#  'good informative good example explain concept',
#  'training add explained enhance device skill motivate perform practice organization day day basis service delivery',
#  'training content subjective easy understand learn thing haired industry fantastic sir delivered point',
#  'needed training provided mr ram tavva effort put teach time ahead future training',
#  'received good knowledge handling improving work implement thing term concern',
#  'training made simple easy understand made practical approach faculty made engaging beautiful example',
#  'training clear concise good amount depth term topic coverage find job effectively find ram friendly knowledgeable',
#  'practical fun learning example make excellent',
#  'organised content relevant current project',
#  'good session informative effective',
#  'excellent workshop relevant super feedback mechanism view recording',
#  'training interactive live example made process understand material good',
#  'completed pmp training great session good experience',
#  'training good',
#  'excellent good delivered',
#  'good training experience',
#  'excellent training good',
#  'excellent training session special krishna',
#  'interactive engaging training',
#  'training helpful understanding concept pmp class room training krishna gave insight concept prepare exam',
#  'training provided helpful effective reliable interactive session',
#  'valuable effective good insight tool technique',
#  'material apt prepare pmp certification knowledge perspective trainer patient highly knowledgeable interactive interested',
#  'excellent easy understand mr krishna understand module simple precise example understanding thanking sir',
#  'pmp training krishna served gaining concept delivered clear resource matched excellence informative',
#  'pmp training good krishna sir',
#  'good knowledge sharing pmp content',
#  'training day nice training people krishna great trainer enjoyed session learning',
#  'good training covering aspect project management',
#  'nice learning thing training good',
#  'training structured krishna sir explained good example',
#  'training structured',
#  'class room training conducted professionally enjoyable provided insight concept approach exam preparation',
#  'pmp class room training impressed level dedication faculty krishna sir excellent method explaining concept interactive effective',
#  'experience good trainer provide lot example lot understand',
#  'good knowledge interactive session',
#  'good training example provided session helped lot',
#  'good preparation guide preparation tip good explain practical example make effective',
#  'work shop informative real time knowledge example full computer course',
#  'covered process valid example satisfied',
#  'nicely conducted',
#  'excellent excellent instructor learning support great thing',
#  'krishna explained topic clarity live example helpful teaching small doubt involved application process',
#  'content',
#  'pmp training satisfactory knowledge shared good example easy understand training good',
#  'interactive good training',
#  'good intensive training mr krishna supporting staff',
#  'training good',
#  'pmp training good relevant example',
#  'good highly interactive session easy understood explained relevant example trainer highly knowledgeable good exposure',
#  'organized learn pmp',
#  'managed helpful training session doubt clarified idea pmp',
#  'excellent training krishna',
#  'attended day pmp training conducted krishna great',
#  'training excellent good supporting staff great teaching',
#  'day training program good covered process learned forward study fir certification',
#  'good training request scenario evm contract type procurement management',
#  'good real time example easy relate thing concept',
#  'good training trainer krishna interesting helpful',
#  'good',
#  'training effective directly motivating developing good service skill helping improving externally meet business requirement',
#  'training good excellent learned thing process value organization business',
#  'training great',
#  'excellent faculty train ultimate presentation training good',
#  'training informative interactively',
#  'excellent training itil good example',
#  'great helpfull',
#  'good knowledgable',
#  'good provided ram tavva',
#  'good knowledgeable learnt thing',
#  'learnt thing whish future trainer excelent interesting training',
#  'great nice trainer',
#  'training intractive make thing easy understand give example related current life training',
#  'training effective directly motivating developing good service skill helping improving externally meet business requirement',
#  'good training',
#  'm training excelr depth subject trainer complete knowledge profesinal experience',
#  'relevant job',
#  'training fine content duration made extended day hard copy study material regular',
#  'novice user m confidently basic real time practice confident tool training structured faculty highly experienced real time industrial knowledge help depth understanding',
#  'great trainer explained doubt ready open discussion',
#  'excellent coverage topic good example',
#  'good effective',
#  'great material concept explained helpful',
#  'good training session',
#  'worth spending boost confidence concept day day example',
#  'excellent training krishna made interesting simple practical example',
#  'good content dry krishna made interactive session gain required knowledge',
#  'interactive specially faculty mr krishna experienced make subject easy giving real life example',
#  'excellent trainer helped upto understandthings simply',
#  'simply excellent',
#  'excellent training institute faculty krishna sir wonderful training lekshmi coordinating training',
#  'good paced training cover required content',
#  'interactive session doubt query cleared trainer',
#  'eas pmp preparation daily busy schedule direction achieve goal trainer guidance valuable',
#  'training conducted pmp easy understand approach excellent',
#  'training helpful detail',
#  'planned paced good training',
#  'krishna good explaining complete pmp content content excellent carry good understanding relate real time scenario',
#  'perfect exceeded expectation',
#  'good understanding provided clear concept',
#  'good helped proper arrangement year experience sequencial manner',
#  'structured organized delivered understand key concept good example helped connect topic real life',
#  'excellent effective',
#  'good environment taking cruck pmp examination attempt krishna sir review manner knowledgeble',
#  'content explained requirement pmp professional method technique explained',
#  'experience good',
#  'excelr standard approach training student excelr support help till crack exam training excellent standardised straight apporach',
#  'good insight project management good direction',
#  'good training day weekend topic covered logical order facility provided good',
#  'resourceful sevion',
#  'happy direct class online video pause cut shortened',
#  'training good good example',
#  'training awesome mr krishna',
#  'good knowledge transfes process',
#  'training excellent training gave attention detail knowledge area',
#  'training excellent connecting real time example',
#  'training program satisfactory instructor covered session time frame good example',
#  'excellent delivery technique trainer clarification real time example',
#  'understand project management concept met expectation attending training',
#  'amazing presentation skill pace lowered',
#  'awesome',
#  'content organized trainer experienced feel experience content delivering professional faculty support staff good starting point pmp journey',
#  'good knowledge point wise explanation clear help start preparation effective approach delivering',
#  'training good faculty good facility session online short exam great',
#  'good informative',
#  'good informative',
#  'training program good detail insight subject',
#  'trainer mr krishna versed pmp concept session cited day day life example made session interesting learning cakewalk great learning experience',
#  'training good expected',
#  'enhance project management knowledge pmp material simple easy understand',
#  'nice experience informative training',
#  'excellent content cover basic statistical term data analysis newer perspective analyse data formation enhance product development efficiency',
#  'training found verygood analyzing data good',
#  'topic covered interesting made tailored customer data',
#  'content involved fundamental advancement data analysis worth attend',
#  'training good covered relevant topic',
#  'attended day pmi acp training session excelr trainer ram tavva trained excellent knowledge subject',
#  'good shortened half day',
#  'training organized clear output agenda',
#  'training good clarification nice presentation',
#  'trainer ram tavva excellent knowledge subject teach good example understand',
#  'faculty ram tavva shared knowledge good polite clarified doubt excellent training presenting skill good finally good helped',
#  'explained related scenario manufacturing construcions good understandable',
#  'training interesting informative',
#  'training good explained example interesting bored good session',
#  'faculty aware concept patient listen query answer',
#  'training dont agile methodology completing good agile methodology',
#  'content good faculty pretty aware concept concept patient listen answer query good implement work',
#  'training satisfied interactive person understands concept trainer gave excitement learn understand',
#  'training provided faculty good gave knowledge agile base fresher helpful understandable training',
#  'planning project advantage',
#  'teached nice live example',
#  'training good superb good explanation',
#  'fresher good knowledge agile',
#  'good coverage examination syllabus',
#  'good interactive training session organized planned teaching effective good technique teach theoretical course',
#  'good content structured accommodating krishna sir good teaching technique',
#  'structured organized trainer understood student requirement explained concept easily grasp concept',
#  'training content delivery good krishna explained process good example help grasp concept',
#  'training provided krishna excellent',
#  'training effective preuse valuable core happy trainer method training',
#  'wonderful training trainer gave process example part exam explain detail krishna sir extrordinary pmp training',
#  'training good trainer mr krishna topic covered confidence clear certification',
#  'training informative live example concept',
#  'training provided upto mark',
#  'training informative helpful organised structured',
#  'training interactive structured explained aspect detail',
#  'training informative linked real example',
#  'training satisfactory',
#  'great experience excelr trainer mr krishna explanation example doubt clearance',
#  'excellent training delivery professional delivery material content chosen part explanation apt',
#  'good good introduction complete guide pmp',
#  'good learning experience',
#  'exellent training provided krishna excelr team',
#  'training met objective instructor communicated relevant example',
#  'structured training krishna knowledgeable class lively',
#  'good breakthrough subject matter krishna sir patiently clarity subject matter motivated certification',
#  'nice training attended explores knowledge area project management',
#  'good training conducted advised exam preparation',
#  'session good interaction example material provided good covering required detail information',
#  'awesome comment excellence',
#  'training effective subject deep full theory trainer session attentive break thoughtfully',
#  'excellent coaching example helpful understand heartfelt mr krishna excelr team',
#  'paced structured training covered area trainer krishnam raj sir good command topic',
#  'excellent training student friendly trainer',
#  'training good paced helpful',
#  'training made realize easiest preparing method example clarity provided simple language highlight trainer giving simple example made easy',
#  'interesting motivating trainer convince',
#  'good detailed training practical example chapter related properly explained logic',
#  'training delivered good example easier connect subject',
#  'good interactive session',
#  'interactive content good instructor explain continuous video trainer excellent',
#  'excellent training real world scenario empowered recommended tool skill interactive time management excellent enjoyed',
#  'training interactive intense gained lot knowledge agile principle hoping attend pmp training future',
#  'trainer knowledge peomising good communication skill depth knowledge concept material',
#  'good learnt lot ram helpful understand training completely',
#  'conducted concept made clear end felt topic slightly rushed',
#  'training excellent confidence passing exam',
#  'training serf complete expectation trainer experienced help understand concept ease good duration distributed day assessment',
#  'good training session emphasizing basic guidewire concept workflow',
#  'material covered important concept guidewire trainer explained expected stipulated time trainer cleared basic concept great learning time',
#  'training setting foundation guidewire',
#  'good informative clarity',
#  'good',
#  'good',
#  'helpful gain knowledge subjective day day work',
#  'articulated explained',
#  'good covered topic teach programming concept explained',
#  'satisfactory entire range topic discussed faculty good handling doubt improved making weekly assgnment compulsory',
#  'good place high pace slowered bit good knowledge faculty good',
#  'nowadays trending lecture good good teaching',
#  'training good classroom training help rest thing good faculty institute',
#  'good training provided trainer made learn complex technique ease made concept clear',
#  'good training provided apt explained mr dinesh',
#  'good explanation example informative terminology',
#  'excellent gained knowledge itil day trainer explained excellent easy understand',
#  'kind business managed structure',
#  'understandable session live reference incident helped understanding additional info itil foundation',
#  'informative',
#  'tranier giving example understand process concept',
#  'explained simple easy example',
#  'understd process service systematic manner',
#  'good interactive day day activity',
#  'session wasgood interesting young support engineer knowledge manage thing',
#  'conducted practical relevant example discussion',
#  'trainer professional exlained good content helpful daily activity',
#  'relevant people',
#  'informative',
#  'training live example made easy understand',
#  'good interactive trainer provided knowledge required',
#  'training good trainer gave live example make understand concept worth attending',
#  'good real wotld example session intensity informative',
#  'training good practical session grip subject',
#  'sir tremending set course influnce basic level high altitude understand fairly concept wise lm content online webinars help',
#  'quality training place learn data science material content nice relevant trainer good knowledge',
#  'good content huge additional class provide week gap working people concentrate question assistance subject huge',
#  'content support good spent theory application theory important data science scenario classroom example length classroom horizontal row',
#  'teaching excellent structural focus theory practical class great support material',
#  'designed concept faculty excellent coding part explanation nice time frame permit recommend friend',
#  'mentor good delivering subject understandable difficulty faced concept covered day apply concept data set solved mentor technique data set',
#  'good interactive session helped relate real time thing office environment',
#  'excellent tutor depth knowledge subjectand engaging training',
#  'excellent training gave good insight implement csi organization benefit implementation trainer highly experienced',
#  'training provided understanding cut life cycle bring improvement organization',
#  'interactive',
#  'satisfied training discipline',
#  'interactive knowledgeable faculty',
#  'pmp training simple effective interactive',
#  'training effective prepare final exam pmp',
#  'concept explained trainer excellent operative great experience',
#  'krishnam raj sir good knowledge pmp love teach partical',
#  'matured approach trainer student friendly methodology handled training',
#  'class informative interactive',
#  'good covered required topic good planned manner',
#  'excellent mr krishnam raj explained area simple good understood concept easily',
#  'training god gave good knowledge project management practice',
#  'training good',
#  'good explained properly',
#  'pmp training explained real time scenario',
#  'excellent training appreciates session arranged',
#  'excellent training trainer krishna relate real world example knowledge area comfortable understanding face rita mulcay material promised part quality material good',
#  'good feel time good',
#  'training pmp process group knowledge area layman understandable krishnam raj knowledgable person explained realistic example',
#  'good training helpful',
#  'training informative thought short time confidence clarity face exam high',
#  'trainer wonderful provided example withlayman team covered ka effectively',
#  'good instructor required input',
#  'training example explained',
#  'good initial start strongly recommend classroom training session',
#  'training good helped understand ka',
#  'interactive training session efficiently conducted',
#  'searching good institute month completing pmp excelr felt search worth krishna indepth knowledge topic pmp covered process thouroughly helped understand',
#  'experience learning',
#  'training delivered exceeds expectation',
#  'mr krishna experience trainer provided good training pmp',
#  'professional approach conducted classroom session',
#  'good clarity example krishnam raj sme pmp clear picture subject',
#  'training good lot real time example working problem exam increase confidence face exam',
#  'content fruitful explaining concept good',
#  'clarified weak point confusion process knowledge area',
#  'excellent training trainer explained example',
#  'facilitator knowledgeable warm person reachable good hold subject',
#  'information provided explained trainer excellent easy remember attempt pmp certification',
#  'training krishna gave great insight subject interactive',
#  'flow method engaging learning excellent',
#  'training conducted structured manner pmp guru krishnam raj',
#  'training good detailed helped understand pmp daily job activity great work',
#  'good experience awesome training',
#  'enjoyedthe great insight practical example',
#  'good content coverage good insight pmp process coupled subject knowledge trainer mr krishnam raj',
#  'structured shared needed clear certification',
#  'excellent good case study',
#  'good interactive session touched industry example ka',
#  'good suggestion add numerical practice question session',
#  'training helpful',
#  'slow pace time managed',
#  'good training material trainer behaviour training room infra long sitting',
#  'good session profession instructor mr krishnam raj tremendous experience',
#  'training good help understand subject great session',
#  'total process linked generalised project',
#  'good pmp training',
#  'excellent training session krishna made interactive recommend institute certified',
#  'training motivating trainer good experience subject',
#  'good paced training cover required content',
#  'planned knowledge area define good manner',
#  'good training explained relevant topic',
#  'good training krishna sir delivers content nice understand interactive session',
#  'satisfactory',
#  'informative interesting',
#  'good understanding pmp detail',
#  'helpful clear certification april',
#  'excellent training happy learning krishna exceptional trainer great delivery skill',
#  'training pmp good understanding understand concept krishna explained help explore highly recommended',
#  'training helpful understand pmp concept trainer mr krishna good making concept clear advised thing clear exam road map',
#  'pmp training helped understanding concept forward support exam preparation',
#  'extremely effective easy understanding day day example duration increased day order information assimilated',
#  'awesome experience entire delivered fashion entire concept molested effectively',
#  'detail study interactive',
#  'excellent training trainer krishnamraj ambiance good',
#  'training quality topic coverage good trainer knowledgeable make learning easier planed managed delivered',
#  'facility faculty ad equation class room training good effect learning krishna fulfilled commitment',
#  'training trainer broke tough concept simple english mr krishna give lot sample ensured al understand subject interactive clear training imparted',
#  'good training facility great',
#  'training concept needed depth clarification study demostration example discussion',
#  'trainer vast knowledge domain agenda structure training improved insisted bit basic swagger generation endpoint testing unit testing actual microservice future training recommend resource git repository day branch starting branch day code branch branch day insist microservice design pattern architecture break monolith app microservices',
#  'help understand basic infra service service offer help understand microservices architecture service communicate understood swagger mean swagger specification file generated help learnt thing technology eureka zuul kibana role work',
#  'good experience lm detail shared late good',
#  'provided professional quoting real world example trainer ram kind patience handle query',
#  'interactive hearing skill anoopp',
#  'interesting',
#  'excellent training explanation topic nice',
#  'training great informative interactive',
#  'good interesting easy follow',
#  'content relevant presenting good time sufficient cover area',
#  'good training wonderful training itil',
#  'small suggestion link example discussing mock test exam increase candidate confidence',
#  'training good faculty explaining concept good',
#  'trainer good',
#  'good gained knowledge agile concept',
#  'require practice session class room training',
#  'good end kindly provide lot material posting regularly drive',
#  'training rated average scenario based example improve time spent topic planned focus unique functionality tabluea helpful',
#  'designed covered designed expectation basically expectation tableau excel software',
#  'thankyou excelr providing interactive session sincerely krishna sir dedication student patient training',
#  'faculty good teaching nice',
#  'industry related made easy understand',
#  'impressive training good',
#  'real refresher pmp exam preparation',
#  'good overview example helped session short test quiz',
#  'excellent training recommend people suggestion example provide shortcut technique remember critical concept',
#  'mr yogesh good teacher attention detail attention student pluspoint good example topic provided good recap good suggestion people background qualification cooling difficult hard understand make simple teaching',
#  'arrangement good material',
#  'excellent',
#  'training excellent',
#  'training phased day',
#  'helpful understanding pmp looked gave direction certification concept project management',
#  'good training covering basic pmp trainer cooperative good knowledge skill',
#  'brilliant training coordination quality training excellent customer service',
#  'extremely helpful understand project management quality content excellent nice balance theory practice',
#  'good trainer training material good understand trainer good knowledge subject',
#  'great experience training faculty touch based complex topic simple day day make pmp simple easy digest highly recommend strongly stand contribution',
#  'training good trainer good clear concept excelr team helpful video provide reading material multiple type question preparation',
#  'educational training institute good trainer highly recommend training institute',
#  'good',
#  'training instructive helpful understand concept rmp trainer explained providing good example understand',
#  'training good provide material excelr material great chapter exercise practice',
#  'excelr solution good option choose seek assistance certification online pmp training great covered topic real life example project management online training video simulation question helpful reviewed couple time conveniently excelr team proving dynamic environment pmp credential',
#  'good training trainer provided good relevant example understand concept made class interesting interactive',
#  'good recommended writing pmp exam',
#  'training good',
#  'training methodical concept explanation clear example easy understanding',
#  'training good concept explained example understand trainer full',
#  'good perfect kickstart novice',
#  'good training way good making concept clear example outstanding',
#  'excellent example provided made understand tough concept easy example',
#  'concise elaborate lm good',
#  'good',
#  'excellent training good work',
#  'training good informative good example provided training relate itil scenario',
#  'training material good facility training institute good trainer punctual session interactive example',
#  'excellent detailed explanation project management concept trainer interactive session good training material provided excelr recommend excelr pmp training',
#  'fruitful krishna provide real time example helped understanding concept easily',
#  'training good example quoted easy understand pace training comfortable',
#  'training good recommend questionnaire session conducted end knowledge area effective',
#  'excellent clarity knowledge itil concept',
#  'bharani excellent trainer kind institute student training institute excelr',
#  'session tableau explained contact bharani srinivas sir doubt',
#  'excellent training lot hand excercise good live project exposure',
#  'training effective worth spending money covered maximum topic concept explained beautifully trainer',
#  'training extremely good doubt great money bharani knowledge level data science top notch advantage excer trainer people worked ba industry managing consulting project world class customer business analytics greatly help student industry perspective data science domain practical issue excel student case study happy wonderful experience surely recommend dr shajahan phd',
#  'syllabus training structured company hire participant complete project trainer expert teaching awesome recommend',
#  'good learned thing career tool technique area',
#  'training phased day trainer friendly knowledgeable interactive training environment good professional training confidence level pmp exam taking increased attending training',
#  'training excellent session conducted effective interactive training',
#  'coverage organized valuable addition skill set skill high career arrangement good material step explain concept real time example',
#  'worthy highly interactive lot giving direction guidance order fill application future endevours suggest friend join classroom program join',
#  'good training trainer good knowledge topic answer question raised attendee pretty satisfied',
#  'conducted timeline focused important topic important material shared good demonstration example',
#  'structure content good question answer session knowledge area sample question mock exam give flavor question',
#  'good training',
#  'training excellent provided insight knowledge pmp certification',
#  'great coverage value concept tool essential aspiring data scientist atmost concern student fullfill dream data scientist',
#  'pleased inform training attended trainer amazing job covered relevant topic structured session planned trainer set relevant example real life situation clear concept enjoyed session',
#  'training good learn lot statistic data analyticals',
#  'excellent trainer experienced communicate clarification effectively',
#  'good faculty material support time',
#  'training awesome idea pmp delivered mr anoop',
#  'anoop good trainer excellent interactive session entire day expertize explaining concept impress training lot anoop',
#  'training good mr bharani explained statistical concept simplest session design good learn concept half practicals half day help gain confidence learnt recorded training session helping revise understanding',
#  'excellent intuitive educational excelr faculty explains concept business analytics progressively starting foundational level advanced concept informs participant challenge enjoyed part program learnt lot thing practice',
#  'good training provided systematic honestly excellent institute excelr',
#  'training great faculty excellent training institute learning visualization analytics thing focus preparing student interview industry standard expectation learn',
#  'training interesting learned lot mr anoop mr kaleem organizing helpful energetic staff training purely interactive session good thing observed',
#  'sheer pleasure part business analytics offered excel entire curriculum training session assignment made hand subject live project session constant support entire staff highly commendable special mention trainer bharani kumar professional oodles experience steered class excellently addition explaining concept motivated constantly giving insight kind opportunity domain extremely rewarding experience',
#  'excellent mentor good knowledge subject training friendly comfortable manner',
#  'training career recommended friend started training worth investing',
#  'exhaustive content excellent methodology training recommend excelr peer',
#  'good enjoyed training',
#  'good session interactive helpful',
#  'impressive training student trainer interaction level good',
#  'ram tavva provided wonderful pmp session suitable example',
#  'good training relivable example',
#  'composed cover subject good understanding level',
#  'good training content good trainer good training classroom environment excellent supporting staff',
#  'good learning trainer expertise',
#  'training good required information field pmp exam purpose good presentation',
#  'good knowledge subject happy part exercise effective',
#  'dozen program variety field impressed technical knowledge translated usability field outstanding combination technical knowledge application market reference material comprehensive excellent mean conveying information superior approach handled professional manner',
#  'good resourceful',
#  'training good krishna patient answering query relates example real life experience help remembering concept',
#  'training good trainer krishnamraj clarified thing neatly enjoyed session',
#  'informative educative relate real working standard project practice found helpful excel',
#  'good training fast slow',
#  'training session informative expert trainer trainer mr ram interactive good example',
#  'explained detailed process group knowledge area base line plan requirement management plan process improvement plan change management plan configuration management plan multiple example task presentation video recording great guided mr ram tawa prepare crack pmp exam easily knowledgeable high capability teaching',
#  'trainer good knowledgeable clear concept structure training good',
#  'training effective gave complete knowledge',
#  'good training krishna',
#  'nice infromative training satisfied',
#  'gained knowledge project management interactive session',
#  'good presentation area easy understand knowledgeable interaction trainer trainee',
#  'structured elaborated interactive man show',
#  'excellemt',
#  'good',
#  'trainie knowledge great interaction good happy',
#  'manikandan deep dive concept bringing clarity itil principle process excellent communication interactive session ram tavva excellent presentation case study vertical highly interactive session example guidance knowledge sharing good apprecaited',
#  'training excellent trainer knowledge interaction participant communication skill connecting participant great',
#  'good training approach session approach topic methodical made logical sense',
#  'excellent interactive session',
#  'training good info ready pmp exam interactive clear exam',
#  'good trainer explained thing good proper example',
#  'training krishnamraj excellent learned thing learned year project management experience',
#  'training conducted krishnamraj good practical example made interesting interactive session',
#  'great attend pmp training excelr trainer good clear understanding topic topic covered depth doubt cleared trainer',
#  'content example training aid delivery good',
#  'training confident leap project manager coming day training insightful offer depth knowledge project management',
#  'helped gain confidence taking pmp exam clear book provided help',
#  'effective clear',
#  'good learn excellar material good understood concept attending class',
#  'good break point enter ba',
#  'good insight business analytics tableau trainer knowledge business analytics fabulous example provided module good hand subject felt good taking choice selecting excelr training',
#  'knowledge trainer excellent teaching good example good',
#  'training session systematically structured helped understand concept pmp ease scenario aspect managing project answer provided trainer multiple query enabled insight phase project life cycle related topic',
#  'pmp training simply superb explain concept good',
#  'excelr training good training institute bangalore lot support providing good training pmp material',
#  'training good good example scenario',
#  'good',
#  'interactive lot example wud recommend krishna sir good depth mgmt',
#  'learn alot trainer sound knowledge process method shared lot real time example',
#  'trainer good explain good thing',
#  'training provided good insight topic example real time easy understand fast effective',
#  'trainer experienced explained real time example easy understanding subject input deal project effectively working organization training good',
#  'training part good trainer excellent knowledge part',
#  'training good topic taught effective trainer knowledge level high',
#  'training improved lot exercise class',
#  'excellent session',
#  'interactive',
#  'good informative',
#  'structured wholistic paced training insight industry example awesome fantastic training experience',
#  'helpful provided insite certified',
#  'good',
#  'flow training explanation example good feel day sufficient trainer cover topic detail',
#  'training good eazily understandable',
#  'training good krishna gave good example understand topic',
#  'training helped enhance skill',
#  'good session lot good addition',
#  'excellent',
#  'good',
#  'good coverage',
#  'good',
#  'excellent planned',
#  'awesome training session interactive informative acquire lot knowledge',
#  'intractive session cover topic',
#  'informartive',
#  'excellent training forward exam helpful trainer',
#  'good knowledge shown trainer helped clear doubt solve problem engaging training trainer involving discussion',
#  'training good capturing concept helped simplifying process',
#  'training good trainer descriptive explained example',
#  'training provided pmp good delivered concept easy example knowledge area excellent',
#  'trainer mr krishnam raj helpful knowledgeable guiding highly recommend mr krishanam raj participant great insight practical experience live project shared helpful empowers participant gain confidence',
#  'training good supportive trainer trainer take personal interest clarify doubt',
#  'training good helped understand concept apt example trainer provider',
#  'example provided understand concept good',
#  'good facilitation relaxed pace training',
#  'real time example training helped understanding subject',
#  'trainer good interactive session discussed scenario example',
#  'trainer creates good environment good active session',
#  'good faculty live example',
#  'skillogic arranged trainer good coacher effective interactive session example diagram chart enjoyable',
#  'time online training great difference classroom training online trainer clear explaining topic actively interacted ensured student understood topic proceeding',
#  'rate session passion interest educating continue good work',
#  'good made concept interesting understand logically related real time scenario',
#  'good',
#  'trainer informative methodical elaborative listened query answer data clarify',
#  'training broader perspective enhancing career entire excelr team help resolving career oriented student critical interrogation boost moral ensures student hit bull eye support shown excelr team',
#  'training good informative trainer good knowledge good teaching skill',
#  'training full learn lot thing training section providing',
#  'training good exercise',
#  'providing program agile methodology worthwhile seminar learned thing knowledge instructor excellent example ebreez providing training program',
#  'give training session found interesting incredibly motivated change approach work honestly putting tip tool practice made feel confident helped feedback work lead',
#  'good',
#  'gave good explanation scrum gave real time example understand term scrum gave explanation real time example easy understand',
#  'training good learned lot training session agile session valuable session',
#  'granular informative training helpful adaption agile process improvement',
#  'training good point explained extremely satisfied training',
#  'good training live knowledgeable trainer',
#  'excellent',
#  'elaborated detailed example',
#  'training great trainer interactive good',
#  'precise felt time spent discussing question knowledge area',
#  'training good classroom training option mysore bangalore training good example shared class trainer easy understanding topic',
#  'training provide krishnamraj good lot thing learnt chapter covered success examination depend individual hardwork time spent learning preparation',
#  'worth penny krishnamraj great instructor accomplished professional vast experience project management area teach pmi principle brings real life example class intense week great experience enjoyable class strongly recommended exam tip superb passing exam totally individual hard work',
#  'venue facility internet table space instructior krishna good communicate change venue place',
#  'training good material provided end life cycle scenario provided',
#  'trainer good infrastructure requires considerable improvement',
#  'ram explaining concept example relate participant shared thought interactive session interesting refreshing forward course itil intermediate sudha follow time confirmed presence',
#  'great content example provided clarity misconception kumar patient answering question easy stupid wanted practice concept practical problem presented kumar session exciting',
#  'nice attend training explanation topic understandable life examplaes',
#  'project management technique conveyed class simplistic easily understood methodology approach good',
#  'good training trainer explain concept adequate break personal disturbance',
#  'training pmp pretty good content summarized main aspect content charted trainer knowledgeable insight phase knowledge area adequate example feel confident knowledge gained write pmp examination',
#  'short sweet',
#  'provided broad understanding area project initiated entire process',
#  'happy pmp training',
#  'training excellent trainer good knowledge subject cited relevant example good training program',
#  'training topic explained',
#  'good attend trainer explained easiest teaching enjoyed classroom training',
#  'training good engaging',
#  'training good time constraint detail learning material',
#  'training good',
#  'training good fact statistical area boring trainer session good training enjoyable time informative',
#  'organised day training good trainer',
#  'training content good time spent topic moderate happy confirm training fulfilled prepared pmp credential',
#  'training good real time daily life example require support till complete certification',
#  'great full taking exam',
#  'learned concept planning group knowledge area process',
#  'training satisfactory providing required information wrt pmp process concept trainer knowledgeable experienced make understand difficult concept required exam good work standard',
#  'excellent',
#  'help understand knowledge concept pmp excelr',
#  'good productive update training material font colour properly',
#  'worth helpful plan pmp certification',
#  'excellent clear understanding',
#  'good informative',
#  'great gained wonderful knowledge needed pmp preparation krishna',
#  'training good informative good example recommend question answer topic',
#  'good time detailed explainatory',
#  'great session informative give credit trainer dry subject trainer created interest',
#  'training excellent teacher training fun educative experience',
#  'great training session mr ram',
#  'good interesting explanation nice appreciated',
#  'good organized trainer knowledgeable real time example help understand concept',
#  'training session helpful cover syllabus relevant example provided understand remember important concept',
#  'structured heart process name class idea technic shared support guranteed money time',
#  'training good case study',
#  'practical example case study pace project management backgroud',
#  'nice experience interactive session',
#  'excellent trainer',
#  'excellent trainer loved experience itil training trainer watched loved easily effectively connects real life example process awesome genius trainer',
#  'day session involving knowledgeable pursued master business administration fair knowledge content itil foundation ram delivered lecture efficiently novice learner gained understanding concept interactive involving subject ram',
#  'excellent trainer explained topic real time made active class teaching style',
#  'good informative',
#  'excellent presentation mentoring',
#  'excellent training conducted interactive session relative situation understand process service operation',
#  '',
#  'awesome term explanation refreshing project management experience excelr',
#  'good',
#  'training explained live day day example good session attend',
#  'satisfied training',
#  'explained real time example made good path understand concept pmp',
#  'trainer good command topic structured',
#  'classroom training good trainer explain process ten knowledge area effectively answer question',
#  'informative interactive',
#  'relevant topic pmp covered fully extent',
#  'training excellent specially trainer covered important topic pmbok easy understand',
#  'trained mr ram tavva expereince tarining good expereince example collectable align life trainer',
#  'excellent',
#  'good interactive session knowledge experience skill make thing understand example run program train trainer',
#  'good delivery commitment engagement',
#  'good understand process area technique remember',
#  'good term practical example',
#  'training good',
#  'helpful give insight tool technique project management',
#  'trainer depth industry experience pmp process knowledge area adequate real world easy understand example committed student till pas pmp exam',
#  'good helpful understanding core publication read',
#  'training good correlate subject current activity',
#  'great session topic knowledge area explained real time example kumar sir patient answered query motivated practice question gave detail plan study topic wise',
#  'good training',
#  'good live example made understanding level easy',
#  'good',
#  'trainng good example knowledge area helped understand perceive content pmbok guide initially confusing good recommend special entire excelr team',
#  'pmp training ram tavva excellent made dry subject interesting giving lively example time explaining important concept made clear pmp exam training attended love recommend training institute sofia project manager tata consultancy service',
#  'training worth interactive session helped gain confidence taking exam',
#  'good effective',
#  'excellent understand tool technique easy',
#  'training good organised',
# ...
#  'give example topic',
#  'good extent good improve depth knowledge',
#  'good',
#  'detailed good',
#  'knowledge',
#  'pmp topic webinar slide',
#  'friendly staff',
#  'attention person team',
#  'explanation topic good',
#  'training help improve management skill',
#  'excellent informative bored day full day session tutor murali managed teaching pmp content teaching skill example real experience murali class room good chair iron good full day seating class recommend change chair cushion soft seat raju',
#  'trainer good krishnaraj present subject query handling ability bikram ordinator skillogic late back followup time invoice hv recieved support',
#  'till good',
#  'good',
#  'online training training good instructor',
#  'training helped understanding project management concept tool technique help certification',
#  'pmp training good presentation skill scenario provided helpful understand real content',
#  '',
#  'good training project management concept',
#  'good big example big business value rita exam prep licensed version center great helpful',
#  'training good',
#  'good good practical example hand experience trainier whatsapp group overview test improvement mock test covered topic',
#  'training good helped understanding concept underlying pmp training helpful reading preparing pmp certification',
#  'good interactive session trainer good practical knowledge explained real life example',
#  'good coverage topic',
#  'good unique point observed day training touch whats group reach trainer require attend online session training forget reach trainer',
#  'content good covered topic helped setting base good',
#  'good example nicely presented instructor superb',
#  'good training',
#  'training good lot learning training',
#  'trainer good extended day day',
#  'training informative good',
#  'interactive training session correlation day day life example make easier layman',
#  'training informative paced practice exam training',
#  'pmp informative good',
#  'planned training feel complete insight area covered pimbok hope pmp exam easily training',
#  'nice learning experience trainer mr raj knowledgeable',
#  'training good real time example',
#  'training good explanation nice good example',
#  'good example good relavant example helped risk management covered depth',
#  'training session informative helped lot learning basic project management',
#  'excellent experience krishnam trainer knowledgeable structured approach example specifically relatable simple enabled understand remember key area small class size ensured undivided attention tailored approach comprehensive training study material provided helpful',
#  'training organized trainer presented effectively made easy understand training session effective',
#  'excellent',
#  'nice interactive people explaning real time example',
#  'nice teaching explaning real time example',
#  'program understand concept doubt nice example provided connect concept',
#  'good indepth training data science knowledgeable trainer',
#  'business analytics sharat excellent training attended related data science concept real time business scenario participant understand quickly dedicated committed exceptional knowledge domain helped engage participant month',
#  'good issue',
#  'training excellent relevant',
#  'flow information good relevant subject elaborated time constraint',
#  'agile explained text case study sale pitch implement agile mentally',
#  'great experience understand technicabilites agile development methodlogies certified',
#  'interactive informative',
#  'nice workshop',
#  'focused product biz owner good',
#  'amazing knowledge sharing session thought session trainer provided detailed level topic workshop',
#  'training good alot information provided divided day',
#  'interesting learn lot detail',
#  'good',
#  'comprehensive introduction agile concept interesting',
#  'excellent training trainer good explaining concept',
#  'good training prefered case',
#  'conducted relevant subject area appilcability line area work',
#  'attended service design training itil intermediate good trainer knowledgeable answered question',
#  'training effective',
#  'insightful good training',
#  'good learning experience',
#  'training good concept explained scenario based apply project management',
#  'good training sir taught tableau',
#  'training good flexibility provided good portability mode teaching lm live online assignment post noon weekend',
#  'good felt topic explained differently trainesr bharani explained aspect nitin explain bharani explained qq plot compared nitin nitin explained matrix compared bharani example complaint observation understand attended sense difference respect knowledgable',
#  'trainer bharani sir knowledge patience training commendable feel trainer [ mark observation wrong excelr organisation recommend institute improvement area suggest trainer changed lose momentum option selecting based bharani sir training',
#  'exhaustive training real time example',
#  '',
#  'close interaction support material',
#  'example trainer',
#  'interactive session',
#  'material realtime example',
#  'concept knowledge gained training implement professional personal life',
#  'taught topic taking example',
#  'trainer good',
#  'learning',
#  'organized agenda',
#  'interactive',
#  'relevent real time scenario',
#  'knowledge experience trainer',
#  'workshop oriented assignment',
#  'webinars good',
#  'interactive friendly tutor',
#  'explanation good',
#  'training good improved study material quality',
#  'excellent time constraint solving mock test',
#  'great session patience explaining answering question good phase interesing',
#  'nice book updated latest training slide practical scenario',
#  'training good trainer interaction helpful',
#  'good training',
#  'good content hard copy material provided comprehensive trainer good explaining real life example metric estimation technique explained',
#  'training good informative',
#  'good training satisfied training',
#  'good training plan trainer clear putting concept crisp',
#  'training learnt easy methodology applying process routine business work',
#  'good trainer handle crowd professionaly easily approachable clarify doubt quoted live example online helped understand concept easily',
#  'good interactive session good',
#  'trainer knowledgeable good experience evolved method train tough part subject completed training doubt',
#  'good',
#  'good informative interactive',
#  'training session',
#  'agile training full clear methodology team work plan implement thing complete timeline type training improve',
#  'training helpful understanding concept',
#  'training informative helpful example related retail hr scenario helped associate field relate work field training rated good',
#  'training good',
#  'pmp framework articulated ram connect concept process tool technique explained job area good practical example fairly systematic approach covering topic',
#  'interactive knowledgeable directive',
#  'training intensive helpful understand knowledge area process',
#  'training good',
#  'engaging trainer attentive',
#  'trainer good explained good example made easy understand input provided good',
#  'training helpful daily business learnt expected term process trainer excellent group active',
#  'great experience good trainer',
#  'training wa good gain good understanding subject',
#  'practical addressed matured',
#  'good place learn information market',
#  'excelr place excellent quality training',
#  'analytics training interactive nicely explained',
#  'super training excellent work recommend excelr',
#  'excellent training experienced faculty curriculum good',
#  'excellent institute trainer traning process excellent trainer',
#  'trainer skilled expert term training practical experience provide awesome good adviser helped term professional career personally recommend people join excelr solution data science programme',
#  'great learning experience helpful completion',
#  'training good staff knowledgeable',
#  'good coaching manual video learning house training good good coaching pmi acp trainer trained concept interaction trainer helpful',
#  'excelr solution nice place build data science career option',
#  'excelr data analytics excellent teaching free add session confidence ahead chosen field',
#  'excelr training data science reasonable price timing suitable working professional hand approach assignment give lot confidence',
#  'good learning experience excel teaching content good relevant practical example real time business scenario data science informative presented sharat sharat wonderful session',
#  'good traini ng personal attention',
#  'excellent training happy learning krishna exceptional trainer grat delivery skill',
#  'efficient training good faculty good faculty knowledgeable great training time day',
#  'training program paced properly helpful understanding pmp concept faculty efficient delivering',
#  'training excellent trainer good knowledge subject cited relevant example good training program',
#  'trainer excellent training fun learning experience',
#  'training structured explains concept holistically quiz helped internalize knowledge',
#  'structured training ample knowledge transfer',
#  'fantastic explaining concept real time scenorious',
#  '',
#  'expert explanation',
#  'training excellent bit indepth',
#  'interactive',
#  'good indepth coverage topic',
#  'excellent training session',
#  'nice session attend happy completing',
#  'training good lm helpful session elaborative',
#  'trainer excellent explained concept vell',
#  'good learning bit fast',
#  'training good interactive happy',
#  'effective interactive session',
#  'training trainer good time short',
#  'effective interactive explanatory',
#  'good monry',
#  'time bit',
#  'program good practicals pace slow',
#  'training cover large amount topic time bit',
#  'good real life example',
#  'faculty great knowledge subject provided great real life example',
#  'good interactive trainer supportive give practical anecdote',
#  'good detailed real life example provided',
#  'good material awesome knowledge delivery good',
#  'ram gave real life example helped relate itil concept',
#  'interactive session gave lot realtime related example helped gained good knowledge st concept',
#  'interactive class',
#  'sharat cored making interesting comprehensive great attitude teaching',
#  'working professional kind material core main topic memorized thing simple definition advise training satisfied',
#  'training institute hyderabad professional facility',
#  'training good base study explain concept handed suggest week',
#  'training good recommended explore topic example',
#  'structured sequencing manner understanding good faculty good delivering content relevant example personally learnt lot confidence d implement',
#  'depth knowledge subject relevant example',
#  'planned clear communication good',
#  'training good faculty good parental skill learnt thing helpful qualify pmp exam',
#  'extensive material good training session',
#  'helpful interactive topic covered cocepts relevant example',
#  'ram good coach clear topic helped understanding principle basic acp recomend excelr course',
#  'good program',
#  'informative concept thought video displayed made understand',
#  'training informative kind training material knowledgeable trainer',
#  'good content knowledgeable instruction friendly approachable staff good place',
#  'training good cover important topic project management',
#  'training gain knowledge',
#  'designed good trainer explained cocept good amount example understand',
#  'training clear learning easy fun',
#  'training great',
#  'clear descriptive training subject',
#  'excellent training time',
#  'content good helpful trainer understandable',
#  'training good duration short',
#  'training content good',
#  'training conducted good manner understand',
#  'good organized',
#  'extra day',
#  'pace bit fast',
#  'day',
#  'training good duration',
#  'trainer made interesting ang gave creative example',
#  'ram nice interactive provided good example',
#  'content covered good session interactive',
#  'content explained precisely effective',
#  'fantastic training session ram knowledgable trainer ram excelr',
#  'trainer ram excellent interactive',
#  'ram amazing trainer thing interesting intriguing real life example understand',
#  'excellent interactive session conducted enjoyable manner productive learning experience',
#  'excellent training example helpful understand concept',
#  'trainer prepared indepth knowledge subject',
#  'structured interactive good knowledge subject',
#  'content structure career trainer excellent',
#  'fully descriptive training',
#  'excellent program',
#  'exellent',
#  'excellent lecture',
#  'great interactive training real life example effective understanding',
#  'session interesting interactive',
#  'programme excellent gained knowledge itil day day activity',
#  'informative aligned practical work exposure real life example made understanding easy',
#  'content structure help give service client',
#  'relevant day day work',
#  'content explained organized',
#  'module covered fully superb trainer explanation example clear',
#  'good time',
#  'good duration longer',
#  'explained',
#  'attractive',
#  'engaging interesting',
#  'gained knowledge subject',
#  'excellent',
#  'session participated chapter related itil covered short time vibrant',
#  'great training',
#  'good learning understandable',
#  'time',
#  'excellent training faculty immense knowledge subject manages',
#  'excellent delivery material exercise tip',
#  'training exhaustive detail informative concept explained example',
#  'training good knowledge trainer good',
#  'coach',
#  'krishna rich experience made learning session interactive interesting good mentor',
#  'classroom session engaging interesting ka covered adequately good learning experience',
#  'mentor knowledgable clarified doubt efficiently training distributed day adequate time spent important area improved understanding',
#  'pmp training good interactive faculty thought good example',
#  'good lm access mock test time dull interesting',
#  'training good precise trainer experienced professional facility training centre good good learning atmosphere',
#  'objective delivery clear help easily understand project management example helpful felt effective efficient session',
#  'prepared documented example',
#  'training good facilitator clear content explained common example made easier',
#  'good experience learning excelr',
#  'kiran demonstrated trait required session excellently',
#  'training interactive field people example explained training',
#  'excellent informative trainer interactive crowd pulling enjoyed encouragement boosted attending exam easy crack based training input',
#  'communication clear completing day good saturday managing st half saturday sunday fine infrastructure resource aligned',
#  'good presentation content covered understandable easy understand pmp program',
#  'great experience learning pmp trainer krishna real time scenario',
#  'good trainer clear understanding',
#  'good experience',
#  'training good set understanding basic itil',
#  'excellent training provided expert board excelr wonderful experience institute itil foundation real time scenario understanding itil',
#  'helpful add add day day work environment role',
#  'good lot knowledge understanding subject',
#  'good trainer dinesh helped understand good practical example quality training material solves purpose learnt lot training knowlege implement daily worth',
#  'information training properly provided',
#  'helpful content excellent',
#  'nice explanation clearing doubt giving real time example make concept visible',
#  'helpful interesting',
#  'helpful material good trainer friendly',
#  'training material classroom training excellent trainer efficiently explained topic',
#  'enriching learning experience satisfied content coaching style depth hold topic',
#  'clartity quality content delivered trainer yogesh iam happy time money inverted worth career level suggest allocate time practical lab senior',
#  'exhaustive attention detail paramount',
#  'good reached expectation gained confidence gap career maintaining whatsapp group good lm video clear',
#  'exhaustive attention detail paramount',
#  ...]

# %%
text=' '.join(X)
text
# Out:
# 'good productive training clear explanation require reading material good training understand basic boom feel confident certification work boom fool training intern project business requirement excellent case material senarios good training provided krishna sir excellent day training effective trainer played key role explained concept dept great teaching method example good pace bit fast training material missing content intro page great experience trainer professional effective speaker group data interactive session made success excellent planed relate real time example work explained real time example helped relate organized easy understand effective instructor gave real time example connect concept pmp training engaging concept explained example krishna structured training easy understand good online support valuable training krishna sir provided good example easily relates topic structured pm book easy understand training provided excellent key area covered clear explanation relevant example training good good training excellent experience cleared lot doubt training people pmp exam methodology training clear interactive excellent training mr krishna provided good example depth knowledge area process covered topic subject pm book good krishna sir job training pmp good clear example ka pg organised structured teaching method krishna sir interactive training full krishna sir effort individual student training good organized good develop skill set career growth structured program process effective trainer interactive knowledgeable area pmp training concise effective interactive planed coaching approach organized effective structured good real time example training good informative good training good duration extended add hand exercise kiran topic explained fundamental advanced method good good trainer food presentation skill training advanced python helped concert usage python help understand aspect machine learning good understanding data science machine learning concept good training science background ai concept arranged presented kiran good faculty content good summary start project data scioner machine learning coursed covered basic python half day subject good training informative presented training good excellent point start journey data science excellent training good knowledge good great explanation easy understand topic make happy nature make session interested nice faulty explained teach topic practical day day life finally entire session good training helpful guide teach business designed organize structure learning element learned point detailed manner content training excellent good teaching technique training good advanced expected topic elaborated beginner intermediate advanced topic lick service mesh deep dive monitoring ect good developing basic understanding kubernetes training good training good good hand kubernetes concept interactive great suggestion share presentation deck day end training day training good learn multiple technique development training good time allocated project management tool working tool training good give good overview project management learnt lot information trainer excellent gob good detailed excellent paced explained suitable example great session certified pmp training good helpful krishna helped solve doubt training provided tilling application relay applicable day pmp training valuable topic explained example help understand concept training good covered aspect depth valuable effective good insight tool technique interactive training mr krishna helped understanding concept easy remember good ram capability skill good stacking point trainer training word learn fun excellent example content good faculty god delivered thing practical manner training good topic explained good training excellent communication engaging audiance training delivered good understanding subject training session good informative enhancing skill knowledge professional career good informative good example  ...

# %%
# Import packages
import matplotlib.pyplot as plt
# %matplotlib inline
from wordcloud import WordCloud, STOPWORDS
# Define a function to plot word cloud
def plot_cloud(wordcloud):
    # Set figure size
    plt.figure(figsize=(40, 30))
    # Display image
    plt.imshow(wordcloud) 
    # No axis details
    plt.axis("off");

# %%
# Generate wordcloud
stop.append('will')
wordcloud = WordCloud(width = 3000, height = 2000, background_color='black', max_words=100,colormap='Set2',stopwords=stop).generate(text)
# Plot
plot_cloud(wordcloud)

# %%
##Part Of Speech Tagging
nlp = spacy.load("en_core_web_sm")
doc_block = nlp(text)
spacy.displacy.render(doc_block, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">good productive training clear explanation require reading material good training understand basic boom feel confident certification work boom fool training intern project business requirement excellent case material senarios good training provided krishna sir excellent day training effective trainer played key role explained concept dept great teaching method example good pace bit fast training material missing content intro page great experience trainer professional effective speaker group data interactive session made success excellent planed relate real time example work explained real time example helped relate organized easy understand effective instructor gave real time example connect concept pmp training engaging concept explained example krishna structured training easy understand good online support valuable training krishna sir provided good example easily relates topic structured pm book easy understand training provided excellent key area covered clear explanation relevant example training good good training excellent experience cleared lot doubt training people pmp exam methodology training clear interactive excellent training mr krishna provided good example depth knowledge area process covered topic subject pm book good krishna sir job training pmp good clear example ka pg organised structured teaching method krishna sir interactive training full krishna sir effort individual student training good organized good develop skill set career growth structured program process effective trainer interactive knowledgeable area pmp training concise effective interactive planed coaching approach organized effective structured good real time example training good informative good training good duration extended add hand exercise kiran topic explained fundamental advanced method good good trainer food presentation skill training advanced python helped concert usage python help understand aspect machine learning good understanding data science machine learning concept good training science background ai concept arranged presented kiran good faculty content good summary start project data scioner machine learning coursed covered basic python
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     half day
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  subject good training informative presented training good excellent point start journey data science excellent training good knowledge good great explanation easy understand topic make happy nature make session interested nice faulty explained teach topic practical day day life finally entire session good training helpful guide teach business designed organize structure learning element learned point detailed manner content training excellent good teaching technique training good advanced expected topic elaborated beginner intermediate advanced topic lick service mesh deep dive monitoring ect good developing basic understanding kubernetes training good training good good hand kubernetes concept interactive great suggestion share presentation deck day end training day training good learn multiple technique development training good time allocated project management tool working tool training good give good overview project management learnt lot information trainer excellent gob good detailed excellent paced explained suitable example great session certified pmp training good helpful krishna helped solve doubt training provided tilling application relay applicable day pmp training valuable topic explained example help understand concept training good covered aspect depth valuable effective good insight tool technique interactive training mr krishna helped understanding concept easy remember good ram capability skill good stacking point trainer training word learn fun excellent example content good faculty god delivered thing practical manner training good topic explained good training excellent communication engaging audiance training delivered good understanding subject training session good informative enhancing skill knowledge professional career good informative good example explain concept training add explained enhance device skill motivate perform practice organization
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     day day
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  basis service delivery training content subjective easy understand learn thing haired industry fantastic sir delivered point needed training provided mr ram tavva effort put teach time ahead future training received good knowledge handling improving work implement thing term concern training made simple easy understand made practical approach faculty made engaging beautiful example training clear concise good amount depth term topic coverage find job effectively find ram friendly knowledgeable practical fun learning example make excellent organised content relevant current project good session informative effective excellent workshop relevant super feedback mechanism view recording training interactive live example made process understand material good completed pmp training great session good experience training good excellent good delivered good training experience excellent training good excellent training session special krishna interactive engaging training training helpful understanding concept pmp class room training krishna gave insight concept prepare exam training provided helpful effective reliable interactive session valuable effective good insight tool technique material apt prepare pmp certification knowledge perspective trainer patient highly knowledgeable interactive interested excellent easy understand mr krishna understand module simple precise example understanding thanking sir pmp training krishna served gaining concept delivered clear resource matched excellence informative pmp training good krishna sir good knowledge sharing pmp content training day nice training people krishna great trainer enjoyed session learning good training covering aspect project management nice learning thing training good training structured krishna sir explained good example training structured class room training conducted professionally enjoyable provided insight concept approach exam preparation pmp class room training impressed level dedication faculty krishna sir excellent method explaining concept interactive effective experience good trainer provide lot example lot understand good knowledge interactive session good training example provided session helped lot good preparation guide preparation tip good explain practical example make effective work shop informative real time knowledge example full computer course covered process valid example satisfied nicely conducted excellent excellent instructor learning support great thing krishna explained topic clarity live example helpful teaching small doubt involved application process content pmp training satisfactory knowledge shared good example easy understand training good interactive good training good intensive training mr krishna supporting staff training good pmp training good relevant example good highly interactive session easy understood explained relevant example trainer highly knowledgeable good exposure organized learn pmp managed helpful training session doubt clarified idea pmp excellent training krishna attended day pmp training conducted krishna great training excellent good supporting staff great teaching day training program good covered process learned forward study fir certification g

# %%
all_scores = all_words.set_index(0)['Value'].to_dict()
all_scores
# Out:
# {'abnormal': -1,
#  'abolish': -1,
#  'abominable': -1,
#  'abominably': -1,
#  'abominate': -1,
#  'abomination': -1,
#  'abort': -1,
#  'aborted': -1,
#  'aborts': -1,
#  'abrade': -1,
#  'abrasive': -1,
#  'abrupt': -1,
#  'abruptly': -1,
#  'abscond': -1,
#  'absence': -1,
#  'absent-minded': -1,
#  'absentee': -1,
#  'absurd': -1,
#  'absurdity': -1,
#  'absurdly': -1,
#  'absurdness': -1,
#  'abuse': -1,
#  'abused': -1,
#  'abuses': -1,
#  'abusive': -1,
#  'abysmal': -1,
#  'abysmally': -1,
#  'abyss': -1,
#  'accidental': -1,
#  'accost': -1,
#  'accursed': -1,
#  'accusation': -1,
#  'accusations': -1,
#  'accuse': -1,
#  'accuses': -1,
#  'accusing': -1,
#  'accusingly': -1,
#  'acerbate': -1,
#  'acerbic': -1,
#  'acerbically': -1,
#  'ache': -1,
#  'ached': -1,
#  'aches': -1,
#  'achey': -1,
#  'aching': -1,
#  'acrid': -1,
#  'acridly': -1,
#  'acridness': -1,
#  'acrimonious': -1,
#  'acrimoniously': -1,
#  'acrimony': -1,
#  'adamant': -1,
#  'adamantly': -1,
#  'addict': -1,
#  'addicted': -1,
#  'addicting': -1,
#  'addicts': -1,
#  'admonish': -1,
#  'admonisher': -1,
#  'admonishingly': -1,
#  'admonishment': -1,
#  'admonition': -1,
#  'adulterate': -1,
#  'adulterated': -1,
#  'adulteration': -1,
#  'adulterier': -1,
#  'adversarial': -1,
#  'adversary': -1,
#  'adverse': -1,
#  'adversity': -1,
#  'afflict': -1,
#  'affliction': -1,
#  'afflictive': -1,
#  'affront': -1,
#  'afraid': -1,
#  'aggravate': -1,
#  'aggravating': -1,
#  'aggravation': -1,
#  'aggression': -1,
#  'aggressive': -1,
#  'aggressiveness': -1,
#  'aggressor': -1,
#  'aggrieve': -1,
#  'aggrieved': -1,
#  'aggrivation': -1,
#  'aghast': -1,
#  'agonies': -1,
#  'agonize': -1,
#  'agonizing': -1,
#  'agonizingly': -1,
#  'agony': -1,
#  'aground': -1,
#  'ail': -1,
#  'ailing': -1,
#  'ailment': -1,
#  'aimless': -1,
#  'alarm': -1,
#  'alarmed': -1,
#  'alarming': -1,
#  'alarmingly': -1,
#  'alienate': -1,
#  'alienated': -1,
#  'alienation': -1,
#  'allegation': -1,
#  'allegations': -1,
#  'allege': -1,
#  'allergic': -1,
#  'allergies': -1,
#  'allergy': -1,
#  'aloof': -1,
#  'altercation': -1,
#  'ambiguity': -1,
#  'ambiguous': -1,
#  'ambivalence': -1,
#  'ambivalent': -1,
#  'ambush': -1,
#  'amiss': -1,
#  'amputate': -1,
#  'anarchism': -1,
#  'anarchist': -1,
#  'anarchistic': -1,
#  'anarchy': -1,
#  'anemic': -1,
#  'anger': -1,
#  'angrily': -1,
#  'angriness': -1,
#  'angry': -1,
#  'anguish': -1,
#  'animosity': -1,
#  'annihilate': -1,
#  'annihilation': -1,
#  'annoy': -1,
#  'annoyance': -1,
#  'annoyances': -1,
#  'annoyed': -1,
#  'annoying': -1,
#  'annoyingly': -1,
#  'annoys': -1,
#  'anomalous': -1,
#  'anomaly': -1,
#  'antagonism': -1,
#  'antagonist': -1,
#  'antagonistic': -1,
#  'antagonize': -1,
#  'anti-': -1,
#  'anti-american': -1,
#  'anti-israeli': -1,
#  'anti-occupation': -1,
#  'anti-proliferation': -1,
#  'anti-semites': -1,
#  'anti-social': -1,
#  'anti-us': -1,
#  'anti-white': -1,
#  'antipathy': -1,
#  'antiquated': -1,
#  'antithetical': -1,
#  'anxieties': -1,
#  'anxiety': -1,
#  'anxious': -1,
#  'anxiously': -1,
#  'anxiousness': -1,
#  'apathetic': -1,
#  'apathetically': -1,
#  'apathy': -1,
#  'apocalypse': -1,
#  'apocalyptic': -1,
#  'apologist': -1,
#  'apologists': -1,
#  'appal': -1,
#  'appall': -1,
#  'appalled': -1,
#  'appalling': -1,
#  'appallingly': -1,
#  'apprehension': -1,
#  'apprehensions': -1,
#  'apprehensive': -1,
#  'apprehensively': -1,
#  'arbitrary': -1,
#  'arcane': -1,
#  'archaic': -1,
#  'arduous': -1,
#  'arduously': -1,
#  'argumentative': -1,
#  'arrogance': -1,
#  'arrogant': -1,
#  'arrogantly': -1,
#  'ashamed': -1,
#  'asinine': -1,
#  'asininely': -1,
#  'asinininity': -1,
#  'askance': -1,
#  'asperse': -1,
#  'aspersion': -1,
#  'aspersions': -1,
#  'assail': -1,
#  'assassin': -1,
#  'assassinate': -1,
#  'assault': -1,
#  'assult': -1,
#  'astray': -1,
#  'asunder': -1,
#  'atrocious': -1,
#  'atrocities': -1,
#  'atrocity': -1,
#  'atrophy': -1,
#  'attack': -1,
#  'attacks': -1,
#  'audacious': -1,
#  'audaciously': -1,
#  'audaciousness': -1,
#  'audacity': -1,
#  'audiciously': -1,
#  'austere': -1,
#  'authoritarian': -1,
#  'autocrat': -1,
#  'autocratic': -1,
#  'avalanche': -1,
#  'avarice': -1,
#  'avaricious': -1,
#  'avariciously': -1,
#  'avenge': -1,
#  'averse': -1,
#  'aversion': -1,
#  'aweful': -1,
#  'awful': -1,
#  'awfully': -1,
#  'awfulness': -1,
#  'awkward': -1,
#  'awkwardness': -1,
#  'ax': -1,
#  'babble': -1,
#  'back-logged': -1,
#  'back-wood': -1,
#  'back-woods': -1,
#  'backache': -1,
#  'backaches': -1,
#  'backaching': -1,
#  'backbite': -1,
#  'backbiting': -1,
#  'backward': -1,
#  'backwardness': -1,
#  'backwood': -1,
#  'backwoods': -1,
#  'bad': -1,
#  'badly': -1,
#  'baffle': -1,
#  'baffled': -1,
#  'bafflement': -1,
#  'baffling': -1,
#  'bait': -1,
#  'balk': -1,
#  'banal': -1,
#  'banalize': -1,
#  'bane': -1,
#  'banish': -1,
#  'banishment': -1,
#  'bankrupt': -1,
#  'barbarian': -1,
#  'barbaric': -1,
#  'barbarically': -1,
#  'barbarity': -1,
#  'barbarous': -1,
#  'barbarously': -1,
#  'barren': -1,
#  'baseless': -1,
#  'bash': -1,
#  'bashed': -1,
#  'bashful': -1,
#  'bashing': -1,
#  'bastard': -1,
#  'bastards': -1,
#  'battered': -1,
#  'battering': -1,
#  'batty': -1,
#  'bearish': -1,
#  'beastly': -1,
#  'bedlam': -1,
#  'bedlamite': -1,
#  'befoul': -1,
#  'beg': -1,
#  'beggar': -1,
#  'beggarly': -1,
#  'begging': -1,
#  'beguile': -1,
#  'belabor': -1,
#  'belated': -1,
#  'beleaguer': -1,
#  'belie': -1,
#  'belittle': -1,
#  'belittled': -1,
#  'belittling': -1,
#  'bellicose': -1,
#  'belligerence': -1,
#  'belligerent': -1,
#  'belligerently': -1,
#  'bemoan': -1,
#  'bemoaning': -1,
#  'bemused': -1,
#  'bent': -1,
#  'berate': -1,
#  'bereave': -1,
#  'bereavement': -1,
#  'bereft': -1,
#  'berserk': -1,
#  'beseech': -1,
#  'beset': -1,
#  'besiege': -1,
#  'besmirch': -1,
#  'bestial': -1,
#  'betray': -1,
#  'betrayal': -1,
#  'betrayals': -1,
#  'betrayer': -1,
#  'betraying': -1,
#  'betrays': -1,
#  'bewail': -1,
#  'beware': -1,
#  'bewilder': -1,
#  'bewildered': -1,
#  'bewildering': -1,
#  'bewilderingly': -1,
#  'bewilderment': -1,
#  'bewitch': -1,
#  'bias': -1,
#  'biased': -1,
#  'biases': -1,
#  'bicker': -1,
#  'bickering': -1,
#  'bid-rigging': -1,
#  'bigotries': -1,
#  'bigotry': -1,
#  'bitch': -1,
#  'bitchy': -1,
#  'biting': -1,
#  'bitingly': -1,
#  'bitter': -1,
#  'bitterly': -1,
#  'bitterness': -1,
#  'bizarre': -1,
#  'blab': -1,
#  'blabber': -1,
#  'blackmail': -1,
#  'blah': -1,
#  'blame': -1,
#  'blameworthy': -1,
#  'bland': -1,
#  'blandish': -1,
#  'blaspheme': -1,
#  'blasphemous': -1,
#  'blasphemy': -1,
#  'blasted': -1,
#  'blatant': -1,
#  'blatantly': -1,
#  'blather': -1,
#  'bleak': -1,
#  'bleakly': -1,
#  'bleakness': -1,
#  'bleed': -1,
#  'bleeding': -1,
#  'bleeds': -1,
#  'blemish': -1,
#  'blind': -1,
#  'blinding': -1,
#  'blindingly': -1,
#  'blindside': -1,
#  'blister': -1,
#  'blistering': -1,
#  'bloated': -1,
#  'blockage': -1,
#  'blockhead': -1,
#  'bloodshed': -1,
#  'bloodthirsty': -1,
#  'bloody': -1,
#  'blotchy': -1,
#  'blow': -1,
#  'blunder': -1,
#  'blundering': -1,
#  'blunders': -1,
#  'blunt': -1,
#  'blur': -1,
#  'bluring': -1,
#  'blurred': -1,
#  'blurring': -1,
#  'blurry': -1,
#  'blurs': -1,
#  'blurt': -1,
#  'boastful': -1,
#  'boggle': -1,
#  'bogus': -1,
#  'boil': -1,
#  'boiling': -1,
#  'boisterous': -1,
#  'bomb': -1,
#  'bombard': -1,
#  'bombardment': -1,
#  'bombastic': -1,
#  'bondage': -1,
#  'bonkers': -1,
#  'bore': -1,
#  'bored': -1,
#  'boredom': -1,
#  'bores': -1,
#  'boring': -1,
#  'botch': -1,
#  'bother': -1,
#  'bothered': -1,
#  'bothering': -1,
#  'bothers': -1,
#  'bothersome': -1,
#  'bowdlerize': -1,
#  'boycott': -1,
#  'braggart': -1,
#  'bragger': -1,
#  'brainless': -1,
#  'brainwash': -1,
#  'brash': -1,
#  'brashly': -1,
#  'brashness': -1,
#  'brat': -1,
#  'bravado': -1,
#  'brazen': -1,
#  'brazenly': -1,
#  'brazenness': -1,
#  'breach': -1,
#  'break': -1,
#  'break-up': -1,
#  'break-ups': -1,
#  'breakdown': -1,
#  'breaking': -1,
#  'breaks': -1,
#  'breakup': -1,
#  'breakups': -1,
#  'bribery': -1,
#  'brimstone': -1,
#  'bristle': -1,
#  'brittle': -1,
#  'broke': -1,
#  'broken': -1,
#  'broken-hearted': -1,
#  'brood': -1,
#  'browbeat': -1,
#  'bruise': -1,
#  'bruised': -1,
#  'bruises': -1,
#  'bruising': -1,
#  'brusque': -1,
#  'brutal': -1,
#  'brutalising': -1,
#  'brutalities': -1,
#  'brutality': -1,
#  'brutalize': -1,
#  'brutalizing': -1,
#  'brutally': -1,
#  'brute': -1,
#  'brutish': -1,
#  'bs': -1,
#  'buckle': -1,
#  'bug': -1,
#  'bugging': -1,
#  'buggy': -1,
#  'bugs': -1,
#  'bulkier': -1,
#  'bulkiness': -1,
#  'bulky': -1,
#  'bulkyness': -1,
#  'bull****': -1,
#  'bull----': -1,
#  'bullies': -1,
#  'bullshit': -1,
#  'bullshyt': -1,
#  'bully': -1,
#  'bullying': -1,
#  'bullyingly': -1,
#  'bum': -1,
#  'bump': -1,
#  'bumped': -1,
#  'bumping': -1,
#  'bumpping': -1,
#  'bumps': -1,
#  'bumpy': -1,
#  'bungle': -1,
#  'bungler': -1,
#  'bungling': -1,
#  'bunk': -1,
#  'burden': -1,
#  'burdensome': -1,
#  'burdensomely': -1,
#  'burn': -1,
#  'burned': -1,
#  'burning': -1,
#  'burns': -1,
#  'bust': -1,
#  'busts': -1,
#  'busybody': -1,
#  'butcher': -1,
#  'butchery': -1,
#  'buzzing': -1,
#  'byzantine': -1,
#  'cackle': -1,
#  'calamities': -1,
#  'calamitous': -1,
#  'calamitously': -1,
#  'calamity': -1,
#  'callous': -1,
#  'calumniate': -1,
#  'calumniation': -1,
#  'calumnies': -1,
#  'calumnious': -1,
#  'calumniously': -1,
#  'calumny': -1,
#  'cancer': -1,
#  'cancerous': -1,
#  'cannibal': -1,
#  'cannibalize': -1,
#  'capitulate': -1,
#  'capricious': -1,
#  'capriciously': -1,
#  'capriciousness': -1,
#  'capsize': -1,
#  'careless': -1,
#  'carelessness': -1,
#  'caricature': -1,
#  'carnage': -1,
#  'carp': -1,
#  'cartoonish': -1,
#  'cash-strapped': -1,
#  'castigate': -1,
#  'castrated': -1,
#  'casualty': -1,
#  'cataclysm': -1,
#  'cataclysmal': -1,
#  'cataclysmic': -1,
#  'cataclysmically': -1,
#  'catastrophe': -1,
#  'catastrophes': -1,
#  'catastrophic': -1,
#  'catastrophically': -1,
#  'catastrophies': -1,
#  'caustic': -1,
#  'caustically': -1,
#  'cautionary': -1,
#  'cave': -1,
#  'censure': -1,
#  'chafe': -1,
#  'chaff': -1,
#  'chagrin': -1,
#  'challenging': -1,
#  'chaos': -1,
#  'chaotic': -1,
#  'chasten': -1,
#  'chastise': -1,
#  'chastisement': -1,
#  'chatter': -1,
#  'chatterbox': -1,
#  'cheap': -1,
#  'cheapen': -1,
#  'cheaply': -1,
#  'cheat': -1,
#  'cheated': -1,
#  'cheater': -1,
#  'cheating': -1,
#  'cheats': -1,
#  'checkered': -1,
#  'cheerless': -1,
#  'cheesy': -1,
#  'chide': -1,
#  'childish': -1,
#  'chill': -1,
#  'chilly': -1,
#  'chintzy': -1,
#  'choke': -1,
#  'choleric': -1,
#  'choppy': -1,
#  'chore': -1,
#  'chronic': -1,
#  'chunky': -1,
#  'clamor': -1,
#  'clamorous': -1,
#  'clash': -1,
#  'cliche': -1,
#  'cliched': -1,
#  'clique': -1,
#  'clog': -1,
#  'clogged': -1,
#  'clogs': -1,
#  'cloud': -1,
#  'clouding': -1,
#  'cloudy': -1,
#  'clueless': -1,
#  'clumsy': -1,
#  'clunky': -1,
#  'coarse': -1,
#  'cocky': -1,
#  'coerce': -1,
#  'coercion': -1,
#  'coercive': -1,
#  'cold': -1,
#  'coldly': -1,
#  'collapse': -1,
#  'collude': -1,
#  'collusion': -1,
#  'combative': -1,
#  'combust': -1,
#  'comical': -1,
#  'commiserate': -1,
#  'commonplace': -1,
#  'commotion': -1,
#  'commotions': -1,
#  'complacent': -1,
#  'complain': -1,
#  'complained': -1,
#  'complaining': -1,
#  'complains': -1,
#  'complaint': -1,
#  'complaints': -1,
#  'complex': -1,
#  'complicated': -1,
#  'complication': -1,
#  'complicit': -1,
#  'compulsion': -1,
#  'compulsive': -1,
#  'concede': -1,
#  'conceded': -1,
#  'conceit': -1,
#  'conceited': -1,
#  'concen': -1,
#  'concens': -1,
#  'concern': -1,
#  'concerned': -1,
#  'concerns': -1,
#  'concession': -1,
#  'concessions': -1,
#  'condemn': -1,
#  'condemnable': -1,
#  'condemnation': -1,
#  'condemned': -1,
#  'condemns': -1,
#  'condescend': -1,
#  'condescending': -1,
#  'condescendingly': -1,
#  'condescension': -1,
#  'confess': -1,
#  'confession': -1,
#  'confessions': -1,
#  'confined': -1,
#  'conflict': -1,
#  'conflicted': -1,
#  'conflicting': -1,
#  'conflicts': -1,
#  'confound': -1,
#  'confounded': -1,
#  'confounding': -1,
#  'confront': -1,
#  'confrontation': -1,
#  'confrontational': -1,
#  'confuse': -1,
#  'confused': -1,
#  'confuses': -1,
#  'confusing': -1,
#  'confusion': -1,
#  'confusions': -1,
#  'congested': -1,
#  'congestion': -1,
#  'cons': -1,
#  'conscons': -1,
#  'conservative': -1,
#  'conspicuous': -1,
#  'conspicuously': -1,
#  'conspiracies': -1,
#  'conspiracy': -1,
#  'conspirator': -1,
#  'conspiratorial': -1,
#  'conspire': -1,
#  'consternation': -1,
#  'contagious': -1,
#  'contaminate': -1,
#  'contaminated': -1,
#  'contaminates': -1,
#  'contaminating': -1,
#  'contamination': -1,
#  'contempt': -1,
#  'contemptible': -1,
#  'contemptuous': -1,
#  'contemptuously': -1,
#  'contend': -1,
#  'contention': -1,
#  'contentious': -1,
#  'contort': -1,
#  'contortions': -1,
#  'contradict': -1,
#  'contradiction': -1,
#  'contradictory': -1,
#  'contrariness': -1,
#  'contravene': -1,
#  'contrive': -1,
#  'contrived': -1,
#  'controversial': -1,
#  'controversy': -1,
#  'convoluted': -1,
#  'corrode': -1,
#  'corrosion': -1,
#  'corrosions': -1,
#  'corrosive': -1,
#  'corrupt': -1,
#  'corrupted': -1,
#  'corrupting': -1,
#  'corruption': -1,
#  'corrupts': -1,
#  'corruptted': -1,
#  'costlier': -1,
#  'costly': -1,
#  'counter-productive': -1,
#  'counterproductive': -1,
#  'coupists': -1,
#  'covetous': -1,
#  'coward': -1,
#  'cowardly': -1,
#  'crabby': -1,
#  'crack': -1,
#  'cracked': -1,
#  'cracks': -1,
#  'craftily': -1,
#  'craftly': -1,
#  'crafty': -1,
#  'cramp': -1,
#  'cramped': -1,
#  'cramping': -1,
#  'cranky': -1,
#  'crap': -1,
#  'crappy': -1,
#  'craps': -1,
#  'crash': -1,
#  'crashed': -1,
#  'crashes': -1,
#  'crashing': -1,
#  'crass': -1,
#  'craven': -1,
#  'cravenly': -1,
#  'craze': -1,
#  'crazily': -1,
#  'craziness': -1,
#  'crazy': -1,
#  'creak': -1,
#  'creaking': -1,
#  'creaks': -1,
#  'credulous': -1,
#  'creep': -1,
#  'creeping': -1,
#  'creeps': -1,
#  'creepy': -1,
#  'crept': -1,
#  'crime': -1,
#  'criminal': -1,
#  'cringe': -1,
#  'cringed': -1,
#  'cringes': -1,
#  'cripple': -1,
#  'crippled': -1,
#  'cripples': -1,
#  'crippling': -1,
#  'crisis': -1,
#  'critic': -1,
#  'critical': -1,
#  'criticism': -1,
#  'criticisms': -1,
#  'criticize': -1,
#  'criticized': -1,
#  'criticizing': -1,
#  'critics': -1,
#  'cronyism': -1,
#  'crook': -1,
#  'crooked': -1,
#  'crooks': -1,
#  'crowded': -1,
#  'crowdedness': -1,
#  'crude': -1,
#  'cruel': -1,
#  'crueler': -1,
#  'cruelest': -1,
#  'cruelly': -1,
#  'cruelness': -1,
#  'cruelties': -1,
#  'cruelty': -1,
#  'crumble': -1,
#  'crumbling': -1,
#  'crummy': -1,
#  'crumple': -1,
#  'crumpled': -1,
#  'crumples': -1,
#  'crush': -1,
#  'crushed': -1,
#  'crushing': -1,
#  'cry': -1,
#  'culpable': -1,
#  'culprit': -1,
#  'cumbersome': -1,
#  'cunt': -1,
#  'cunts': -1,
#  'cuplrit': -1,
#  'curse': -1,
#  'cursed': -1,
#  'curses': -1,
#  'curt': -1,
#  'cuss': -1,
#  'cussed': -1,
#  'cutthroat': -1,
#  'cynical': -1,
#  'cynicism': -1,
#  'd*mn': -1,
#  'damage': -1,
#  'damaged': -1,
#  'damages': -1,
#  'damaging': -1,
#  'damn': -1,
#  'damnable': -1,
#  'damnably': -1,
#  'damnation': -1,
#  'damned': -1,
#  'damning': -1,
#  'damper': -1,
#  'danger': -1,
#  'dangerous': -1,
#  'dangerousness': -1,
#  'dark': -1,
#  'darken': -1,
#  'darkened': -1,
#  'darker': -1,
#  'darkness': -1,
#  'dastard': -1,
#  'dastardly': -1,
#  'daunt': -1,
#  'daunting': -1,
#  'dauntingly': -1,
#  'dawdle': -1,
#  'daze': -1,
#  'dazed': -1,
#  'dead': -1,
#  'deadbeat': -1,
#  'deadlock': -1,
#  'deadly': -1,
#  'deadweight': -1,
#  'deaf': -1,
#  'dearth': -1,
#  'death': -1,
#  'debacle': -1,
#  'debase': -1,
#  'debasement': -1,
#  'debaser': -1,
#  'debatable': -1,
#  'debauch': -1,
#  'debaucher': -1,
#  'debauchery': -1,
#  'debilitate': -1,
#  'debilitating': -1,
#  'debility': -1,
#  'debt': -1,
#  'debts': -1,
#  'decadence': -1,
#  'decadent': -1,
#  'decay': -1,
#  'decayed': -1,
#  'deceit': -1,
#  'deceitful': -1,
#  'deceitfully': -1,
#  'deceitfulness': -1,
#  'deceive': -1,
#  'deceiver': -1,
#  'deceivers': -1,
#  'deceiving': -1,
#  'deception': -1,
#  'deceptive': -1,
#  'deceptively': -1,
#  'declaim': -1,
#  'decline': -1,
#  'declines': -1,
#  'declining': -1,
#  'decrement': -1,
#  'decrepit': -1,
#  'decrepitude': -1,
#  'decry': -1,
#  'defamation': -1,
#  'defamations': -1,
#  'defamatory': -1,
#  'defame': -1,
#  'defect': -1,
#  'defective': -1,
#  'defects': -1,
#  'defensive': -1,
#  'defiance': -1,
#  'defiant': -1,
#  'defiantly': -1,
#  'deficiencies': -1,
#  'deficiency': -1,
#  'deficient': -1,
#  'defile': -1,
#  'defiler': -1,
#  'deform': -1,
#  'deformed': -1,
#  'defrauding': -1,
#  'defunct': -1,
#  'defy': -1,
#  'degenerate': -1,
#  'degenerately': -1,
#  'degeneration': -1,
#  'degradation': -1,
#  'degrade': -1,
#  'degrading': -1,
#  'degradingly': -1,
#  'dehumanization': -1,
#  'dehumanize': -1,
#  'deign': -1,
#  'deject': -1,
#  'dejected': -1,
#  'dejectedly': -1,
#  'dejection': -1,
#  'delay': -1,
#  'delayed': -1,
#  'delaying': -1,
#  'delays': -1,
#  'delinquency': -1,
#  'delinquent': -1,
#  'delirious': -1,
#  'delirium': -1,
#  'delude': -1,
#  'deluded': -1,
#  'deluge': -1,
#  'delusion': -1,
#  'delusional': -1,
#  'delusions': -1,
#  'demean': -1,
#  'demeaning': -1,
#  'demise': -1,
#  'demolish': -1,
#  'demolisher': -1,
#  'demon': -1,
#  'demonic': -1,
#  'demonize': -1,
#  'demonized': -1,
#  'demonizes': -1,
#  'demonizing': -1,
#  'demoralize': -1,
#  'demoralizing': -1,
#  'demoralizingly': -1,
#  'denial': -1,
#  'denied': -1,
#  'denies': -1,
#  'denigrate': -1,
#  'denounce': -1,
#  'dense': -1,
#  'dent': -1,
#  'dented': -1,
#  'dents': -1,
#  'denunciate': -1,
#  'denunciation': -1,
#  'denunciations': -1,
#  'deny': -1,
#  'denying': -1,
#  'deplete': -1,
#  'deplorable': -1,
#  'deplorably': -1,
#  'deplore': -1,
#  'deploring': -1,
#  'deploringly': -1,
#  'deprave': -1,
#  'depraved': -1,
#  'depravedly': -1,
#  'deprecate': -1,
#  'depress': -1,
#  'depressed': -1,
#  'depressing': -1,
#  'depressingly': -1,
#  'depression': -1,
#  'depressions': -1,
#  'deprive': -1,
#  'deprived': -1,
#  'deride': -1,
#  'derision': -1,
#  'derisive': -1,
#  'derisively': -1,
#  'derisiveness': -1,
#  'derogatory': -1,
#  'desecrate': -1,
#  'desert': -1,
#  'desertion': -1,
#  'desiccate': -1,
#  'desiccated': -1,
#  'desititute': -1,
#  'desolate': -1,
#  'desolately': -1,
#  'desolation': -1,
#  'despair': -1,
#  'despairing': -1,
#  'despairingly': -1,
#  'desperate': -1,
#  'desperately': -1,
#  'desperation': -1,
#  'despicable': -1,
#  'despicably': -1,
#  'despise': -1,
#  'despised': -1,
#  ...}

# %%
#Custom function :score each word in a sentence in lemmatised form, 
#but calculate the score for the whole original sentence.
nlp = spacy.load('en_core_web_sm')
sentiment_lexicon = all_scores

def calculate_sentiment(result: str = None):
    sent_score = 0
    if result:
        sentence = nlp(result)
        for word in sentence:
            sent_score += sentiment_lexicon.get(word.lemma_, 0)
    return sent_score

# %%
# test that it works
calculate_sentiment(result = 'amazing')
# Out:
# 1

# %%
df=pd.DataFrame({'Reviews':result , 'Cleaned_text' : X })
df
# Out:
#                                                 Reviews  \
# 0                                                  Good
# 1     Productive Training with clear explanation cou...
# 2     Could understand the basics of boom and feel c...
# 3     Useful training intern of project & Business r...
# 4     The Training provided by krishna sir was excel...
# ...                                                 ...
# 1376  Very interactive trainer with lot of simple ex...
# 1377  The Overall Training was nice. The sad part is...
# 1378  Training was very helpful, very interactive an...
# 1379  Overall Training was excellent. Trainer was we...
# 1380  It was awesome training which will redefine my...
#
#                                            Cleaned_text
# 0                                                  good
# 1     productive training clear explanation require ...
# 2     understand basic boom feel confident certifica...
# 3     training intern project business requirement e...
# 4               training provided krishna sir excellent
# ...                                                 ...
# 1376  interactive trainer lot simple example easy un...
# 1377  training nice sad part missed half session due...
# 1378             training helpful interactive practical
# 1379  training excellent trainer versed knowledge de...
# 1380  awesome training redefine carrer analytics are...
#
# [1381 rows x 2 columns]

# %%
df['sentiment_value'] = df['Cleaned_text'].apply(calculate_sentiment)

# %%
df
# Out:
#                                                 Reviews  \
# 0                                                  Good
# 1     Productive Training with clear explanation cou...
# 2     Could understand the basics of boom and feel c...
# 3     Useful training intern of project & Business r...
# 4     The Training provided by krishna sir was excel...
# ...                                                 ...
# 1376  Very interactive trainer with lot of simple ex...
# 1377  The Overall Training was nice. The sad part is...
# 1378  Training was very helpful, very interactive an...
# 1379  Overall Training was excellent. Trainer was we...
# 1380  It was awesome training which will redefine my...
#
#                                            Cleaned_text  sentiment_value
# 0                                                  good                1
# 1     productive training clear explanation require ...                3
# 2     understand basic boom feel confident certifica...                3
# 3     training intern project business requirement e...                2
# 4               training provided krishna sir excellent                1
# ...                                                 ...              ...
# 1376  interactive trainer lot simple example easy un...                1
# 1377  training nice sad part missed half session due...               -1
# 1378             training helpful interactive practical                1
# 1379  training excellent trainer versed knowledge de...                2
# 1380  awesome training redefine carrer analytics are...                2
#
# [1381 rows x 3 columns]

# %%
# how many words are in the sentence?
df['word_count'] = df['Reviews'].str.split().apply(len)
df['word_count'].sort_values(ascending=False).head(20)
# Out:
# 403     106
# 1350     99
# 492      99
# 468      98
# 701      95
# 704      91
# 1330     91
# 794      90
# 513      81
# 732      81
# 1301     78
# 611      78
# 695      77
# 1344     76
# 404      76
# 795      74
# 506      70
# 487      69
# 445      66
# 763      64
# Name: word_count, dtype: int64

# %%
# Sentiment score of the whole review
df['sentiment_value'].describe()
# Out:
# count    1381.000000
# mean        1.669080
# std         1.236454
# min        -2.000000
# 25%         1.000000
# 50%         1.000000
# 75%         2.000000
# max         8.000000
# Name: sentiment_value, dtype: float64

# %% [markdown]
# #### Highly Positive Reviews

# %%
df.sort_values(by='sentiment_value').tail(10)
# Out:
#                                                 Reviews  \
# 85    The training was clear, concise with good amou...
# 1175  "Iam felling happy & proud to put the feedback...
# 1004  "Fantastic Training experience with ExcelR. Tr...
# 611   This course was worth every penny. Krishnamraj...
# 690   "PMP training given by Ram Tavva was excellent...
# 1277  PMP training given by Ram Tavva was excellent....
# 468   The overall training was extremely good. No do...
# 701   Very informative and great to have such a trai...
# 598   First of all I want to give thanks for the tra...
# 578   "Trainer Mr Krishnam Raj was very helpful, kno...
#
#                                            Cleaned_text  sentiment_value  \
# 85    training clear concise good amount depth term ...                6
# 1175  iam felling happy proud put feedback session d...                6
# 1004  fantastic training experience excelr trainer m...                6
# 611   worth penny krishnamraj great instructor accom...                6
# 690   pmp training ram tavva excellent made dry subj...                7
# 1277  pmp training ram tavva excellent made dry subj...                7
# 468   training extremely good doubt great money bhar...                7
# 701   informative great training session presenter e...                7
# 598   give training session found interesting incred...                7
# 578   trainer mr krishnam raj helpful knowledgeable ...                8
#
#       word_count
# 85            37
# 1175          45
# 1004          61
# 611           78
# 690           63
# 1277          54
# 468           98
# 701           95
# 598           56
# 578           48

# %% [markdown]
# #### Highly Negative Reviews

# %%
df[df['sentiment_value']<0]
# Out:
#                                                 Reviews  \
# 358   Got clarified weak points and confusion on pro...
# 374   A little slow pace,can be followed, but again ...
# 404   This course helps me to understand better the ...
# 465   All the sessions in R and Tableau were very we...
# 712   "Krishna makes sure we understand the process ...
# 1154  The training was knowledgable .Got on overall ...
# 1162  "Very explanatory ,interactive ,hectic schedul...
# 1234  All of the course content was not covered in t...
# 1315  Service Delivery Manager – IBM India Private L...
# 1377  The Overall Training was nice. The sad part is...
#
#                                            Cleaned_text  sentiment_value  \
# 358   clarified weak point confusion process knowled...               -2
# 374                              slow pace time managed               -1
# 404   help understand basic infra service service of...               -1
# 465   session tableau explained contact bharani srin...               -1
# 712   krishna make understand process session intera...               -1
# 1154  training knowledgable understanding pattern lt...               -1
# 1162  explanatory interactive hectic schedule team o...               -1
# 1234  content covered time provided mock exam lot co...               -1
# 1315  service delivery manager ibm india private lim...               -1
# 1377  training nice sad part missed half session due...               -1
#
#       word_count
# 358            9
# 374           14
# 404           76
# 465           26
# 712           17
# 1154          28
# 1162          25
# 1234          25
# 1315           8
# 1377          30

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.histplot(df['sentiment_value'])
# Out:
# <AxesSubplot:xlabel='sentiment_value', ylabel='Count'>

# %%
df.plot.scatter(x='word_count', y='sentiment_value', figsize=(8,8), title='Sentence sentiment value to sentence word count')
# Out:
# <AxesSubplot:title={'center':'Sentence sentiment value to sentence word count'}, xlabel='word_count', ylabel='sentiment_value'>
