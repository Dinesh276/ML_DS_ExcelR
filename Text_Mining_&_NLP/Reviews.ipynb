# %% [markdown]
#  TWO:
# 1) Extract reviews of any product from ecommerce website like amazon
# 2) Perform emotion mining

# %%
# !pip install autoscraper
# Out:
# Collecting autoscraper
#   Downloading autoscraper-1.1.12-py3-none-any.whl (10 kB)
# Requirement already satisfied: lxml in c:\programdata\anaconda3\lib\site-packages (from autoscraper) (4.6.1)
# Collecting bs4
#   Downloading bs4-0.0.1.tar.gz (1.1 kB)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from autoscraper) (2.24.0)
# Requirement already satisfied: beautifulsoup4 in c:\programdata\anaconda3\lib\site-packages (from bs4->autoscraper) (4.9.3)
# Requirement already satisfied: idna<3,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->autoscraper) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from requests->autoscraper) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->autoscraper) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->autoscraper) (2020.6.20)
# Requirement already satisfied: soupsieve>1.2; python_version >= "3.0" in c:\programdata\anaconda3\lib\site-packages (from beautifulsoup4->bs4->autoscraper) (2.0.1)
# Building wheels for collected packages: bs4
#   Building wheel for bs4 (setup.py): started
#   Building wheel for bs4 (setup.py): finished with status 'done'
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1277 sha256=243579c8f75df7d9417ce70e0caae2ad293ab410cbc3641b6720f12d8800105f
#   Stored in directory: c:\users\uk15\appdata\local\pip\cache\wheels\75\78\21\68b124549c9bdc94f822c02fb9aa3578a669843f9767776bca
# Successfully built bs4
# Installing collected packages: bs4, autoscraper
# Successfully installed autoscraper-1.1.12 bs4-0.0.1

# %%
from autoscraper import AutoScraper

# %%
url='https://www.excelr.com/testimonials'

# %%
wanted_list=['Productive Training with clear explanation could require more reading material. Overall good and useful training.']

# %%
scrap=AutoScraper()

# %%
result=scrap.build(url,wanted_list)

# %%
result
# Out:
# ['Good',
#  'Productive Training with clear explanation could require more reading material. Overall good and useful training.',
#  'Could understand the basics of boom and feel confident for certification and to work on boom fool as well. Thanks.',
#  'Useful training intern of project & Business requirement excellent use case materials & senarios . overall this is good',
#  'The Training provided by krishna sir was excellent.',
#  'The 4 days training course was very effective. the trainer played a key role in explained each concept in dept.',
#  'Great',
#  'Teaching method and examples were good. Pace was bit fast & Training material is missing content intro page but overall it was a great experience.',
#  'Trainer is very professional and effective speaker. we will able to group data as much as possible interactive session made it a success.',
#  'Excellent',
#  'Well planed course and Could relate with real time examples at work.',
#  'Well explained course with real time examples. which helped me to relate with.',
#  'Well organized , easy to understand.',
#  'The Course was very effective & useful instructor gave real time examples & We could connect the concepts well.',
#  'The PMP training was very engaging and the concepts were very clearly explained with examples by Krishna.',
#  'Well Structured Training, easy to understand & Good online Support.',
#  'Very valuable training. Krishna sir provided very good examples which could be easily relates to the topics.',
#  'Course has been structured from pm book is easy to understand.',
#  'Training Provided was excellent, all key areas were covered with clear explanation & Relevant Examples.',
#  'Training & Course was really good . overall good training.',
#  'It was an excellent experience. cleared lot of my doubts.very useful training for the people who will appear in pmp exam. Methodology used in the Training was clear and interactive.',
#  'Excellent Training by Mr. Krishna , Provided good examples. And went in depth of each knowledge area and process.',
#  'Covered most of the topics.',
#  'Subject pm book is very good but krishna sir did the job well.',
#  "Training on PMP was good . Clear examples was given against each KA's & PG's.",
#  'It is a well organised and well structured course. The teaching method of krishna sir is very interactive.',
#  'The Training was quite help full. Really appreciate Krishna sir efforts towards individual student.',
#  'Training was good &well organized.',
#  'It is a very good and useful course. Through which one can develop their skill set and career growth.',
#  'Very structured program and the process very effective.',
#  'The trainer is interactive and knowledgeable on the area of pmp.',
#  'Training was through and concise.',
#  'Effective, Interactive, Planed coaching approach.',
#  'Very well organized and effective.',
#  'Very Well Structured/ With good real time examples.',
#  'Training was good informative.',
#  'Course is very good.',
#  'Training was good. Duration can be extended & add more hands on exercises.',
#  'kiran Knows the topic very will and he explained the fundamentals and advanced methods , What Why and Where use it. Overall it was very good',
#  'It is good. the trainer was food presentation skills.',
#  'this training on advanced python helped me to concert my on the usage of python . Also helps to understand the various aspects of machine learning.',
#  'Good Understanding on the data science & machine Learning concepts.',
#  'Good Training Science I was not having any background of AI. Concepts are very well arranged and presented. Kiran is a good faculty.',
#  'The course content was very good. Given summary of how to start project on data scioner and machine learning.',
#  'Coursed covered basics of python for half of the day.And will go to the subject . It is Good.',
#  'Training was very informative and well presented.',
#  'Training was good.',
#  'The Course is Excellent point to start journey to Data science.',
#  'Excellent Training',
#  'He has good Knowledge on',
#  'Very Good',
#  'Great explanation and With easy example to understand the topic and make a happy nature to make the session interested',
#  'It Was very nice faulty has explained us to teach and topic very well and with all the practical in day to day life . Finally the entire session was really good',
#  'The Training is Very helpful Because it guides and teach you the value of business.',
#  'The course is designed in very organize structure and it contain many learning elements. Also we learned many points in detailed manner . thanks',
#  'Overall course content and training was excellent good teaching techniques',
#  'Training was good , But not very advanced as expected.The topic was elaborated for the beginners to intermediate but some more advanced topics lick service meshes deep dive into monitoring ect.',
#  'Course is good for the developing with a basic understanding of Kubernetes .',
#  'Training was good',
#  'Training was good ,get the good hands an kubernetes concepts. and more interactive.',
#  'Course was great, one suggestion is to share the presentation deck for each day at the end of training day.',
#  'the training was good. we learn multiple techniques and it is useful to our development',
#  'Overall the training was good. Less time to allocated. Project Management tool become only those are working on the tool.',
#  'Overall the training was good the course give a good overview of project management. I have learnt lot of new information . Trainer did an excellent gob.',
#  'IT Good & detailed out.',
#  'It was excellent . Paced it well and explained with suitable examples. Great session with would help me to get certified on PMP.',
#  'Training was really good and helpful . Krishna helped us to solve so many doubts .Training has been provided on tilling the application also which is relay applicable.',
#  '4 days PMP training was valuable & each topic has been explained neither examples. Which helps to understand the concept',
#  'The Training is good. covered all aspects in depth.',
#  'Valuable & effective , good insight of the tools & techniques',
#  'Really liked the interactive training given by Mr . Krishna , It helped in understanding the concept and easy to remember.',
#  'Overall good',
#  'Ram was best on his capability & skill got good no of stacking point also to have more trainer like him',
#  'IT was training with words learn with fun excellent examples given.',
#  'Course content is good the faculty who came here was god &delivered the thing in a practical manner.',
#  'Training course was good and the topic were explained clearly.',
#  'Very good training . Excellent in communication and in engaging the audiance',
#  'Training was very useful & delivered good understanding about the subject.',
#  'Training session was good and very informative. It will help me enhancing my skill and knowledge in my professional career.',
#  '"It was good and informative\ncontains good examples to explain concepts"',
#  '"The training is must value add and well explained to enhance the device skills\nIt will motivate to perform best practices in organization in day to day basis of service delivery."',
#  'Training content was very subjective and easy to understand. I learn more new things which i never haired in the industry. It was fantastic way sir delivered every point of course.',
#  'Much needed training provided by Mr.Ram Tavva. I appreciate the efforts he put to teach us. Wish him best and best time ahead in future with training.',
#  'Received good knowledge about handling and improving our work and how to implement new things. in terms of IT concerns.',
#  'Training course was made simple and very easy to understand ,It was made more practical approach and faculty made us more engaging with some beautiful examples.',
#  'The training was clear, concise with good amount of depth in terms of topics coverage. I find it very useful and it will help me in doing my job effectively. I find Ram really friendly and knowledgeable.',
#  'Practical fun with learning more examples will make it excellent course.',
#  'It was well organised & content was relevant to my current project.',
#  'Good Session . Very informative & effective.',
#  'Excellent workshop . Very relevant . Super feedback mechanism with view recording',
#  'training is very interactive, Live examples made the process understand clearly. material was very good',
#  'Completed pmp training ,Great session , Good experience',
#  '"The training was good"',
#  'excellent one,Good Delivered',
#  'Good Training experience',
#  'Excellent , Training was a good',
#  'Excellent Training session & Special thanks to krishna.',
#  'Very interactive & engaging training',
#  'Training was very helpful in understanding the concept of PMP class room training by Krishna gave insight to the concept & also how to prepare for exam.',
#  'The training provided was very helpful , effective and reliable . Interactive session',
#  'Valuable & Effective , Good insight of the tools & techniques',
#  'Course material was very apt to prepare for pmp certification and also from an overall knowledge perspective. Trainer was very patient,highly knowledgeable & kept the course to be interactive & interested.',
#  'Excellent & easy to understand, Mr. Krishna us understand each module with simple & precise examples for our better understanding . Thanking you sir.',
#  'PMP Training by Krishna was well served & Really gaining. The concepts delivered were clear and resources used matched excellence. Very informative.',
#  'PMP training was really good by Krishna sir.',
#  'Good knowledge sharing and to course on pmp content.',
#  'The Training was 4 days and it was really nice training with the peoples . Krishna has a really great trainer. I enjoyed the session and learning.',
#  'Good training covering all aspects of project management.',
#  'It was nice learning many things The training was good.',
#  'Training was structured & Krishna sir was explained everything well with good examples.',
#  'The training course is well structured.',
#  'The class room Training was conducted thoroughly professionally . I was enjoyable . It provided insight into the concepts & also to approach the exam preparation.',
#  'PMP class room training very impressed by the level dedication by the faculty Krishna sir and his excellent method of explaining concepts very interactive and effective',
#  'Overall experience was good, Trainer should provide lot more examples which help a lot to understand.',
#  'Very good knowledge and interactive session.',
#  'good training The examples provided during the session helped a lot',
#  '"Course was very good , Preparation guide and preparation tips are good.\nhe explain practical examples to make it even more effective."',
#  'The work shop was informative Real time knowledge examples help full in computer courses.',
#  'Got covered all process with valid examples and i am very much satisfied.',
#  'Nicely conducted course',
#  'Excellent course by excellent instructor . E- learning support is a great thing',
#  'Krishna explained each & every topic with more clarity & live examples . He is very helpful in teaching every small doubts involved & also in the application Process.',
#  'Enough content available.',
#  'PMP training was very satisfactory . The knowledge shared was an good examples and very easy to understand . overall the training was good.',
#  'Very interactive & good training',
#  'Good , Intensive training by Mr Krishna , Supporting staff.',
#  'Training is Good',
#  'The PMP Training was good with relevant examples',
#  'Very good, Highly interactive session, easy to understood and explained with relevant examples , Trainer is highly knowledgeable and having good exposure.',
#  'The course was very organized and learn more on PMP',
#  'It is well managed ,Helpful Training session where most of the doubts are clarified Get a better idea about PMP',
#  'Excellent training by Krishna.',
#  'I attended the 4 days PMP training conducted by Krishna . It was a great.',
#  'The training was excellent with good supporting staff Great teaching',
#  'The 4 days training program was good. Covered all the processes . Also learned the way forward to study fir certification',
#  'Good training . Request to have more scenarios on EVM and contract type in procurement management.',
#  'It was really good, real time examples are easy to relate things to concept',
#  'It was a very good training. Trainer krishna was interesting And helpful throughout',
#  'It was very good',
#  'The training have been very effective as it would be directly motivating in developing good service skill and helping me in improving my way that can be externally used to meet business requirements.',
#  'The training is good and excellent. We learned much things and process about it and its values for organization & business.',
#  'The training was great.',
#  'Excellent faculty, The way to train was ultimate. The presentation and the training course is very good and appropriate.',
#  'Training course has been very much informative and interactively.',
#  'Excellent training on ITIL with good examples',
#  'It was great, very helpfull',
#  'Course was very good, knowledgable',
#  'It was very good provided by Ram Tavva',
#  'Overall it was good knowledgeable course. Learnt new things.',
#  'Learnt many things whish will be useful for future. Trainer is excelent interesting training. Thank you',
#  'Great nice trainer',
#  'Training was very intractive able to make things easy to understand. Able to give examples related to current life.Over all the training is best.',
#  'the training have been very effective as it would be directly motivating in developing good service skill and helping me in improving my way that can be externally used to meet business requirements.',
#  'It was good training.',
#  'MS Training by Excelr was in depth to the subject and the trainer had complete knowledge and Profesinal Experience',
#  'Its very useful to relevant job',
#  'Training is fine.Content and duration could have been made extended more instead of two days.Hard copy study material other than there is also regular.',
#  'Came as novice user in MS.P, Now I can confidently say I know the basics and with real time practice. .I Can be more confident in the tool. Training was well structured and the faculty is highly experienced with the real time industrial knowledge.Which helps in depth understanding.',
#  'Great trainer, explained each and every doubt and always ready for open discussions',
#  'Excellent coverage of topics with some good examples',
#  'Good and effective',
#  'Great material, concepts explained very well. Very helpful',
#  'Good Training session',
#  'Worth spending,Boosts confidence,concepts with day to day examples',
#  'Excellent training.Krishna has made it more interesting and simple with practical examples.',
#  'Course was very good.Though the content being dry,Krishna made it very interactive session and I could gain the required Knowledge.',
#  'It was very interactive specially the faculty Mr. Krishna who is very experienced and make subject very easy by giving real life examples.',
#  'Excellent Trainer,Helped upto understandthings in a simply way',
#  'Simply I would say "EXCELLENT"',
#  'Excellent Training.Thanks to the institute & faculty(Krishna sir) for such a wonderful training.Thanks to Lekshmi for coordinating the training.',
#  'Good Paced training.Covers the required content.',
#  'It was very interactive session and got all doubts and queries cleared by the trainer',
#  'It eases the PMP preparation from daily busy schedule.Given right direction to achieve the goal.Trainer guidance is really valuable.',
#  'Training conducted on PMP was easy to understand and approach was excellent.',
#  'The training is helpful and in detail.',
#  'Well planned,Well paced and good training.',
#  'Krishna was too good in explaining the complete PMP content.Course content was also excellent. He carries good understanding and relate to the real time scenario.',
#  'Perfect.Exceeded my expectations.',
#  'Good understanding of the course was provided that will help clear the concepts.',
#  'Very Good.Helped in proper arrangement of 12 years experience in a sequencial manner.',
#  'Well structured ,organized and delivered. We were able to understand the key concepts well. Good examples helped to connect topics to real life.',
#  'The course was excellent and effective',
#  'Good environment for these who are taking to cruck the PMP examination first attempt.Krishna sir will do the course review in a well manner and knowledgeble',
#  'Course content were explained well, considering the overall requirement to be a PMP professional methods and techniques were well explained.',
#  'Overall experience was really good.',
#  'ExcelR has a standard approach training.The students ExcelR supports and helps till the crack the exam.Training is excellent ,standardised ,straight apporach.',
#  'It was good insight to project management,Good Directions.',
#  'It was good training of 4 days(2 weekends).Topics covered with logical order.Facility provided was good.',
#  'It was very useful and resourceful sevion indeed.',
#  'Very happy with direct classes.But online videos pauses needs to be cut shortened.',
#  'Training was very good with good examples',
#  'Training was awesome.Really appreciate Mr.Krishna',
#  'Very good knowledge transfes on each process',
#  'Training was excellent. Training gave attention to detail in all the knowledge areas.',
#  'Training is given Excellent way and well connecting with real time examples.',
#  'Training Program is satisfactory. Instructor covered the session within a time frame and with good examples.',
#  'Excellent delivery techniques by the trainer. All clarifications were immediate with real time examples.',
#  'It is very useful and able to understand the project management concepts.I have clearly met my expectations by attending the training.',
#  'Amazing Presentation skills. But the pace of the course should be lowered.',
#  'Awesome',
#  'Course Content is very well organized.Trainer is very experienced and we can feel the experience in his content delivering. Very professional faculty and support staffs.I will take this as good starting point for my PMP Journey.',
#  'Good Knowledge & points wise explanation was very clear.Clearly helps us to start the preparation. Very effective approach in delivering',
#  'Overall training was really good.Faculty is good, but facility is ok.If after every session an online short exam be kept, that would be really great.',
#  'Very good and informative',
#  'Very Good ,Informative',
#  'Training program was very good.Got detail insight of the subject.Thank You',
#  'Trainer Mr.Krishna is very well versed of PMP concepts. During the sessions, he cited day to day life examples which made the session very interesting and learning a cakewalk.Overall great learning experience.',
#  'Overall training is very good and useful.I got what I expected.',
#  'Very useful to enhance the project management knowledge and to become PMP course materials are very simple and easy to understand.',
#  'Overall it was a nice experience.Very informative training.',
#  'Excellent Course Content.Covers basics of statistical terms and data analysis.Got a newer perspective to analyse data in our formation and to enhance the product development efficiencies.',
#  'Training was found to be verygood and may help us in analyzing our data in a good way.',
#  'Topics covered are very interesting.But can be made tailored according to the customer data.',
#  'Content was involved from fundamentals to little advancement in the data analysis.It was worth to attend the course.',
#  'Training was very good.It covered most of the relevant topics.',
#  'I have attended 2 days PMI - ACP training session at ExcelR. Trainer Ram Tavva well trained us. He has excellent knowledge of the subject.',
#  'Good,Can be shortened by half a day',
#  'Training course is very well organized with clear output of the agenda',
#  'Training was very good.Clarifications are done better. Nice Presentation.',
#  'Trainer Ram Tavva was the excellent knowledge on the subject and teaches with good examples to understand.',
#  'Faculty Ram Tavva shared knowledge is very good and polite.Clarified the doubts .Excellent training presenting skills was very good.Finally this is very good and helped to us.',
#  'Need to be explained by using IT related scenarios instead of manufacturing & construcions.Otherwise overall very good and understandable.',
#  'Training was very interesting & informative.',
#  'Training was good, Explained with examples very interesting.Not get bored.Good Session.',
#  'The faculty was well aware of the concepts and was patient enough to listen to queries and answer them.',
#  'Before training course I dont know agile methodology. After completing then I know good about the agile methodology.',
#  'Course content was very good.The faculty is pretty aware about the concept the concept and patient enough to listen and answer the queries.The course was good enough to implement at work.',
#  'Training was very satisfied and was more interactive where every person can understands the concept well.Also the trainer has gave some excitement so that we learn and understand more.',
#  'Training provided by the faculty was very good. Gave a thorough knowledge on agile from base, as a fresher also it was really helpful and understandable training.',
#  'It is very useful to us what has use to the planning the project as some advantage',
#  'He teached very nice way and took live examples.',
#  'Training was good and its superb good Explanations.',
#  'As a fresher I got good knowledge about agile.',
#  'Good Coverage of the Examination syllabus.',
#  'Good interactive training session. organized and planned teaching. Very much effective. Overall very good techniques to teach these theoretical courses',
#  'Very good course content.Structured, very accommodating. Krishna sir has a very good teaching technique.',
#  "The course was very well structured/organized. Trainer understood the student's requirement and clearly explained the concepts.I could easily grasp the concepts.",
#  'Training content and delivery was very good.Krishna explained the processes with good examples which helps to grasp the concept.',
#  'Training provided by krishna was excellent',
#  'Training was effective,preuse and valuable to the core .happy with the trainer and his method of training.',
#  'It is really a wonderful training.Trainer gave each and every process thoroughly with examples.Every parts of exam he explain in detail.Krishna sir is extrordinary in PMP Training',
#  'The training was very good, especially the trainer Mr.Krishna course topics were well covered and now I have confidence that I will clear the certification.',
#  'Training was very much informative with live examples on each concepts.',
#  'Training Provided was upto the mark.',
#  'Training was very informative and helpful. Well organised and structured.',
#  'Training was interactive and well structured. Explained all the aspect in detail.',
#  'The training was really informative and linked with many real examples.',
#  'Training was satisfactory.',
#  'It was a great experience with ExcelR.I appreciate the trainer Mr,Krishna for his explanation, examples and doubt clearance.',
#  'Excellent training Delivery.Very Professional delivery course material and the contents chosen as part of explanation was apt.',
#  'It was very good. Good introduction and complete guide to get the PMP.',
#  "It's a Good Learning Experience.",
#  'Exellent training provided by Krishna and ExcelR Team.',
#  'The training met my objectives.The instructor communicated clearly and used relevant examples.',
#  'Very Structured training, Krishna is very knowledgeable and the class is lively.',
#  'The Course was really good which has given me a breakthrough on the subject matter and Krishna sir has very patiently given clarity on the subject matter which has motivated me to do the certification',
#  'It was nice training ever attended. It explores the different knowledge area of project management.',
#  'Good Training conducted and advised for exam preparations.',
#  'All Sessions were really good with interactions and examples.material provided is also good for covering the required details and information.',
#  'Awesome,No Comment on excellence.',
#  'The training was very effective. Even though the subject is very deep and full of theories, the trainer is able to keep the session in such a way that I was able to be attentive throughout. The breaks are very thoughtfully done.',
#  'Excellent coaching, the examples used were helpful to understand. Heartfelt Thanks to Mr.Krishna & the ExcelR team.',
#  'Well paced, Structured training. Covered all the areas quite well. Trainer Krishnam Raj sir has very good command over the topics.',
#  'Excellent Training, Student friendly Trainer',
#  'Training was good, Well paced and helpful.',
#  'Training made me realize the easiest way of preparing the methods,examples,clarity provided to us was very useful.Simple language was a highlight.Trainer was giving very simple examples which made easy.',
#  'Interesting and really motivating. As the trainer convince, he is available to help us.',
#  'It was good& detailed training followed by practical examples. Liked the way each chapter was co-related with another & properly explained with logic.',
#  'Training was delivered with good examples.Easier to connect to the subject.',
#  'Very good interactive sessions.',
#  'Course was not interactive but the content was very good.It would have been better to let the instructor explain instead of continuous videos . Trainer was excellent though.',
#  'Excellent training with real world scenario empowered with recommended tools,skills. Interactive and time management was excellent.Enjoyed!!!',
#  'The training was very interactive and intense. I have gained lot of knowledge on Agile and its principles.Hoping to attend PMP training as well in the near future.',
#  'Trainer is very knowledge and peomising.Good Communication skills.In depth knowledge on concept .Useful course materials.',
#  'Very good and learnt a lot from Ram.It was very helpful to understand training completely.',
#  'Course was well conducted.Concept were made clear. But at the end felt the topics were slightly rushed.',
#  'Training was excellent.Got confidence on passing the exam.',
#  'The training definitely serves the complete expectations.The trainer is very well experienced and helps understand all the concepts with ease.Would be more good if the duration was distributed to 3-4 days followed by assessment.',
#  'It was overall good training session emphasizing on the basic guidewire concepts and workflow.',
#  'The material covered almost all the important concepts of guidewire and the trainer has explained thoroughly as expected within the stipulated time. The trainer cleared the basic concepts too and I had a great learning time.',
#  'The training was useful in setting up the foundation for Guidewire.',
#  'It was really very good, informative with clarity.',
#  'It was good.',
#  'It is good',
#  'Very helpful & could gain knowledge. Very subjective for day to day work.',
#  'Very well articulated and explained.',
#  'Everything was good, covered all the topics. Could teach more about R programming concepts were explained very clearly.',
#  'Course has been satisfactory.The entire range of topics were discussed.Faculty was good at handling doubts. However the course can be improved by making weekly assgnment compulsory.',
#  'Overall course is good,but the place is very high.If the pace can slowered a bit then it will be very good. Knowledge of faculty is very good.',
#  "This course nowadays it's trending course,lectures are good,good teaching. It is so useful to us.",
#  'The training was very good.But if more classroom training. So it helps very much to us.Rest of things are very good about faculty and institute.',
#  'Very good training provided by the trainer.Made us learn complex techniques with ease and made the concepts clear.',
#  'Course has been good,training provided was apt and well explained by Mr.Dinesh.',
#  'Very Good,explanation with examples.Informative,Get to know new terminology.',
#  'Excellent and very useful.Gained knowledge about ITIL in two days.The way trainer explained in excellent and very easy to understand.',
#  'This course would really help any kind of Business to be managed in a better structure.',
#  'It was understandable session with live references and incidents.Which helped in understanding. Also appreciate the additional info on ITIL Foundation.',
#  'Very Much informative',
#  'Tranier giving with best examples and understand the process of concepts.',
#  'Explained with simple and easy examples.',
#  'Understd the process of service in systematic manner',
#  'It was very good, very interactive and will be useful in our day to day activities.',
#  'Session wasgood & interesting. As a young support engineer it given more knowledge on how to manage the things.',
#  'Very Well Conducted course with practical and relevant examples & discussions.Keep it up.',
#  '"Trainer is a very professional and exlained in a very good way.Course contents were very helpful in our daily activities.\n"',
#  'It was very much relevant for IT people.It was very useful.',
#  'Informative and Useful',
#  'The course training given with live examples made me easy to understand-Thanks.',
#  'Good and Interactive, trainer provided the the knowledge required.',
#  'Training was good, Trainer gave live examples to make us understand the concepts worth attending it.',
#  'Good With real wotld examples, the session was intensity and informative.',
#  'Training was good, but more and more practical session should be done to get the grip on the subject.',
#  'Sir, tremending set of courses influnce to basic level with high altitude. So we can understand fairly, clearly concept wise. LMS content and online webinars helps',
#  'Best and quality training course.Best place to learn data science.Course material and course contents are very nice and relevant.Trainer have good knowledge.',
#  "It's good, as the content is huge, need the additional classes or you should provide one week of gap,so that working people will concentrate and ask the questions as well. Need more assistance as the subject is huge.",
#  'Overall course content and support is good.But we spent more on theory rather application of the theory, which is more important for Data Science. Need more Scenarios or classroom examples and length of the classroom is more.Anything horizontal with less rows would be better.',
#  'Teaching was excellent.Course was well structural. Mostly was focus on theory, it would have been more better with practical classes. Great support with materials too. Overall 4/5.',
#  "Course was well designed & the concepts given by faculty is excellent,but the coding part explanation would have been nice, although time frame won't permit. I recommend my friends very likely.",
#  "Mentor is good in delivering the subject in understandable way. Only difficulties faced ,more concepts covered in same day,couldn't able to get when to apply which concepts.If 3 or 4 data sets would solved in five by mentor using different techniques is used for same data sets.",
#  'It was very good and interactive session, It helped to relate the real time things in the office environment.',
#  'Excellent tutor,having in depth knowledge of the subjectand very engaging during the training.',
#  'Excellent Training. Gave very good insight on how to implement CSI & how an organization can benefit from its implementation. Trainer was highly experienced.',
#  'The training provided me an understanding of one can cut across the IT life cycles and bring in an improvement for the organization',
#  'Very interactive',
#  'Overall satisfied with training and the discipline',
#  'Interactive,Knowledgeable faculty',
#  'PMP training was simple ,effective and Interactive',
#  'Training was effective to prepare for final exam-PMP',
#  'Concepts were really well explained, trainer was excellent & co-operative. Overall had a great experience.',
#  'Krishnam Raj Sir has very good knowledge on PMP Course.I love the way he teaches the course partical.',
#  'Matured approach by Trainer.Students friendly methodologies handled during training.',
#  'Classes were really informative and interactive',
#  'Good,Covered the required topics in good planned Manner.',
#  'Course is excellent.Mr.Krishnam raj explained all the area with simple and good example.Which help me to understood the concept easily.',
#  'Overall training is god and gave us good knowledge of Project Management best practices.',
#  'Training was very good.',
#  'It was good and explained properly.',
#  'PMP training is very useful and explained with real time scenario.',
#  'Excellent Training (Appreciates if more Q and A session could be arranged)',
#  'Excellent training.Trainer Krishna could relate us to real world examples and take us through all knowledge areas at a comfortable and understanding face.Rita Mulcay material was promised as part of the course.But the quality of the material is not good.',
#  'Overall good,Feel like more time will be good.',
#  'Training on PMP all the processes and groups with knowledge areas is very layman understandable.Krishnam Raj is very Knowledgable person and he explained in realistic examples.',
#  'Good Training and was very helpful.',
#  'Training was very informative and very clearly thought in the short available time.Now the confidence and clarity to face exam is high.',
#  "Trainer was wonderful.Provided examples withlayman team& covered all the KA's effectively.",
#  'Good Instructor with required input.',
#  'The training was done very well with examples and explained very well.Thank you very much',
#  'Very Good for initial start,I strongly recommend this classroom training session',
#  'Training was good and helped us understand all KA',
#  'Interactive Training session,efficiently conducted.',
#  'I have been searching for good institutes from last 2-3 months.After completing the PMP course in Excelr,felt the search was worth it.Krishna has indepth knowledge on all topics of PMP.He has covered all process thouroughly and helped to understand clearly',
#  'Best Experience in learning',
#  'Training delivered exceeds expectation',
#  'Mr.Krishna is much experience trainer and provided good training for PMP.',
#  'Very professional approach.Well conducted classroom sessions.',
#  'Good,with clarity and examples.Krishnam Raj is a SME on PMP and has given us clear picture of the subject',
#  'Training was very good with lots of real time examples and working on problems as given in exam,which increases on confidence to face the exam.',
#  'Content is fruitful and the way explaining the concepts also good.',
#  'Got clarified weak points and confusion on process/knowledge areas.',
#  'Excellent Training course.Trainer has explained everything with examples.',
#  'The facilitator was very knowledgeable and warm person and could be reachable for any help and has good hold on the subject.',
#  'The information provided and explained by trainer was excellent. Which is easy to remember and attempt the PMP certification',
#  'Training with Krishna gave a great insight on the subject. Very interactive.',
#  'The flow of course and method of engaging in learning is excellent.',
#  'Training being conducted in a very well structured manner by the PMP Guru - Krishnam Raj',
#  'Training was good, detailed, helped me understand about pmp,and also will help in my daily job activities.Great Work.!!!',
#  'It was a good Experience.It was awesome training.',
#  'I thoroughly enjoyedthe course, Great insights through practical examples.',
#  'Good content coverage, good insights into PMP process coupled with subject knowledge of the trainer, Mr.Krishnam Raj.',
#  'Very well structured& shared what is needed to clear the certification',
#  'Excellent with good case studies.',
#  "Very good interactive sessions. Touched upon industry examples for KA's",
#  'It was good.Suggestions: Please add few more numerical and practice question during sessions?',
#  'Training was very helpful',
#  'A little slow pace,can be followed, but again time has to be managed too.',
#  "Good training with material & trainer behaviour. Training room's Infra could have been better for long sitting.",
#  'Very good session and very profession instructor Mr.Krishnam Raj. it was a tremendous experience overall.',
#  'Training course is good.It helps me to understand the subject.Overall It is a great session',
#  'Total processes can be linked with one generalised project.',
#  'Good-PMP training Course',
#  'Excellent training session.Krishna made it as interactive as possible.I would definitely recommend the institute to anyone who needs to get certified.',
#  'Training was very motivating.Trainer has the good experience and thorough on the subject',
#  'Good Paced training.Covers the required content well.',
#  'All are planned well,Each knowledge areas define in very good manner',
#  'Its really good training.Explained all the relevant topics thoroughly',
#  'It was a good training.Krishna Sir delivers the content very nice & in a way we can understand .It was a very Interactive session',
#  'Satisfactory',
#  'Very informative and interesting',
#  'Got the very good understanding of the PMP in detail.',
#  '"It was helpful,Hopefully will be able to clear my certification on April 28th\n"',
#  'Excellent training happy with the learning krishna is an exceptional trainer with great delivery skills',
#  'Training on PMP .Got good understanding which help understand concepts.Krishna explained the way further helps to explore more,highly recommended to go for it',
#  'The training was very helpful to understand the PMP concepts.Trainer Mr Krishna was very good in making the concepts clear.He also advised on many other things eg :How to clear the exam(road map)',
#  'The pmp training helped me in understanding concepts.Looking forward to your support in exam preparation',
#  'Extremely effective course.Easy understanding with day to day examples.Course duration can be increased to 5 days in order for the information to get assimilated',
#  'BEEN AN AWESOME EXPERIENCE AND THE ENTIRE COURSE WAS DELIVERED IN A FASHION THAT ENTIRE CONCEPT WAS MOLESTED CLEARLY AND EFFECTIVELY',
#  'IN DETAILS STUDY. INTERACTIVE',
#  '"EXCELLENT TRAINING BY TRAINER KRISHNAMRAJ\nAMBIANCE IS GOOD."',
#  'TRAINING QUALITY, AND TOPICS COVERAGE WAS REALLY GOOD. THE TRAINER IS KNOWLEDGEABLE AND MAKES LEARNING EASIER. OVERALL IT WAS WELL PLANED MANAGED AND DELIVERED.',
#  '"FACILITY AND FACULTY BOTH ARE AD-EQUATION\nCLASS ROOM TRAINING ALWAYS HAS A GOOD EFFECT ON LEARNING\nKRISHNA HAS FULFILLED THE NEED AND COMMITMENT "',
#  'VERY USEFUL TRAINING, TRAINER BROKE DOWN SOME OFF THE TOUGHS CONCEPTS , IT SIMPLE ENGLISH MR. KRISHNA GIVE LOT OF SAMPLES AND ENSURED THAT AL OF US UNDERSTAND THIS SUBJECT. VERY INTERACTIVE CLEAR TRAINING IMPARTED.',
#  'Good training ,Facility is not so great',
#  'Training was OK. Concepts needed more in depth clarification and study and demostration through examples during discussions',
#  'The trainers had a vast knowledge of the domain however the agenda and structure of the training could be improved: I think we insisted a bit too much on the very basics (swagger generation, endpoint testing, unit testing) and too little on the actual microservice. Also for future trainings I would recommend having all resources in a Git repository and each day on a branch, so we starting on branch day1, and we try to code this branch to get even with branch day2. I would have liked to insist more on microservice design patterns, architecture and maybe even break down a monolith app into microservices.',
#  'This course helps me to understand better the basics of all the infra services and what the services offer; helps me to understand better the microservices architecture, how the services can communicate one to each other. I understood what is Swagger, what means a Swagger specification file, how can be generated and how it helps. I learnt many new things/technologies like Eureka, Zuul, Kibana, how they can do, what are their roles and how work together.',
#  'It was very good experience but LMS details shared but late otherwise over all is good.',
#  'The course was provided in professional way by quoting the real world examples. Also the trainer "Ram" was kind and patience enough to handle all the queries.',
#  'Very Interactive,hearing skills ,thanks to anoopp',
#  'Very Interesting',
#  'Excellent training.The Explanation of each topic is very nice.',
#  'The training was great.Very informative and interactive.',
#  'Very good,interesting and easy to follow',
#  'Content is relevant and useful.The way of presenting is good.Time is not sufficient to cover all the areas',
#  'It was a very good training.Thank you for your wonderful training on ITIL',
#  'Overall course went well.One small suggestion is to link the examples with IT as well.Also discussing mock test before exam will increase candidate confidence.',
#  'Training is Good. Faculty is explaining the concepts in a very good way',
#  'The trainer was good.',
#  'VERY GOOD -GAINED KNOWLEDGE ABOUT AGILE CONCEPTS',
#  'Require more practice sessions in class room training',
#  'Overall Good. By the end of the course kindly provide the whole lot of material together, instead of posting regularly in drive.',
#  'Overall training can be rated as average. Scenario based examples can help to improve. Further, time to be spent on different topics can be better planned. More focus on unique functionalities of Tabluea can be helpful.',
#  'The way it was designed for the course it was not covered.By designed course my expectation was different.Basically my expectation was how Tableau is different than excel and other software.',
#  "Thankyou very much ExcelR for providing such an interactive sessions .I sincerely appreciate Krishna Sir's dedication to his students .He was very patient throughout the training",
#  'Faculty was good,Teaching was nice',
#  'It was useful & industry related .Made easy to understand',
#  'Impressive training,Good to have here',
#  'The course was a real refresher for the pmp exam preparation',
#  '"Very good overview\nMore examples would have helped\nSession with short tests & quiz will help "',
#  'Excellent training.I would recommend people for this .Only suggestion i have is "Have more examples & provide more shortcuts or technique to remember the some critical concepts',
#  'Mr Yogesh was very good teacher ,Attention to detail as well as attention to students which is pluspoint in him & very good examples for every topic is provided ,Good Recap; Overall very good only one suggestions :For peoples with different background & qualification cooling seems to be difficult & hard to understand so please make it in simple way of teaching if possible',
#  'The arrangements were good and course material is ok.',
#  'Excellent.',
#  'Training was Excellent.',
#  'Training was well phased across 4 days.',
#  'It was quite helpful in understanding the way PMP should be looked at and gave us the direction not only towards the certification but also the very concept of Project Management.',
#  '"A good training covering the basics of PMP course. The Trainers are very cooperative and good in their knowledge and skills.\n"',
#  'Brilliant Training and Coordination Quality training and excellent customer service.',
#  '"It was extremely helpful to understand the Project Management.\nQuality of the content was excellent.\nNice balance of theory and practice."',
#  '"It is overall good. Trainers and training material is good enough to understand.\nTrainers has good knowledge of the subject."',
#  'Very great experience to be in this Training . The faculty has touch based the complex topics with simple day to day example to make it PMP look simple and easy to digest . I highly recommend them and strongly stand with their contributions',
#  '"Training was good, Trainer was very good and clear in concept.\nwhole ExcelR team is very helpful.\nApart from videos if they can provide some reading material , multiple type questions for preparation."',
#  'One of the best educational training institute with good trainers. I highly recommend this training institute.',
#  'GOOD',
#  'Training was quite instructive and helpful to understand the concepts of RMP. Trainer explained well with providing good examples to understand.',
#  'Training was good, but if you could provide the material (Not excelr material) that would be great. Each and every chapter there should have been some exercises to practice.',
#  '"Overall ExcelR Solution is very good option to choose and seek assistance on certification. My online PMP training is really great and covered all topics and real life examples of project management.\nOnline training video and simulation questions are very helpful and i reviewed them couple of times conveniently 24X7. Thanks for ExcelR team to proving such a dynamic environment to get my PMP credential. "',
#  'Very good training. Trainer provided very good n relevant examples to understand the concept. made the class very interesting n interactive.',
#  'Good, Recommended before writing the PMP exam.',
#  'Overall training was good.',
#  '"Training is very methodical. concept explanation is very clear and examples help in easy understanding."',
#  'The training was really good, the concepts are thoroughly explained with examples to understand . The trainers are very help-full .',
#  'The course is good. A perfect kickstart for a novice',
#  'its good and the training ways are good, way of making the concept clear with appropriate examples are outstanding.',
#  'Excellent, i like the examples provided, made me understand tough concepts with easy examples',
#  'Concise, could be more elaborate. LMS is good .',
#  'It was good !!',
#  'Excellent training..keep up the good work!!!',
#  'Training was good and informative. Good examples provided during the training to help relate to ITIL scenarios.',
#  'The training and the material are good. The facilities at the training institute are good. The trainer is very punctual and the sessions are interactive with better examples.',
#  'Excellent in-detailed explanation of Project Management concepts by the trainer. Interactive sessions. Good training material provided by ExcelR. Would recommend ExcelR for PMP training.',
#  'Fruitful... Krishna was able to provide us real time examples which helped us in understanding the concepts easily',
#  'Training was really good. Examples quoted were easy to understand and pace of training was very much comfortable.',
#  'Overall training has been good and would also recommend to have questionnaire session to be conducted at the end of each knowledge area which can be effective.',
#  'Excellent, got clarity and knowledge regarding ITIL concepts.',
#  'Bharani has been an excellent trainer. The kind of serious institute has towards their students and they getting placed, has never seen this before with any of the training institutes. Thank You so much EXCELR',
#  'All the sessions in R and Tableau were very well explained.Also , I was able to contact both Bharani & Srinivas Sir whenever I had doubts.',
#  'Excellent training with lots of hands on excercise. Some good live project exposure too.',
#  'Overall training was very effective. It was worth spending a money. Covered maximum topics and concepts were explained beautifully by trainer.',
#  "The overall training was extremely good. No doubt it is definitely great value for money!! Bharani's knowledge levels on Data Science are really top-notch!! The advantage with ExceR is their trainers are people who have really worked in BA Industry or even currently managing consulting projects to world-class customers on Business Analytics. It greatly helps students to get a industry perspective of Data science domain and the practical issues those come across by excel-r, which may be given to students as case-studies. Overall truly happy and its a wonderful experience, which i surely recommend.. Thanks, Dr. Shajahan, PhD.",
# ...
#  'The training was good and informative.',
#  '"1.Good Training\n2.Satisfied with the training"',
#  'Very Good Training Plan and Trainer was very clear in putting concepts in a crisp way',
#  'Training is very useful and we have learnt about the easy methodologies for applying the process in our routine business works.',
#  'Very Good. Trainer was able to handle the crowd very professionaly and was easily approachable to clarify doubts. He quoted the live examples (online) which helped us to understand the concept easily.',
#  'Good interactive session. Overall it was good and useful',
#  '"The trainer is very knowledgeable and have a very good experience.\nHe evolved his own methods to train the tough parts.\nEven if I\'m new to the subject, I completed the training without having doubts."',
#  "It's good",
#  'good informative, even more interactive',
#  'Very useful training session',
#  '"Agile training is very use full to me, i came to know the clear methodology as a team how we have to take the work how to plan and how to implement the things and complete it in a given timelines.\nThis type of training\'s will help us to improve ourselves."',
#  'Training was very helpful in understanding the concepts.',
#  'Training was informative. Would have been more helpful if the examples were more related to the retail, IT, HR scenarios which would have helped associates in each field to better relate to their work field. Overall training can be rated good!',
#  'The overall training was good.',
#  'Overall PMP framework well articulated by Ram. Was able to connect to the concepts, processes, tools and techniques explained to my job area. Good practical examples were used with a fairly systematic approach on covering the topics',
#  'Interactive,knowledgeable and directive',
#  'Training was intensive and helpful to understand all the 10 Knowledge areas & 47 Processes',
#  'The training was very good .',
#  'Very engaging. Trainer kept everybody attentive !!',
#  'The trainer is very good . He explained with good examples and made easy to understand, All the inputs provided are good.',
#  'The training was very helpful for the daily business and I have learnt more than I expected in terms of IT processes, the trainer was excellent and kept the group active, thanks.',
#  'Great Experience. Very good trainer.',
#  'Training wa good could gain good understanding of the subject',
#  'Should be more practical and need be addressed matured example',
#  'Good place to learn. And more information about outside market',
#  'Excelr is the best place to have excellent quality training',
#  'Analytics Training was very much Interactive and nicely explained',
#  'Super training. Excellent work. I will recommend ExcelR',
#  'Excellent training. Experienced faculty and curriculum is also good',
#  'Excellent institute, trainers and traning process are really excellent. Thanks all the trainer..',
#  'Trainers are very skilled Experts in terms of training and practical experience they provide is awesome.They are really good advisers.They helped me in terms of professional career. I personally recommend people to join EXCELR Solutions for Data Sciences programme.',
#  'Great learning experience and very helpful after the course completion',
#  'Training was good and also staff is very knowledgeable',
#  'They have good coaching manual and videos for self learning apart from their in house training, which is good. Overall it was a good coaching for PMI ACP. Trainers are well trained on concepts and it interactions with the trainers was helpful.',
#  'Excelr Solutions is a nice place if you want to build data science as career option.',
#  'Currently associated with Excelr for data analytics course.. Excellent teaching...with free add-on sessions...gives you confidence to go ahead in the chosen field!!!',
#  'ExcelR provides the best training on data science at a reasonable price and with timing suitable for working professional.Their hands on approach and assignment give lot of confidence.',
#  'I had a very good learning experience with Excel R.. I liked their way of teaching and the course content was very good with relevant practical examples and real time business scenarios.I have taken Data Science course and it was very informative and very well presented by Sharat. I would like to thank Sharat for this wonderful session.',
#  'Very good trAINI9NG AND PERSONAL ATTENTION',
#  'Excellent training ,happy with the learning .Krishna is an exceptional trainer with grat delivery skills',
#  'Very efficient training.Good faculty,good faculty ,Very knowledgeable would be great if the training time was more then 4 days',
#  'THE TRAINING PROGRAM IS PACED PROPERLY AND QUITE HELPFUL IN UNDERSTANDING THE PMP CONCEPTS. THE FACULTY HAS BEEN VERY EFFICIENT IN DELIVERING THE COURSE.',
#  'The training was excellent. The trainer had a good knowledge over the subject and cited relevant examples.\nOverall this was a good training program.',
#  'The trainer was excellent . The overall training was a fun and learning experience.',
#  'The training was structured well,which explains all concepts very holistically followed by the quizzes,that helped me to internalize the knowledge very well',
#  'well structured training,ample knowledge transfer.',
#  'Fantastic way of explaining the concepts with real time scenorious',
#  'Very Well',
#  'Expert Explanation',
#  'Training was excellent. But a bit more indepth would be better',
#  'Very Interactive',
#  'Very good course. Indepth coverage of all topics',
#  'Excellent training sessions',
#  'Very nice sessions to attend. I am very happy in completing this course',
#  'Training was good. LMS was very helpful.The sessions were very elaborative',
#  'Trainer was excellent,explained the concepts very vell',
#  'Good learning. But was a bit fast',
#  'Training was very good and interactive. Very happy with the course',
#  'Very effective and interactive sessions',
#  'Training and the trainer were both good. But time was short',
#  'Was very effective,interactive and explanatory',
#  'Course is very good. Value for monry',
#  'Time was a bit less',
#  'Program was good but would be better with more practicals. Pace could be slow',
#  'Training covers a large amount of topics. But time is a bit less',
#  'Good. But it would be better with more real life examples',
#  'Faculty has great knowledge about the subject. He provided great real life examples',
#  'Course was very good and interactive. Trainer was very supportive and was able to give practical anecdotes',
#  'Very good,detailed,real life examples were provided',
#  'Good material,awesome knowledge,delivery was very good',
#  'Ram gave real life examples which helped relate to ITIL concepts',
#  'Very interactive session,gave lots of realtime IT related examples which helped me. Gained good knowledge on ST concepts',
#  'Very useful and very interactive classes',
#  'Sharat cored about making the course interesting and comprehensive to everyone. great attitude about teaching',
#  'As a working professionals, want to have same kind of material, that cores the main topic along with the memorized things and simple definitions. This is just advise overall training is satisfied',
#  'it is one of the best training institute in Hyderabad with professional facility',
#  'overall training is good, base studies to explain concepts are very well handed. I suggest to have this course for weeks instead of 5',
#  'Overall training is good. Recommended to explore each topic with examples',
#  'Course is structured in very sequencing manner and understanding is very good. Faculty is very good in delivering the content with relevant examples. personally i learnt lot and am confidence now in DS to implement',
#  'In-depth Knowledge of the subject with relevant Examples',
#  'Well planned and clear communication. very good',
#  'Training is very good and faculty has very good Parental skills. I have learnt many things, it is very helpful to me to qualify PMP exam',
#  'Extensive course material and good training sessions',
#  'very helpful and interactive topics were covered cocepts with relevant examples',
#  'ram is a very good coach and is clear on topics which helped to understanding principle and basics of acp i recomend ExcelR for such courses',
#  'Good program',
#  'Informative and concepts were thought.Videos were displayed which made understand better',
#  'Training is very informative with right kind of training materials and knowledgeable trainer',
#  'Good content,knowledgeable instruction,friendly and approachable staff. Overall good place',
#  'Training is very good and the course covers all important topics. It is very useful for project management',
#  'Very useful training to gain knowledge',
#  'The course was designed in a very good way.The trainer explained each cocept with good amount of examples to understand',
#  'Training was clear. Learning was easy and fun',
#  'This training was of great value.Thank you',
#  'Clear and descriptive training on each subject',
#  'Excellent training but needs more time',
#  'Content was very good and helpful.Trainer was very and understandable',
#  'Training was good but duration was short',
#  'Training and content was good.',
#  'Training is conducted in a very good manner so that all understand',
#  'Good and well organized',
#  'One extra day would be better',
#  'Pace is a bit fast',
#  'Course should be for 3 days',
#  'Training was very good.Duration was not enough.',
#  'Our trainer made it very interesting ang gave many creative examples.',
#  'Ram was very nice and interactive,provided good examples',
#  'Content covered was very good.Sessions were very interactive',
#  'Course content was explained very clearly and precisely.It was very effective',
#  'It was a fantastic training session.Ram was a very knowledgable trainer.All the best to Ram and EXCELR',
#  'Trainer Ram was excellent and very interactive',
#  'Ram was an amazing trainer.He kept things very interesting and intriguing,used real life examples to understand better',
#  'Excellent interactive sessions conducted in a very enjoyable manner.It was a productive learning experience.',
#  'Excellent training.Examples were very helpful to understand the concept.',
#  'Trainers are well prepared and have indepth knowledge in the subject.',
#  'Very well structured and interactive.Good knowledge on the subject',
#  'The content and structure is very much useful for my career. The trainer was excellent',
#  'Fully descriptive and thorough training',
#  'Excellent program',
#  'Exellent',
#  'Excellent lecture',
#  'Great interactive training with real life examples for effective understanding.',
#  'The session was very interesting and interactive',
#  'The overall programme was excellent.I have gained more knowledge on ITIL.It will help me in my day to day activities.',
#  'Very informative.Aligned to practical work exposure.Real life examples made understanding easy',
#  'The content of the course and the structure is very useful. It helps me give better service to my client',
#  'Very much relevant for day to day work',
#  'Course contents and the way it was explained was well organized.',
#  'All modules of the course were covered fully.We got a superb trainer.Explanations and examples were very clear',
#  'Good but would be better with more time',
#  'Its good.It would be better if the duration is longer',
#  'Very well explained',
#  'Very useful and attractive',
#  'The course was very engaging and interesting',
#  'Gained knowledge on the subject',
#  'Excellent course',
#  'One of the best sessions i have ever participated in.All chapters related to ITIL were covered in a very short time in a very vibrant way',
#  'Great training',
#  'It was good learning,very understandable',
#  'It would have been better if we had some more time',
#  'Excellent training.Faculty has immense knowledge on subject.He manages it well',
#  'Excellent delivery of material with exercise and useful tips',
#  'Training is very exhaustive,detail and informative.All concepts were explained very well with examples.',
#  'Training is good. Knowledge of trainer is good',
#  'The best coach i ever had',
#  'Krishna comes with rich experience and made the learning sessions very interactive and interesting. He is a very good mentor.',
#  'Classroom sessions are engaging and interesting.All the KA were covered adequately.A good learning experience',
#  'Mentor was knowledgable and clarified our doubts efficiently. Training course was distributed well across 4 days and adequate time was spent on important areas which improved overall understanding.',
#  'PMP training is very good and interactive.Faculty thought us with good examples',
#  'Course was good with LMS access and mock tests.But there are times were it is dull and less interesting.',
#  'Training was good and precise. Our trainer was like an experienced professional.The facilities at the training centre were good too.Overall a good learning atmosphere.',
#  'The objective and delivery of the course is very clear and helps one to easily understand the project management.Also the examples were very helpful. i felt it was an effective and efficient session.',
#  'Course is well prepared and documented.More examples would be better',
#  'Training was good.Facilitator was clear on content and explained with common examples which made it easier.',
#  'I think it was all-in-all a good experience learning from ExcelR',
#  'Kiran demonstrated all the traits.required for the session excellently.',
#  'Training was very interactive , various field people , having no of examples.well explained training.',
#  'This is excellent and very informative and trainer is very interactive and crowd pulling. I enjoyed. I got my encouragement boosted for attending exam and seems easy to crack based on training & inputs',
#  'communication was very clear ,but completing the course in 4 days is good to have on saturdays .or even for better managing .only on the 1st half of saturdays& sundays would be fine.Infrastructure resources can be aligned better.',
#  'It is good presentation and the course content covered is understandable and it is easy to understand the PMP program',
#  'I had a great experience in learning PMP with trainer Krishna. With real time scenarios.',
#  'Good Trainer ,Clear understanding',
#  'Good Experience',
#  'Training given was good and set the understanding on the basics of ITIL',
#  'Excellent training provided by the experts on board with Excelr .Overall wonderful experience with this institute for my ITIL Foundation .Real time scenarios would further help us in understanding ITIL',
#  'Helpful & Adds a value add to our day to day work environment according to our role',
#  'It was good,We got lots of knowledge & understanding over the subject',
#  'Very good trainer ,Dinesh helped 7us to understand course with good & practical examples quality of training material solves the purpose .Have learnt a lot in my training with new knowlege to implement in daily worth',
#  'All the information regarding the training course was properly provided',
#  'The course was very helpful .The content was excellent',
#  'Nice Explanation ,Clearing the doubts, Giving real time examples to make concepts more visible',
#  'Helpful & interesting throughout the course',
#  'The course was very helpful also materials are very good ,Trainers are very Friendly',
#  'The training material and the classroom training is excellent .The trainer has efficiently explained the topics',
#  'Overall its an enriching learning experience .Very much satisfied with the course content and coaching style and depth of hold on the topic',
#  'I appreciate clartity and quality of the course content delivered by trainer "Yogesh".Iam happy to say that time & money inverted is worth to take your career to next level .I would suggest to allocate more time for practical lab senior',
#  'The course is quite exhaustive & attention to details is paramount',
#  'Very good & reached expectations.Gained confidence as i have gap in my career.Maintaining whatsapp group is good & also LMS videos are clear',
#  'The course quite exhaustive & attention to details is paramount',
#  ...]

# %%
len(result)
# Out:
# 1381
